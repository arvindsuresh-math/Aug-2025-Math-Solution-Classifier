# %%
# !pip install -U transformers==4.49.0
# Out:
# Collecting transformers==4.49.0
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (0.34.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.49.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.49.0) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.49.0) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.49.0) (2025.7.14)
# Using cached transformers-4.49.0-py3-none-any.whl (10.0 MB)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.55.0
#     Uninstalling transformers-4.55.0:
#       Successfully uninstalled transformers-4.55.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# trl 0.21.0 requires transformers>=4.55.0, but you have transformers 4.49.0 which is incompatible.
# Successfully installed transformers-4.49.0

# %%
# !pip install -Uq peft
# !pip install -Uq trl
# !pip install -Uq accelerate
# !pip install -Uq datasets
# !pip install -Uq bitsandbytes

# !pip install flash-attn==2.7.4.post1 \
  --extra-index-url https://download.pytorch.org/whl/cu124 \
  --no-build-isolation
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.9/503.9 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.9/511.9 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 112.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 33.7 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu124
# Collecting flash-attn==2.7.4.post1
#   Downloading flash_attn-2.7.4.post1.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 57.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from flash-attn==2.7.4.post1) (2.6.0+cu124)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash-attn==2.7.4.post1) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn==2.7.4.post1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->flash-attn==2.7.4.post1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->flash-attn==2.7.4.post1) (3.0.2)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.7.4.post1-cp311-cp311-linux_x86_64.whl size=187831595 sha256=58853b28a5a926cae14402bfd8d4d93a45ebf8f9e79533f37ab09d0d77a99c05
#   Stored in directory: /root/.cache/pip/wheels/3d/88/d8/284b89f56af7d5bf366b10d6b8e251ac8a7c7bf3f04203fb4f
# Successfully built flash-attn
# Installing collected packages: flash-attn
# Successfully installed flash-attn-2.7.4.post1

# %%
class Config:
    # Model ID from Hugging Face Hub
    MODEL_ID = "microsoft/Phi-4-mini-instruct"

    # Local path to the unzipped dataset
    DATASET_PATH = '/content/N3_disc.csv'

    # Number of labels for the classification task
    NUM_LABELS = 3

# %%
def label(error_type):
    if error_type == 'conceptual_error':
        return 2
    elif error_type == 'computational_error':
        return 1
    else:
        return 0

# %%
# --- 2.2: Load Dataset from Disk ---
from datasets import Dataset, DatasetDict
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv(Config.DATASET_PATH, index_col=0)

data['label'] = data['error_type'].apply(label)
data.drop(columns=['error_type'], inplace=True)

data_train, data_test = train_test_split(data, test_size=0.25,shuffle=False)

# Load the dataset using the path defined in our Config
raw_dataset_train = Dataset.from_pandas(data_train)
raw_dataset_test = Dataset.from_pandas(data_test)

# Combine the training and test datasets
raw_dataset = DatasetDict({
    'train': raw_dataset_train,
    'test': raw_dataset_test
})

# Display the structure of the loaded dataset
print("--- Raw Dataset Structure ---")
print(raw_dataset)
# Out:
# --- Raw Dataset Structure ---
# DatasetDict({
#     train: Dataset({
#         features: ['wrong_answer', 'label', 'question'],
#         num_rows: 3989
#     })
#     test: Dataset({
#         features: ['wrong_answer', 'label', 'question'],
#         num_rows: 1330
#     })
# })

# %%
raw_dataset['train'][2]
# Out:
# {'wrong_answer': 'Weng earns 12/60 = $0.2 per minute.\nWorking 50 minutes, she earned 0.2 x 50 = $10.\n#### 10',
#  'label': 0,
#  'question': 'Weng earns $12 an hour for babysitting. Yesterday, she just did 50 minutes of babysitting. How much did she earn?'}

# %%
# --- 3.1: Load and Configure the Tokenizer ---
from transformers import AutoTokenizer

# Load the tokenizer associated with the specified model
tokenizer = AutoTokenizer.from_pretrained(
    Config.MODEL_ID,
    trust_remote_code=True
)

# Configure tokenizer padding for a causal language model
tokenizer.padding_side = "left"
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print("Tokenizer loaded and configured successfully.")
# Out:
# Tokenizer loaded and configured successfully.

# %%
# --- 3.2: Define and Apply Preprocessing ---

def preprocess_function(examples):
    """
    Formats the input text using a prompt template and tokenizes it.
    The 'label' and 'index' columns are passed through untouched.
    """
    # Define the instruction prompt for the model
    system_prompt = """ You are given a math word problem, and a solution written by a student.
Analyze the solution, and determine if the solution is correct (All logic is correct, and all calculations are correct), or it has a conceptual Error (There is an error in reasoning or logic somewhere in the solution, but all the calculations are correct)
, or it has a computational Error (All logic and reasoning is correct, but the result of some calculation is incorrect). """

    # Create a single formatted input string for each example
    input_texts = [
        f"{system_prompt}\n\n### Problem:\n{q}\n\n### Answer:\n{t}"
        for q, t in zip(examples["question"], examples["wrong_answer"])
    ]

    # Tokenize the formatted text
    return tokenizer(
        input_texts,
        truncation=True,
        max_length=512,
        padding=False
    )

# Apply the function to all splits of the dataset
tokenized_dataset = raw_dataset.map(
    preprocess_function,
    batched=True,  # Process examples in batches for speed
    remove_columns=["question", "wrong_answer"]
)

# --- Verification of a Single Example ---

# 1. Reconstruct the full prompt for the first training example
first_example_raw = raw_dataset["train"][0]
system_prompt = """ You are given a math word problem, and a solution written by a student.
Analyze the solution, and determine if the solution is correct (All logic is correct, and all calculations are correct), or it has a conceptual Error (There is an error in reasoning or logic somewhere in the solution, but all the calculations are correct)
, or it has a computational Error (All logic and reasoning is correct, but the result of some calculation is incorrect). """
full_prompt = f"{system_prompt}\n\n### Problem:\n{first_example_raw['question']}\n\n### {first_example_raw['wrong_answer']}"

# 2. Get the tokenized output for the same example
first_example_tokenized = tokenized_dataset["train"][0]["input_ids"]

# 3. Print everything for inspection
print("--- Example of a Single Processed Input ---")
print("\n[Full Prompt String]\n")
print(full_prompt)
print("\n\n[Corresponding Token IDs]\n")
print(first_example_tokenized)
# Out:
# Map:   0%|          | 0/3989 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1330 [00:00<?, ? examples/s]
# --- Example of a Single Processed Input ---
#
# [Full Prompt String]
#
#  You are given a math word problem, and a solution written by a student.
# Analyze the solution, and determine if the solution is correct (All logic is correct, and all calculations are correct), or it has a conceptual Error (There is an error in reasoning or logic somewhere in the solution, but all the calculations are correct)
# , or it has a computational Error (All logic and reasoning is correct, but the result of some calculation is incorrect).
#
# ### Problem:
# Weng earns $12 an hour for babysitting. Yesterday, she just did 50 minutes of babysitting. How much did she earn?
#
# ### Weng earns 12/60 = $0.2 per minute.
# Working 50 minutes, she earned 0.2 x 50 = $11.
# #### 11
#
#
# [Corresponding Token IDs]
#
# [1608, 553, 4335, 261, 13324, 2195, 4792, 11, 326, 261, 7578, 7582, 656, 261, 6760, 558, 107202, 290, 7578, 11, 326, 11433, 538, 290, 7578, 382, 6145, 350, 2594, 18485, 382, 6145, 11, 326, 722, 48742, 553, 6145, 936, 503, 480, 853, 261, 60567, 8654, 350, 5632, 382, 448, 2915, 306, 57927, 503, 18485, 22991, 306, 290, 7578, 11, 889, 722, 290, 48742, 553, 6145, 446, 11, 503, 480, 853, 261, 76423, 8654, 350, 2594, 18485, 326, 57927, 382, 6145, 11, 889, 290, 1534, 328, 1236, 40722, 382, 25570, 741, 1202, 31639, 26113, 734, 54, 882, 112231, 548, 899, 448, 8825, 395, 95717, 6603, 13, 85247, 11, 1770, 1327, 2242, 220, 1434, 5438, 328, 95717, 6603, 13, 3253, 2009, 2242, 1770, 8748, 1715, 31639, 30985, 734, 54, 882, 112231, 220, 899, 14, 1910, 314, 548, 15, 13, 17, 777, 12434, 558, 39580, 220, 1434, 5438, 11, 1770, 22639, 220, 15, 13, 17, 1215, 220, 1434, 314, 548, 994, 558, 1509, 220, 994]

# %%
# --- 3.3: Combine Training and Validation Splits ---
from datasets import concatenate_datasets, DatasetDict

final_dataset = DatasetDict({
    "train": tokenized_dataset['train'],
    "test": tokenized_dataset["test"]
})

# Display the structure of the final dataset to be used for training
print("--- Final Dataset for Training and Evaluation ---")
print(final_dataset)
# Out:
# --- Final Dataset for Training and Evaluation ---
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 3989
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 1330
#     })
# })

# %%
# --- 4.1: Define the Custom Classifier Class ---
import torch.nn as nn

class GPTSequenceClassifier(nn.Module):
    """
    A custom wrapper class for sequence classification using an LLM backbone.
    """
    def __init__(self, base_model, num_labels):
        super().__init__()
        self.base = base_model
        hidden_size = base_model.config.hidden_size
        self.classifier = nn.Linear(hidden_size, num_labels, bias=True)
        self.num_labels = num_labels

    def forward(self, input_ids=None, attention_mask=None, labels=None, **kwargs):
        # 1. Get hidden states from the backbone
        outputs = self.base(
            input_ids=input_ids,
            attention_mask=attention_mask,
            output_hidden_states=True,
            **kwargs,
            )

        # 2. Perform last-token pooling
        last_hidden_state = outputs.hidden_states[-1]
        pooled_output = last_hidden_state[:, -1, :]

        # 3. Pass the pooled output through the classifier to get logits
        logits = self.classifier(pooled_output)

        # 4. Calculate loss if labels are provided (i.e., during training)
        loss = None
        if labels is not None:
            loss = nn.functional.cross_entropy(logits.view(-1, self.num_labels), labels.view(-1))

        # Return a dictionary compatible with the Hugging Face Trainer
        return {"loss": loss, "logits": logits} if loss is not None else {"logits": logits}

print("SequenceClassifier class defined successfully.")
# Out:
# SequenceClassifier class defined successfully.

# %%
# --- 5.1: Define Common Training Arguments ---
from transformers import TrainingArguments

# Define the arguments that will be shared across both training runs.
training_args = TrainingArguments(
    # Base directory for outputs. Specific trainers will use subdirectories.
    output_dir="/content/training_output",

    # --- Batching & Epochs ---
    num_train_epochs=5,
    per_device_train_batch_size=8,
    gradient_accumulation_steps=4,

    # --- Optimizer & Learning Rate Schedule ---
    optim="paged_adamw_8bit",
    learning_rate=1e-4,
    lr_scheduler_type="cosine",
    warmup_ratio=0.1,

    # --- Precision & Memory ---
    bf16=True,
    gradient_checkpointing=False,

    # --- Logging & Checkpointing ---
    logging_strategy="steps",
    logging_steps=25,
    save_strategy="epoch",
    save_total_limit=1,
    report_to="none",
    save_safetensors=False,
)

print("Common TrainingArguments configured.")
# Out:
# Common TrainingArguments configured.

# %%
# --- 5.2: Define the Evaluation Metric ---
import numpy as np
from transformers.trainer_utils import EvalPrediction

def compute_metrics(p: EvalPrediction):
    """
    Computes accuracy for a sequence classification task. Accepts an EvalPrediction object `p` which contains the model's predictions and true labels. Returns a dictionary mapping `"accuracy"` to its value.
    """
    logits = p.predictions[0] if isinstance(p.predictions, (tuple, list)) else p.predictions
    preds = np.argmax(logits, axis=1)
    labels = p.label_ids
    accuracy = (preds == labels).mean().item()
    return {"accuracy": accuracy}

print("Metric computation function defined.")
# Out:
# Metric computation function defined.

# %%
# --- 6.1: Define and Freeze the Backbone for Probing ---
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

# Define the data type and quantization configuration
DTYPE = torch.bfloat16
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=DTYPE,
)

# Load a fresh instance of the base model
backbone_probe = AutoModelForCausalLM.from_pretrained(
    Config.MODEL_ID,
    quantization_config=quantization_config,
    device_map="auto",
    trust_remote_code=True,
    attn_implementation="flash_attention_2",
)

# --- CRITICAL STEP: Freeze all parameters in the backbone ---
for param in backbone_probe.parameters():
    param.requires_grad = False

# #  # Verify that all weights are frozen
# print("Trainable parameters for linear probe model:")
# backbone_probe.base.print_trainable_parameters() # Should show 0 trainable params

# Ensure the model's pad token ID is set correctly
backbone_probe.config.pad_token_id = tokenizer.pad_token_id

print("Backbone for linear probing loaded and all parameters frozen.")
# Out:
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.77G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# Backbone for linear probing loaded and all parameters frozen.

# %%
# --- 6.2: Initialize the Linear Probe Trainer ---
from transformers import Trainer, DataCollatorWithPadding
import copy

# Instantiate the model: frozen backbone + trainable head.
model_probe = GPTSequenceClassifier(backbone_probe, Config.NUM_LABELS)

# Verify which parts of the model are trainable.
# We expect to see that only the 'classifier' parameters require gradients.
total_params = 0
trainable_params = 0
print("--- Trainable Status for Linear Probe Model ---")
for name, param in model_probe.named_parameters():
    total_params += param.numel()
    if param.requires_grad:
        trainable_params += param.numel()
        print(f"  [Trainable]: {name}")
print(f"-------------------------------------------------")
print(f"Trainable params: {trainable_params} || All params: {total_params} || Trainable %: {100 * trainable_params / total_params:.4f}")

# Create a copy of the shared training args to modify the output directory
probe_training_args = copy.deepcopy(training_args)
probe_training_args.output_dir = "/content/training_output/linear_probe"

# The data collator will dynamically pad inputs in each batch.
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Instantiate a dedicated Trainer for the linear probe experiment.
trainer_probe = Trainer(
    model=model_probe,
    args=probe_training_args,
    train_dataset=final_dataset["train"],
    eval_dataset=final_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

print("\nTrainer for linear probing initialized successfully.")
# Out:
# --- Trainable Status for Linear Probe Model ---
#   [Trainable]: classifier.weight
#   [Trainable]: classifier.bias
# -------------------------------------------------
# Trainable params: 9219 || All params: 2225418243 || Trainable %: 0.0004
#
# Trainer for linear probing initialized successfully.
# /tmp/ipython-input-191356708.py:29: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer_probe = Trainer(

# %%
# --- 7.1: Define the LoRA-Enabled Model ---
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType

# Load a fresh instance of the base model for this experiment
backbone_lora = AutoModelForCausalLM.from_pretrained(
    Config.MODEL_ID,
    quantization_config=quantization_config, # Defined in 6.1
    device_map="auto",
    trust_remote_code=True,
    attn_implementation="flash_attention_2",
)
backbone_lora.config.pad_token_id = tokenizer.pad_token_id

# Define the configuration for the LoRA adapters
lora_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules="all-linear",
)

# Apply the LoRA configuration to the backbone
lora_backbone = get_peft_model(backbone_lora, lora_config)

# Instantiate the new model with the LoRA backbone
model_lora = GPTSequenceClassifier(lora_backbone, Config.NUM_LABELS)

# Verify which parts of the model are trainable.
# We expect to see LoRA adapter weights ('lora_A', 'lora_B') and 'classifier' weights.
total_params = 0
trainable_params = 0
print("--- Trainable Status for LoRA Fine-Tuning Model ---")
for name, param in model_lora.named_parameters():
    total_params += param.numel()
    if param.requires_grad:
        trainable_params += param.numel()
        print(f"  [Trainable]: {name}")
print(f"-------------------------------------------------")
print(f"Trainable params: {trainable_params} || All params: {total_params} || Trainable %: {100 * trainable_params / total_params:.4f}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# --- Trainable Status for LoRA Fine-Tuning Model ---
#   [Trainable]: base.base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.0.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.1.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.2.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.3.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.4.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.5.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.6.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.7.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.8.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.9.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.10.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.11.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.12.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.13.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.14.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.15.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.16.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.17.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.18.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.19.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.20.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.21.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.22.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.23.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.24.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.25.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.26.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.27.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.28.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.29.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.30.mlp.down_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.self_attn.o_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.self_attn.o_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.self_attn.qkv_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.self_attn.qkv_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.mlp.gate_up_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.mlp.gate_up_proj.lora_B.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.mlp.down_proj.lora_A.default.weight
#   [Trainable]: base.base_model.model.model.layers.31.mlp.down_proj.lora_B.default.weight
#   [Trainable]: classifier.weight
#   [Trainable]: classifier.bias
# -------------------------------------------------
# Trainable params: 23077891 || All params: 2248486915 || Trainable %: 1.0264

# %%
# --- 7.2: Initialize the LoRA Trainer ---
import copy
from transformers import Trainer

# Create a copy of the shared training args to modify the output directory
lora_training_args = copy.deepcopy(training_args)
lora_training_args.output_dir = "/content/training_output/lora_finetune"

# Instantiate a new Trainer for the full fine-tuning experiment.
trainer_lora = Trainer(
    model=model_lora,
    args=lora_training_args,
    train_dataset=final_dataset["train"],
    eval_dataset=final_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,      # Defined in 6.2
    compute_metrics=compute_metrics,  # Defined in 5.2
)

print("Trainer for full LoRA fine-tuning initialized successfully.")
# Out:
# Trainer for full LoRA fine-tuning initialized successfully.
# /tmp/ipython-input-1624353024.py:10: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer_lora = Trainer(

# %%
# --- 7.3: Fine-Tune the LoRA Model ---

print("--- Starting full LoRA fine-tuning ---")
trainer_lora.train()
print("\n--- Full LoRA fine-tuning complete ---")
# Out:
# --- Starting full LoRA fine-tuning ---
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
#     <div>
#
#       <progress value='620' max='620' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [620/620 25:00, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>4.428100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.263400</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>4.076500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.712800</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>3.458200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>3.149000</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>2.923700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.842200</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>2.842200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.589000</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>1.840700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.320600</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>1.070600</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.218200</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.879800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.623500</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.654100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.526300</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.467800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.532900</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.261800</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.349100</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.295700</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.194600</td>
#     </tr>
#   </tbody>
# </table><p>
# --- Full LoRA fine-tuning complete ---

# %%
import gc
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
trainer_lora.evaluate()
# Out:
#     <div>
#
#       <progress value='167' max='167' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [167/167 00:43]
#     </div>
# {'eval_loss': 0.47711265087127686,
#  'eval_accuracy': 0.8879699248120301,
#  'eval_runtime': 43.4494,
#  'eval_samples_per_second': 30.61,
#  'eval_steps_per_second': 3.844,
#  'epoch': 4.993987975951904}

# %%
comp_vs_correct = Dataset.from_pandas(data_test[data_test['label']!=2])

tokenized_comp_vs_correct = comp_vs_correct.map(
    preprocess_function,
    batched=True,  # Process examples in batches for speed
    remove_columns=["question", "wrong_answer"]
)

trainer_lora.evaluate(tokenized_comp_vs_correct)
# Out:
# Map:   0%|          | 0/887 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='278' max='167' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [167/167 08:26]
#     </div>
# {'eval_loss': 0.4444761872291565,
#  'eval_accuracy': 0.8962795941375423,
#  'eval_runtime': 29.8083,
#  'eval_samples_per_second': 29.757,
#  'eval_steps_per_second': 3.724,
#  'epoch': 4.993987975951904}

# %%
concep_vs_correct = Dataset.from_pandas(data_test[data_test['label']!=1])

tokenized_concep_vs_correct = concep_vs_correct.map(
    preprocess_function,
    batched=True,  # Process examples in batches for speed
    remove_columns=["question", "wrong_answer"]
)

trainer_lora.evaluate(tokenized_concep_vs_correct)
# Out:
# Map:   0%|          | 0/887 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='500' max='167' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [167/167 10:32]
#     </div>
# {'eval_loss': 0.5339984893798828,
#  'eval_accuracy': 0.8793686583990981,
#  'eval_runtime': 29.6798,
#  'eval_samples_per_second': 29.886,
#  'eval_steps_per_second': 3.74,
#  'epoch': 4.993987975951904}
