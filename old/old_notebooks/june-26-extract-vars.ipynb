# %%
import sys
from pathlib import Path
import ast
import importlib.util

# ---------------------------------------------------------------------- #
#  Global constants & Configuration
# ---------------------------------------------------------------------- #

def find_project_root():
    """Traverse upwards to find the project root, marked by the .git folder."""
    current_path = Path.cwd()
    while current_path != current_path.parent:
        if (current_path / ".git").is_dir():
            return current_path
        current_path = current_path.parent
    raise FileNotFoundError("Could not find project root. Is this a git repository?")


PROJECT_ROOT = find_project_root()
BASE_OUTPUT_DIR = PROJECT_ROOT / 'data' / 'code_gen_outputs_formatted'
print(f"Project root found: {PROJECT_ROOT}")
print(f"Base output directory set to: {BASE_OUTPUT_DIR}")

MODEL_DICT = {
  "anthropic": ["claude-3-5-haiku-20241022"], 
  "openai": ["gpt-4.1-mini"],
  "google": ["gemini-2.0-flash-thinking-exp", 
             "gemini-2.5-flash-lite-preview-06-17",
             "gemini-2.5-flash"]
}

MODELS = [f"{provider}_{model}" for provider, sublist in MODEL_DICT.items() for model in sublist]
print(f"Available models: {MODELS}")
# Out:
# Project root found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math
# Base output directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted
# Available models: ['anthropic_claude-3-5-haiku-20241022', 'openai_gpt-4.1-mini', 'google_gemini-2.0-flash-thinking-exp', 'google_gemini-2.5-flash-lite-preview-06-17', 'google_gemini-2.5-flash']

# %%
import ast
import importlib.util
import pandas as pd

def eval_default_expr(expr_node):
    """
    Safely evaluate a default argument AST node to obtain its value.

    Tries to use ast.literal_eval for simple literals (numbers, strings, etc.).
    Falls back to evaluating the expression using eval/compile for cases like arithmetic expressions (e.g., 1/2, 2*3).
    
    Parameters
    ----------
    expr_node : ast.AST
        The AST node representing the default value expression.

    Returns
    -------
    Any
        The evaluated value of the expression.
    """
    try:
        return ast.literal_eval(expr_node)
    except Exception:
        return eval(compile(ast.Expression(expr_node), filename="<ast>", mode="eval"))

def extract_vars_to_df(
        index: int, 
        models: list, 
        output_dir=BASE_OUTPUT_DIR,
        verbose=True,
        save=True):
    """
    Extracts argument and variable information from the 'solve' function in generated Python files for multiple models.

    For each model, loads the corresponding Python file, parses the 'solve' function, and collects:
      - All argument names, types (from type hints), and default values.
      - All intermediate and final variables (as determined by local variables in the function).
      - The role of each variable ('argument', 'intermediate', or 'final').

    Returns a pandas DataFrame with columns: index, model, variable, role, type, value.
    Optionally saves the DataFrame as a CSV file for each problem index.

    Parameters
    ----------
    index : int
        The problem index to process.
    models : list
        List of model names to process for the given index.
    output_dir : Path, optional
        The base directory containing the generated Python files (default: BASE_OUTPUT_DIR).
    verbose : bool, optional
        If True, prints progress and error messages (default: True).
    save : bool, optional
        If True, saves the resulting DataFrame as a CSV file (default: True).

    Returns
    -------
    pd.DataFrame
        DataFrame containing variable information for all models for the given index.
    """
    rows = []
    for model in models:
        problem_dir = output_dir / f"{index}"
        py_file_path = problem_dir / f"{model}.py"
        try:
            spec = importlib.util.spec_from_file_location("module.name", py_file_path)
            module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(module)
            if verbose:
                print(f"Processing ast for model {model}")
            with open(py_file_path, "r") as f:
                source = f.read()
            tree = ast.parse(source)

            result = {}

            for node in ast.walk(tree):
                if isinstance(node, ast.FunctionDef) and node.name == "solve":
                    # Arguments
                    args = node.args.args
                    defaults = node.args.defaults
                    if len(defaults) != len(args):
                        raise ValueError("All arguments must have default values.")
                    for arg, default in zip(args, defaults):
                        arg_name = arg.arg
                        # Get type from annotation
                        if arg.annotation is not None:
                            if isinstance(arg.annotation, ast.Name):
                                arg_type = arg.annotation.id
                            elif isinstance(arg.annotation, ast.Subscript):
                                arg_type = ast.unparse(arg.annotation)
                            else:
                                arg_type = str(ast.dump(arg.annotation))
                        else:
                            arg_type = "unknown"
                        value = eval_default_expr(default)
                        result[arg_name] = {
                            "role": "argument",
                            "type": arg_type,
                            "value": value
                        }
                    # Intermediate/final variables
                    solve_func = getattr(module, "solve")
                    arg_values = [result[arg.arg]["value"] for arg in args]
                    def capture_locals(*args, **kwargs):
                        frame = {}
                        def tracer(frame_obj, event, arg):
                            if event == "return":
                                frame.update(frame_obj.f_locals)
                            return tracer
                        sys.setprofile(tracer)
                        try:
                            ret = solve_func(*args, **kwargs)
                        finally:
                            sys.setprofile(None)
                        return frame, ret
                    locals_dict, _ = capture_locals(*arg_values)
                    for var, val in locals_dict.items():
                        if var not in result:
                            role = "final" if var == "answer" else "intermediate"
                            result[var] = {
                                "role": role,
                                "type": type(val).__name__,
                                "value": val
                            }
                    break
            # Add to rows
            for var, info in result.items():
                rows.append({
                    "index": index,
                    "model": model,
                    "variable": var,
                    "role": info["role"],
                    "type": info["type"],
                    "value": info["value"]
                })
        except FileNotFoundError:
            if verbose:
                print(f"File not found: {py_file_path}, skipping.")
            continue
        except Exception as e:
            if verbose:
                print(f"Error processing {py_file_path}: {e}, skipping.")
            continue
    df = pd.DataFrame(rows, columns=["index", "model", "variable", "role", "type", "value"])

    # save if required
    if save and not df.empty:
        save_path = problem_dir / f"{index}_variables.csv"
        df.to_csv(save_path, index=False)
    return df

# %%
vars_df_dict = {}
for index in range(100):
    print(f"Extracting variables for problem {index}")
    vars_df_dict[index] = extract_vars_to_df(index, MODELS)
# Out:
# Extracting variables for problem 0
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 1
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 2
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 3
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 4
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 5
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 6
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 7
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 8
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 9
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 10
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 11
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 12
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 13
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 14
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 15
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 16
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 17
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 18
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 19
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 20
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 21
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 22
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 23
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 24
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 25
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 26
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 27
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 28
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 29
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 30
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 31
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 32
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 33
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 34
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 35
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 36
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 37
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 38
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 39
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 40
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 41
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 42
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 43
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 44
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 45
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 46
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 47
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 48
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 49
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 50
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 51
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 52
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 53
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 54
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 55
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 56
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 57
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 58
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 59
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 60
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 61
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 62
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 63
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 64
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 65
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 66
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 67
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 68
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 69
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 70
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 71
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/71/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 72
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 73
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 74
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 75
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 76
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/76/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 77
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 78
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 79
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 80
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 81
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 82
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 83
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 84
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 85
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 86
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 87
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 88
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 89
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 90
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 91
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 92
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 93
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 94
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 95
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 96
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 97
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 98
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Extracting variables for problem 99
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash

# %%
display(vars_df_dict[26])  # Displaying the DataFrame for problem index 25
# Out:
#     index                                       model            variable  \
# 0      26         anthropic_claude-3-5-haiku-20241022     seawater_volume
# 1      26         anthropic_claude-3-5-haiku-20241022     salt_percentage
# 2      26         anthropic_claude-3-5-haiku-20241022        ml_per_liter
# 3      26         anthropic_claude-3-5-haiku-20241022  salt_volume_liters
# 4      26         anthropic_claude-3-5-haiku-20241022      salt_volume_ml
# 5      26         anthropic_claude-3-5-haiku-20241022              answer
# 6      26                         openai_gpt-4.1-mini     liters_seawater
# 7      26                         openai_gpt-4.1-mini     salt_percentage
# 8      26                         openai_gpt-4.1-mini         liters_salt
# 9      26                         openai_gpt-4.1-mini             ml_salt
# 10     26                         openai_gpt-4.1-mini              answer
# 11     26        google_gemini-2.0-flash-thinking-exp     seawater_liters
# 12     26        google_gemini-2.0-flash-thinking-exp     salt_percentage
# 13     26        google_gemini-2.0-flash-thinking-exp        ml_per_liter
# 14     26        google_gemini-2.0-flash-thinking-exp      liters_of_salt
# 15     26        google_gemini-2.0-flash-thinking-exp          ml_of_salt
# 16     26        google_gemini-2.0-flash-thinking-exp              answer
# 17     26  google_gemini-2.5-flash-lite-preview-06-17  liters_of_seawater
# 18     26  google_gemini-2.5-flash-lite-preview-06-17     salt_percentage
# 19     26  google_gemini-2.5-flash-lite-preview-06-17      liters_of_salt
# 20     26  google_gemini-2.5-flash-lite-preview-06-17          ml_of_salt
# 21     26  google_gemini-2.5-flash-lite-preview-06-17              answer
# 22     26                     google_gemini-2.5-flash     seawater_liters
# 23     26                     google_gemini-2.5-flash     salt_percentage
# 24     26                     google_gemini-2.5-flash      liters_of_salt
# 25     26                     google_gemini-2.5-flash          ml_of_salt
# 26     26                     google_gemini-2.5-flash              answer
#
#             role   type   value
# 0       argument  float     2.0
# 1       argument  float     0.2
# 2       argument    int  1000.0
# 3   intermediate  float     0.4
# 4   intermediate  float   400.0
# 5          final  float   400.0
# 6       argument  float     2.0
# 7       argument  float    20.0
# 8   intermediate  float     0.4
# 9   intermediate  float   400.0
# 10         final  float   400.0
# 11      argument    int     2.0
# 12      argument    int    20.0
# 13      argument    int  1000.0
# 14  intermediate  float     0.4
# 15  intermediate  float   400.0
# 16         final  float   400.0
# 17      argument  float     2.0
# 18      argument  float     0.2
# 19  intermediate  float     0.4
# 20  intermediate  float   400.0
# 21         final  float   400.0
# 22      argument    int     2.0
# 23      argument  float     0.2
# 24  intermediate  float     0.4
# 25  intermediate  float   400.0
# 26         final  float   400.0
