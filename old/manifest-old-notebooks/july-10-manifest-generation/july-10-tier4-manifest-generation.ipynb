# %% [markdown]
# #### Cell 1: Paths

# %%
from pathlib import Path

def find_project_root():
    """Traverse upwards to find the project root, marked by the .git folder."""
    current_path = Path.cwd()
    while current_path != current_path.parent:
        if (current_path / ".git").is_dir():
            return current_path
        current_path = current_path.parent
    raise FileNotFoundError("Could not find project root. Is this a git repository?")

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / 'data'

# To contain generated manifest txt files
MANIFEST_OUTPUT_DIR = DATA_DIR / "tier-manifests-gen-txt" 

# Contains sample manifest json files, questions answers, and user prompt prefixes
MANIFEST_EXAMPLES_DIR = DATA_DIR / "tier-manifests-examples-json" 

TIER_OUTPUT_DIRS = {f"tier{i}": MANIFEST_OUTPUT_DIR / f"tier{i}" for i in range(1, 6)}
TIER_EXAMPLES_DIRS = {f"tier{i}": MANIFEST_EXAMPLES_DIR / f"tier{i}" for i in range(1, 6)}

# Make the directory for the tier if it doesn't exist
for tier_dir in TIER_OUTPUT_DIRS.values():
    tier_dir.mkdir(parents=True, exist_ok=True)

for tier_dir in TIER_EXAMPLES_DIRS.values():
    tier_dir.mkdir(parents=True, exist_ok=True)

print(f"Project root found at: {PROJECT_ROOT}")
print(f"Data directory found at: {DATA_DIR}")
print(f"Raw manifest output directory set to: {MANIFEST_OUTPUT_DIR}")
# Out:
# Project root found at: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math
# Data directory found at: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data
# Raw manifest output directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-gen-txt

# %% [markdown]
# #### Cell 2: Dataset and tier definitions

# %%
import datasets
from datasets import load_dataset 
import re

GSM8K_TRAIN = load_dataset("gsm8k", "main", split="train")

def has_computational_division(solution_text: str):
    """Returns True if a '/' is followed by optional whitespace and then a digit."""
    pattern = re.compile(r'/\s*\d')
    return bool(pattern.search(solution_text))


def has_float(solution_text: str):
    """Returns True if the solution text contains a floating-point number."""
    pattern = re.compile(r'(?<!\d)\.\d+|\d+\.\d+')
    return bool(pattern.search(solution_text))


def is_symbolic(solution_text: str):
    """Returns True if the solution contains a symbolic reasoning line (Let @ ...)."""
    pattern = re.compile(r'^Let [a-zA-Z] ', re.MULTILINE)
    return bool(pattern.search(solution_text))


def mutually_disjoint_tiers(dataset: datasets.Dataset):
    tiers = {}
    symbolic_set = set(
        idx for idx, sample in enumerate(dataset)
        if is_symbolic(sample.get("answer", ""))
    )
    non_symbolic_indices = [
        idx for idx in range(len(dataset)) if idx not in symbolic_set
    ]

    # Tier 1: Only integer arithmetic (no floats, no computational division)
    tiers["tier1"] = sorted([
        idx for idx in non_symbolic_indices
        if not has_float(dataset[idx].get("answer", "")) and not has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 2: Float arithmetic, no computational division
    tiers["tier2"] = sorted([
        idx for idx in non_symbolic_indices
        if has_float(dataset[idx].get("answer", "")) and not has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 3: Computational division, no floats
    tiers["tier3"] = sorted([
        idx for idx in non_symbolic_indices
        if not has_float(dataset[idx].get("answer", "")) and has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 4: Both floats and computational division
    tiers["tier4"] = sorted([
        idx for idx in non_symbolic_indices
        if has_float(dataset[idx].get("answer", "")) and has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 5: Symbolic reasoning (Let @ ...)
    tiers["tier5"] = sorted(symbolic_set)

    return tiers


TIER_LISTS = mutually_disjoint_tiers(GSM8K_TRAIN)

# Display the number of samples in each tier
for tier, indices in TIER_LISTS.items():
    print(f"{tier:<10}: {len(indices)} samples")
print(f"{'Total':<10}: {len(GSM8K_TRAIN)} samples")
# Out:
# tier1     : 2767 samples
# tier2     : 837 samples
# tier3     : 3113 samples
# tier4     : 544 samples
# tier5     : 212 samples
# Total     : 7473 samples

# %% [markdown]
# #### **Selecting the current tier for this notebook**

# %%
### --- Select the tier ONCE for this notebook --- ###
CURRENT_TIER = "tier4"

CURRENT_INDICES = TIER_LISTS[CURRENT_TIER]
CURRENT_TIER_OUTPUT_DIR = TIER_OUTPUT_DIRS[CURRENT_TIER]
CURRENT_TIER_EXAMPLES_DIR = TIER_EXAMPLES_DIRS[CURRENT_TIER]

print(f"Tier for this notebook: {CURRENT_TIER}")
print(f"Number of samples in {CURRENT_TIER}: {len(CURRENT_INDICES)}")
print(f"Output directory for {CURRENT_TIER}: {CURRENT_TIER_OUTPUT_DIR}")
print(f"Examples directory for {CURRENT_TIER}: {CURRENT_TIER_EXAMPLES_DIR}")
# Out:
# Tier for this notebook: tier4
# Number of samples in tier4: 544
# Output directory for tier4: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-gen-txt/tier4
# Examples directory for tier4: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-examples-json/tier4

# %% [markdown]
# #### Cell 3: Prompt creation

# %%
import json


def sanitize_text(text: str):
    """
    Replaces a comprehensive set of problematic Unicode characters with their
    ASCII equivalents to prevent model generation and string parsing errors.
    """
    replacements = {
        # Mathematical Operators
        "\u2212": "-",  # Minus Sign
        "\u00d7": "*",  # Multiplication Sign
        "\u00f7": "/",  # Division Sign
        "\u22c5": "*",  # Dot Operator
        
        # Typographic Quotes
        "\u201c": '"',  # Left Double Quotation Mark
        "\u201d": '"',  # Right Double Quotation Mark
        "\u2018": "'",  # Left Single Quotation Mark
        "\u2019": "'",  # Right Single Quotation Mark
        
        # Typographic Dashes
        "\u2014": "-",  # Em Dash
        "\u2013": "-",  # En Dash
        
        # Other
        "\u2026": "...", # Horizontal Ellipsis
        "\u00a0": " ",  # Non-breaking Space
    }
    for uni, ascii_char in replacements.items():
        text = text.replace(uni, ascii_char)
    return text


def build_solution_mapping(
        index: int, 
        dataset: 'datasets.Dataset' = GSM8K_TRAIN,
        exclude_FA: bool = True
    ):
    """
    Extracts the natural language solution, sanitizes it, and structures
    it into a line-numbered dictionary.
    """
    solution_mapping = {}
    solution_text = dataset[index]["answer"]
    sanitized_solution_text = sanitize_text(solution_text)
    
    # --- CORRECTION: Use the sanitized variable ---
    lines = [ln.strip() for ln in sanitized_solution_text.splitlines() if ln.strip()]

    if lines and re.match(r"^####\s*[\d\.,]+$", lines[-1]):
        solution_mapping["FA"] = lines.pop(-1).strip()

    for i, line in enumerate(lines, 1):
        solution_mapping[f"L{i}"] = line

    if exclude_FA and "FA" in solution_mapping:
        del solution_mapping["FA"]

    return solution_mapping


BASE_MANIFEST_SCHEMA = {
    "type": "object",
    "properties": {
        "function_code": {
            "type": "string",
            "description": "A single string containing a complete, self-contained Python function that constitutes an end-to-end formalization of the solution."
        },
        "logical_steps": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "line_number": {"type": "string"},
                    "question_inputs": {"type": "array", "items": {"type": "string"}},
                    "WK_inputs": {"type": "array", "items": {"type": "string"}},
                    "output_variable": {"type": "string"},
                    "solution_line_template": {"type": "string"}
                },
                "required": ["line_number", "question_inputs", "WK_inputs", "output_variable", "solution_line_template"]
            }
        }
    },
    "required": ["function_code", "logical_steps"]
}


SYSTEM_PROMPT = """You are a data formalization expert who excels in mathematical reasoning and writing python code. You will be presented with a math word problem accompanied by a step-by-step natural language solution. You goal is to carefully and meticulously analyze the given question and solution, and formalize it by converting it into a structured json object that deconstructs the logic of the solution.

You MUST follow all rules and formatting instructions provided in the user prompt without deviation. Your entire output MUST be a single JSON object wrapped in ```json ... ```. Do not include any text or explanation before or after the JSON object."""

STATIC_PREFIXES = {}
for tier in TIER_LISTS.keys():
    prefix_file = TIER_EXAMPLES_DIRS[tier] / f"{tier}_user_prompt_prefix.txt"
    with open(prefix_file, 'r', encoding='utf-8') as f:
        STATIC_PREFIXES[tier] = f.read()


def append_sample_to_user_prompt(
        tier: str, 
        index: int, 
        dataset: datasets.Dataset = GSM8K_TRAIN
    ):
    """
    Appends a chosen sample from the GSM8K dataset to the user prompt for a specific tier. Returns the complete user prompt, ready to be sent to the LLM for manifest generation.
    """
    if tier not in TIER_LISTS:
        raise ValueError(f"Invalid tier: {tier}. Must be one of {list(TIER_LISTS.keys())}.")

    sample = dataset[index]
    question = sample['question']
    answer = build_solution_mapping(index, dataset)

    task_block = f"""## Input

**Index:**:
{index}

**Question:**:
{question}

**Solution mapping:**:
{json.dumps(answer, indent=2)}

## Output

"""
    return STATIC_PREFIXES[tier] + task_block


# Example usage
idx = CURRENT_INDICES[0]
user_prompt = append_sample_to_user_prompt(CURRENT_TIER, idx, GSM8K_TRAIN)
print(f"User prompt for index {idx} in {CURRENT_TIER} has {len(user_prompt)} characters:")
print("-"*80)
print(user_prompt)
# Out:
# User prompt for index 1 in tier4 has 22581 characters:
# --------------------------------------------------------------------------------
# In the TASK below, you will be given a math problem and its corresponding step-by-step solution. Each step in the solution is numbered (e.g. "L1", "L2" and so on), and many of the steps include calculator annotations (e.g. "<<20*0.1=2>>"). Your goal is to convert this information into a structured JSON object according to the following detialed instructions.
#
# # Detailed Field Instructions
#
# ## 1. "function_code"
#
# This string must contain a Python function with the following characteristics:
#
# *   **1.A. Handling Imports:** The `function_code` should have no imports **unless** your formalization requires the `Fraction` object.
#     *   If your code uses the `Fraction()` constructor, the very first line of the string MUST be `from fractions import Fraction`.
#     *   If your code does **not** use the `Fraction()` constructor (e.g., it only uses integers, floats, or standard division `/`), the function definition `def solve():` MUST be the very first line.
# *   **1.B. Function Naming & Docstring:** The function must be named `solve`, and it should not have any args. It must begin with a docstring that has exactly two lines:
#     *   **1.B.i.** The first line must be: "Index: [Index]." using the index from the task header.
#     *   **1.B.ii.** The second line must be a succinct, one-sentence description of what the function returns (e.g., "Returns: the total cost of wages and taxes.").
# *   **1.C. Line comments:** For each solution line that is used to compute the final answer, include a comment of the form `# L1`, `# L2` and so on, which references the line number.
#     *   **1.C.i.** Such a comment must immediately be followed by a code block that precisely formalizes the corresponding solution line. More details about code blocks are provided in 1.D below.
#     *   **1.C.ii.** If a solution line does not contain any computation relevant to the final answer, then omit it completely from the function code and do NOT add a corresponding line comment.
# *   **1.D. Code blocks:** Each code block constitutes a complete formalization of its corresponding solution line. It must consist of the following:
#     *   **1.D.i. Input Variables** First, define any NEW variables needed for the computation, i.e. that will be used for the first time in the solution. Each input variable MUST be followed by a comment (`#`) in the same line. These variables fall into two categories:
#         *   "question_inputs": These are variables whose values are stated in or can be extracted from the question text (only the question text, NOT the answer text). The comment for these variables should quote or refer to the phrase in the question text from which it is extracted.
#         *   "WK_inputs": These are variables drawn from common-sense "World Knowledge" (e.g. `minutes_per_hour = 60`, `dozen = 12`). The comment for these variables MUST simply say `# WK`.
#     *   **1.D.ii. Output Variables** Second, there should be EXACTLY ONE line of code which formalizes the computation in the solution line and assigns the resulting value to a new variable (this is the "output_variable" field).
# *   **1.E. The Direct Substitution Rule:** This is the MOST IMPORTANT RULE, which ensures that the "solution_line_template" is purely identical to the original solution line except that numerical values in computations have been replaced with variable placeholders: You MUST define variables in such a way that they can be DIRECTLY SUBSTITUTED into the solution line without changing any operators or surrounding text in the line.
# *   **1.F. Final Answer:** The line that assigns the final result to the `answer` variable must be immediately preceded by a line containing only the comment `# FA`. The last line of the function must always return the `answer` variable.
#
# ## 2. "solution_line_template"
#
# *   **2.A.** The template should be EXACTLY identical to the original solution line, with the ONLY CHANGES being that every NUMERICAL value used in a computation is replaced by its corresponding `{variable_name}` placeholder. This applies to the entire content of the solution line, including the inside and outside of the calculator annotations.
# *   **2.B.** In particular, EVERY SINGLE numerical value appearing inside the calculator annotation (`<<..>>`) MUST be replaced with a `{variable_name}` placeholder.
# *   **2.C.** Note: some quantities may appear as words in the solution line (e.g. "twice as many"). Do NOT attempt to replace these with variable name placeholders.
# *   **2.D.** The Direct Substitution Rule will ensure that for correctly defined variables, it will be possible to replace the numerical values with variable name placeholders while leaving all surrounding text, symbols, and operators unchanged. Thus, in a correct "solution_line_template", the calculator annotation will not contain any numerical values, and moreover, replacing each `{variable_name}` by its value should exactly recover the original solution line, including the original calculator annotation.
#
# # Examples
#
# Given below are three examples that illustrate what a perfect formalization will look like. For each example, you are given the following:
#
# *   Input: consisting of an index, question, and solution mapping.
# *   Output: complete output, wrapped inside ```json .. ```
#
# In all examples, you will observe the following:
#
# *   **A rigid adherence to the Direct Substitution Rule (1.E)**. This is the most important principle. The `solution_line_template` must be an exact copy of the original solution line, with only computational numbers replaced by `{variable}` placeholders. Every other point follows from this rule.
#
# *   **How to formalize a rational number depends entirely on how it appears in the solution text.** It is crucial to distinguish between `floats`, `Fractions`, and the division operation (`/`).
#     *   **Use `float` for decimals:** In **Example 1**, "half" is used in the calculation as `0.5`, so it is formalized as `kevin_nice_fraction = 0.5`. In **Example 3**, "30 percent" is used as `.30`, formalized as `third_night_stolen_percent = 0.30`.
#     *   **Use `fractions.Fraction` for fractional quantities:** If "/" acts as a separator within a single fractional quantity, use `Fraction`. In **Example 1**, "three-fourths" appears as `(3/4)`, so it is formalized as `Fraction(3, 4)`. This requires the `from fractions import Fraction` import.
#     *   **Use the `/` operator for division operations:** If "/" represents the operation of dividing two values, use the standard operator. In **Example 2**, the solution `300/100` is a division operation, formalized using `/`: `total_dollars = total_cents / cents_per_dollar`. This does **not** require an import.
#
# *   **A single manifest can require multiple formalizations.** **Example 1** shows a problem using both `float` (`0.5`) and `Fraction` (`3/4`). **Example 4** shows a mix of percentages (decomposed into floats) and division (`/`). The model must adapt to each line.
#
# *   **Decomposition is sometimes needed to follow the rules.** This is a critical and advanced point. In **Example 4**, the solution for L1 is `80% * 20 votes = <<80*0.01*20=16>>16 votes`. To satisfy the Direct Substitution Rule for the calculator annotation, this must be decomposed into two variables: `taotd_discard_percent_num = 80` and `percent_factor = 0.01`.
#
# *   **Strict adherence to defining only NEW variables** in each step's `question_inputs` and `WK_inputs` lists. For instance, in **Example 3**, `initial_ducks` is defined in L1 and then simply re-used in the computation for L2 without being listed as an input again.
#
# *   Comments for `question_inputs` must cite the question text only, **NEVER** the solution text. Note how `cents_per_dollar = 100` in **Example 2** is correctly labeled `# WK` because that fact constitutes common-sense World Knowledge and is not present in the question text.
#
# ## Example 1
#
# ### Input
#
# **Index:**
# 3847
#
# **Question:**
# All people named Barry are nice, while only half of the people named Kevin are nice.  Three-fourths of people named Julie are nice, while 10% of people named Joe are nice.  If a crowd contains 24 people named Barry, 20 people named Kevin, 80 people named Julie, and 50 people named Joe, how many nice people are in the crowd?
#
# **Solution mapping:**
# {
#   "L1": "If all people named Barry are nice, and the crowd contains 24 people named Barry, then 1*24=<<24*1=24>>24 of these people are nice.",
#   "L2": "If only half of people named Kevin are nice, and the crowd contains 20 people named Kevin, then 0.5*20=<<0.5*20=10>>10 of these people are nice.",
#   "L3": "If three-fourths of people named Julie are nice, and the crowd contains 80 people named Julie, then (3/4)*80=<<3/4*80=60>>60 of these people are nice.",
#   "L4": "If 10% of people named Joe are nice, and the crowd contains 50 people named Joe, then 0.1*50=<<0.1*50=5>>5 of these people are nice.",
#   "L5": "In total, the crowd contains 24+10+60+5=<<24+10+60+5=99>>99 people who are nice."
# }
#
# ### Output
#
# ```json
# {
#   "function_code": "from fractions import Fraction\n\ndef solve():\n    \"\"\"Index: 3847.\n    Returns: the number of nice people in the crowd.\n    \"\"\"\n    # L1\n    num_barry = 24 # 24 people named Barry\n    barry_nice_fraction = 1 # All people named Barry are nice\n    nice_barry = barry_nice_fraction * num_barry\n\n    # L2\n    num_kevin = 20 # 20 people named Kevin\n    kevin_nice_fraction = 0.5 # half of the people named Kevin are nice\n    nice_kevin = kevin_nice_fraction * num_kevin\n\n    # L3\n    num_julie = 80 # 80 people named Julie\n    julie_nice_fraction = Fraction(3, 4) # Three-fourths of people named Julie are nice\n    nice_julie = julie_nice_fraction * num_julie\n\n    # L4\n    num_joe = 50 # 50 people named Joe\n    joe_nice_fraction = 0.1 # 10% of people named Joe are nice\n    nice_joe = joe_nice_fraction * num_joe\n\n    # L5\n    total_nice_people = nice_barry + nice_kevin + nice_julie + nice_joe\n\n    # FA\n    answer = total_nice_people\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["num_barry", "barry_nice_fraction"],
#       "WK_inputs": [],
#       "output_variable": "nice_barry",
#       "solution_line_template": "If all people named Barry are nice, and the crowd contains {num_barry} people named Barry, then {barry_nice_fraction}*{num_barry}=<<{num_barry}*{barry_nice_fraction}={nice_barry}>>{nice_barry} of these people are nice."
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": ["num_kevin", "kevin_nice_fraction"],
#       "WK_inputs": [],
#       "output_variable": "nice_kevin",
#       "solution_line_template": "If only half of people named Kevin are nice, and the crowd contains {num_kevin} people named Kevin, then {kevin_nice_fraction}*{num_kevin}=<<{kevin_nice_fraction}*{num_kevin}={nice_kevin}>>{nice_kevin} of these people are nice."
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["num_julie", "julie_nice_fraction"],
#       "WK_inputs": [],
#       "output_variable": "nice_julie",
#       "solution_line_template": "If three-fourths of people named Julie are nice, and the crowd contains {num_julie} people named Julie, then ({julie_nice_fraction})*{num_julie}=<<{julie_nice_fraction}*{num_julie}={nice_julie}>>{nice_julie} of these people are nice."
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": ["num_joe", "joe_nice_fraction"],
#       "WK_inputs": [],
#       "output_variable": "nice_joe",
#       "solution_line_template": "If 10% of people named Joe are nice, and the crowd contains {num_joe} people named Joe, then {joe_nice_fraction}*{num_joe}=<<{joe_nice_fraction}*{num_joe}={nice_joe}>>{nice_joe} of these people are nice."
#     },
#     {
#       "line_number": "L5",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "total_nice_people",
#       "solution_line_template": "In total, the crowd contains {nice_barry}+{nice_kevin}+{nice_julie}+{nice_joe}=<<{nice_barry}+{nice_kevin}+{nice_julie}+{nice_joe}={total_nice_people}>>{total_nice_people} people who are nice."
#     }
#   ]
# }
# ```
#
# ## Example 2
#
# ### Input
#
# **Index:**
# 4847
#
# **Question:**
# Lucy plans to purchase potato chips for a party. Ten people will be at the party, including Lucy. The potato chips cost 25 cents per pound. How much will Lucy pay (in dollars) for the potato chips if she wants each person to get 1.2 pounds?
#
# **Solution mapping:**
# {
#   "L1": "Lucy needs to purchase 10 x 1.2 = <<10*1.2=12>>12 pounds of potato chips.",
#   "L2": "So, Lucy will pay 12 x 25 = <<12*25=300>>300 cents for it.",
#   "L3": "Since there are 100 cents in $1, thus, Lucy will pay 300/100 = <<300/100=3>>3 dollars."
# }
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 4847.\n    Returns: the amount Lucy will pay in dollars.\n    \"\"\"\n    # L1\n    num_people = 10 # Ten people will be at the party\n    chips_per_person = 1.2 # each person to get 1.2 pounds\n    total_pounds = num_people * chips_per_person\n\n    # L2\n    cents_per_pound = 25 # 25 cents per pound\n    total_cents = total_pounds * cents_per_pound\n\n    # L3\n    cents_per_dollar = 100 # WK\n    total_dollars = total_cents / cents_per_dollar\n\n    # FA\n    answer = total_dollars\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["num_people", "chips_per_person"],
#       "WK_inputs": [],
#       "output_variable": "total_pounds",
#       "solution_line_template": "Lucy needs to purchase {num_people} x {chips_per_person} = <<{num_people}*{chips_per_person}={total_pounds}>>{total_pounds} pounds of potato chips."
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": ["cents_per_pound"],
#       "WK_inputs": [],
#       "output_variable": "total_cents",
#       "solution_line_template": "So, Lucy will pay {total_pounds} x {cents_per_pound} = <<{total_pounds}*{cents_per_pound}={total_cents}>>{total_cents} cents for it."
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": [],
#       "WK_inputs": ["cents_per_dollar"],
#       "output_variable": "total_dollars",
#       "solution_line_template": "Since there are 100 cents in $1, thus, Lucy will pay {total_cents}/{cents_per_dollar} = <<{total_cents}/{cents_per_dollar}={total_dollars}>>{total_dollars} dollars."
#     }
#   ]
# }
# ```
#
# ## Example 3
#
# ### Input
#
# **Index:**
# 5040
#
# **Question:**
# There are 320 ducks in a pond.  On the first night 1/4 of them get eaten by a fox.  On the second night 1/6 of the remaining ducks fly away, and on the third night 30 percent are stolen.  How many ducks remain after the three nights?
#
# **Solution mapping:**
# {
#   "L1": "First night:320(1/4)=80",
#   "L2": "320-80=<<320-80=240>>240",
#   "L3": "Second night:240(1/6)=40",
#   "L4": "240-40=<<240-40=200>>200",
#   "L5": "Third night:200(.30)=60",
#   "L6": "200-60=<<200-60=140>>140 ducks remain"
# }
#
# ### Output
#
# ```json
# {
#   "function_code": "from fractions import Fraction\n\ndef solve():\n    \"\"\"Index: 5040.\n    Returns: the number of ducks remaining after three nights.\n    \"\"\"\n    # L1\n    initial_ducks = 320 # 320 ducks in a pond\n    first_night_eaten_fraction = Fraction(1, 4) # 1/4 of them get eaten\n    first_night_eaten = initial_ducks * first_night_eaten_fraction\n\n    # L2\n    ducks_after_night1 = initial_ducks - first_night_eaten\n\n    # L3\n    second_night_flew_fraction = Fraction(1, 6) # 1/6 of the remaining ducks fly away\n    second_night_flew = ducks_after_night1 * second_night_flew_fraction\n\n    # L4\n    ducks_after_night2 = ducks_after_night1 - second_night_flew\n\n    # L5\n    third_night_stolen_percent = 0.30 # 30 percent are stolen\n    third_night_stolen = ducks_after_night2 * third_night_stolen_percent\n\n    # L6\n    ducks_after_night3 = ducks_after_night2 - third_night_stolen\n\n    # FA\n    answer = ducks_after_night3\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["initial_ducks", "first_night_eaten_fraction"],
#       "WK_inputs": [],
#       "output_variable": "first_night_eaten",
#       "solution_line_template": "First night:{initial_ducks}({first_night_eaten_fraction})={first_night_eaten}"
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "ducks_after_night1",
#       "solution_line_template": "{initial_ducks}-{first_night_eaten}=<<{initial_ducks}-{first_night_eaten}={ducks_after_night1}>>{ducks_after_night1}"
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["second_night_flew_fraction"],
#       "WK_inputs": [],
#       "output_variable": "second_night_flew",
#       "solution_line_template": "Second night:{ducks_after_night1}({second_night_flew_fraction})={second_night_flew}"
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "ducks_after_night2",
#       "solution_line_template": "{ducks_after_night1}-{second_night_flew}=<<{ducks_after_night1}-{second_night_flew}={ducks_after_night2}>>{ducks_after_night2}"
#     },
#     {
#       "line_number": "L5",
#       "question_inputs": ["third_night_stolen_percent"],
#       "WK_inputs": [],
#       "output_variable": "third_night_stolen",
#       "solution_line_template": "Third night:{ducks_after_night2}({third_night_stolen_percent})={third_night_stolen}"
#     },
#     {
#       "line_number": "L6",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "ducks_after_night3",
#       "solution_line_template": "{ducks_after_night2}-{third_night_stolen}=<<{ducks_after_night2}-{third_night_stolen}={ducks_after_night3}>>{ducks_after_night3} ducks remain"
#     }
#   ]
# }
# ```
#
# ## Example 4
#
# ### Input
#
# **Index:**
# 7037
#
# **Question:**
# At a book burning, Fran counts 20 votes for The Art of the Deal, 12 votes for Twilight, and 10 votes for Game of Thrones.  She decides to alter the results by throwing away 80% of the votes for The Art of the Deal and half the votes for Twilight. What percentage of the altered votes are for Game of Thrones?
#
# **Solution mapping:**
# {
#   "L1": "First find the total number of The Art of the Deal votes Fran throws away: 80% * 20 votes = <<80*0.01*20=16>>16 votes",
#   "L2": "Then subtract these votes from the total number of The Art of the Deal votes to find the altered number: 20 votes - 16 votes = <<20-16=4>>4 votes",
#   "L3": "Then divide the total number Twilight votes by 2 to find the altered number of votes: 12 votes / 2 = <<12/2=6>>6 votes",
#   "L4": "Then add the altered number of votes for each book to find the total altered number of votes: 6 votes + 4 votes + 10 votes = <<6+4+10=20>>20 votes",
#   "L5": "Then divide the number of votes for Game of Thrones by the total altered number of votes and multiply by 100% to express the answer as a percentage: 10 votes / 20 votes * 100% = 50%"
# }
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 7037.\n    Returns: the percentage of altered votes for Game of Thrones.\n    \"\"\"\n    # L1\n    taotd_initial_votes = 20 # 20 votes for The Art of the Deal\n    taotd_discard_percent_num = 80 # throws away 80% of the votes\n    percent_factor = 0.01 # WK\n    taotd_discarded_votes = taotd_discard_percent_num * percent_factor * taotd_initial_votes\n\n    # L2\n    taotd_altered_votes = taotd_initial_votes - taotd_discarded_votes\n\n    # L3\n    twilight_initial_votes = 12 # 12 votes for Twilight\n    twilight_discard_divisor = 2 # half the votes for Twilight\n    twilight_altered_votes = twilight_initial_votes / twilight_discard_divisor\n\n    # L4\n    got_initial_votes = 10 # 10 votes for Game of Thrones\n    total_altered_votes = twilight_altered_votes + taotd_altered_votes + got_initial_votes\n\n    # L5\n    percent_multiplier = 100 # WK\n    got_percentage = got_initial_votes / total_altered_votes * percent_multiplier\n\n    # FA\n    answer = got_percentage\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["taotd_discard_percent_num", "taotd_initial_votes"],
#       "WK_inputs": ["percent_factor"],
#       "output_variable": "taotd_discarded_votes",
#       "solution_line_template": "First find the total number of The Art of the Deal votes Fran throws away: 80% * {taotd_initial_votes} votes = <<{taotd_discard_percent_num}*{percent_factor}*{taotd_initial_votes}={taotd_discarded_votes}>>{taotd_discarded_votes} votes"
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "taotd_altered_votes",
#       "solution_line_template": "Then subtract these votes from the total number of The Art of the Deal votes to find the altered number: {taotd_initial_votes} - {taotd_discarded_votes} votes = <<{taotd_initial_votes}-{taotd_discarded_votes}={taotd_altered_votes}>>{taotd_altered_votes} votes"
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["twilight_initial_votes", "twilight_discard_divisor"],
#       "WK_inputs": [],
#       "output_variable": "twilight_altered_votes",
#       "solution_line_template": "Then divide the total number Twilight votes by {twilight_discard_divisor} to find the altered number of votes: {twilight_initial_votes} votes / {twilight_discard_divisor} = <<{twilight_initial_votes}/{twilight_discard_divisor}={twilight_altered_votes}>>{twilight_altered_votes} votes"
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": ["got_initial_votes"],
#       "WK_inputs": [],
#       "output_variable": "total_altered_votes",
#       "solution_line_template": "Then add the altered number of votes for each book to find the total altered number of votes: {twilight_altered_votes} votes + {taotd_altered_votes} votes + {got_initial_votes} votes = <<{twilight_altered_votes}+{taotd_altered_votes}+{got_initial_votes}={total_altered_votes}>>{total_altered_votes} votes"
#     },
#     {
#       "line_number": "L5",
#       "question_inputs": [],
#       "WK_inputs": ["percent_multiplier"],
#       "output_variable": "got_percentage",
#       "solution_line_template": "Then divide the number of votes for Game of Thrones by the total altered number of votes and multiply by {percent_multiplier}% to express the answer as a percentage: {got_initial_votes} votes / {total_altered_votes} votes * {percent_multiplier}% = {got_percentage}%"
#     }
#   ]
# }
# ```
#
# ## Input
#
# **Index:**:
# 1
#
# **Question:**:
# Weng earns $12 an hour for babysitting. Yesterday, she just did 50 minutes of babysitting. How much did she earn?
#
# **Solution mapping:**:
# {
#   "L1": "Weng earns 12/60 = $<<12/60=0.2>>0.2 per minute.",
#   "L2": "Working 50 minutes, she earned 0.2 x 50 = $<<0.2*50=10>>10."
# }
#
# ## Output

# %% [markdown]
# #### Cell 4: API clients, concurrency limits, models

# %%
# Imports for API clients and related functionality
import os
import openai
import google.generativeai as genai
import anthropic
import asyncio
import nest_asyncio
from openai import AsyncOpenAI
from anthropic import AsyncClient
from dotenv import load_dotenv

# This must be done once per kernel to allow asyncio to run in a Jupyter notebook..
nest_asyncio.apply()

# Load API Keys from .env file
load_dotenv()
print("Loaded environment variables from .env file.")

# Initialize Asynchronous API Clients
try:
    openai_client_async = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    anthropic_client_async = AsyncClient(api_key=os.getenv("ANTHROPIC_API_KEY"))
    genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
    print("API clients initialized successfully.")
except TypeError:
    print("API key not found for one or more services. Please check your .env file.")
    # Assign None to prevent errors in subsequent cells
    openai_client_async = None
    anthropic_client_async = None

# Define API Concurrency Limits to prevent 429 "Too Many Requests" errors.
API_CONCURRENCY_LIMITS = {
    "google": 30,    
    "anthropic": 2, 
    "openai": 2,    
}
print(f"API concurrency limits set to: {API_CONCURRENCY_LIMITS}")

MODEL_DICT = {
  "openai": "gpt-4.1",
  "google": "gemini-2.5-flash"
}

MODELS = [f"{provider}_{model}" for provider, model in MODEL_DICT.items()]
print(f"Available models: {MODELS}")
# Out:
# Loaded environment variables from .env file.
# API clients initialized successfully.
# API concurrency limits set to: {'google': 30, 'anthropic': 2, 'openai': 2}
# Available models: ['openai_gpt-4.1', 'google_gemini-2.5-flash']

# %% [markdown]
# #### Cell 5: Helper functions to avoid rate limits in API calls

# %%
import time
import random

import threading
import datetime


_log_lock = threading.Lock()
def log_event(
        level: str, 
        index: int, 
        model: str, 
        message: str
    ):
    """A thread-safe logger for concurrent operations."""
    with _log_lock:
        ts = datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="milliseconds")
        task_id = asyncio.current_task().get_name()
        print(f"{ts} [{level:^7s}] [Idx {index:<4}] [Mdl: {model:<15}] [Task {task_id:<8}] {message}")
 

async def with_api_retries(
        send_coroutine_factory,
        *,
        model_info: str,  # For informative logging
        max_attempts: int = 10,
        base_wait_seconds: int = 10
    ):
    """A wrapper to handle API retries with exponential backoff."""
    for attempt in range(max_attempts):
        try:
            return await send_coroutine_factory()
        except (openai.RateLimitError, anthropic.RateLimitError, Exception) as e:
            # Check for specific rate limit error types or a 429 status code in the error string
            if isinstance(e, (openai.RateLimitError, anthropic.RateLimitError)) or "429" in str(e):
                if attempt == max_attempts - 1:
                    print(f"❌ Final attempt failed for {model_info}. Giving up.")
                    raise
                
                # Exponential backoff with jitter
                wait_time = base_wait_seconds * (2 ** attempt) + random.uniform(0, 1)
                
                # More informative error message
                print(f"🕒 Rate limit on {model_info}. Retrying in {wait_time:.2f}s... (Attempt {attempt + 1}/{max_attempts})")
                await asyncio.sleep(wait_time)
            else:
                # If it's not a rate limit error, re-raise immediately
                raise
    return None


class RateLimitCoordinator:
    def __init__(self, refill_rate_per_sec: float, max_tokens: int):
        self.refill_rate_per_sec = refill_rate_per_sec
        self.max_tokens = float(max_tokens)
        self.tokens = self.max_tokens
        self._lock = asyncio.Lock()
        self._refill_task = None
        
    async def _refill(self):
        """The background task that refills the token bucket at 1-second intervals."""
        while True:
            await asyncio.sleep(1)
            async with self._lock:
                self.tokens = min(self.max_tokens, self.tokens + self.refill_rate_per_sec)
                if int(time.time()) % 10 == 0:
                    log_event("REFILL", -1, "Coordinator", f"Bucket budget at {int(self.tokens)} / {int(self.max_tokens)}")

    async def start(self):
        if self._refill_task is None:
            self._refill_task = asyncio.create_task(self._refill())

    async def stop(self):
        if self._refill_task:
            self._refill_task.cancel()
            self._refill_task = None

    async def get_tokens(self, index: int, model: str, tokens_needed: int):
        while True:
            async with self._lock:
                if self.tokens >= tokens_needed:
                    self.tokens -= tokens_needed
                    log_event("GRANT", index, model, f"Permission granted. Budget: {int(self.tokens + tokens_needed)} -> {int(self.tokens)}")
                    return
            
            deficit = tokens_needed - self.tokens
            wait_time = max(0.1, deficit / self.refill_rate_per_sec) # Ensure at least a small wait
            
            log_event("WAIT", index, model, f"Budget low. Needed: {tokens_needed}, Have: {int(self.tokens)}. Waiting ~{wait_time:.2f}s...")
            await asyncio.sleep(wait_time)

    async def return_tokens(self, index: int, model: str, tokens_returned: int):
        async with self._lock:
            self.tokens += tokens_returned
            log_event("RETURN", index, model, f"Tokens returned on failure. Budget restored to {int(self.tokens)}.")

    async def refund_tokens(self, index: int, model: str, tokens_refunded: int):
        """Refunds tokens to the budget after a successful call, correcting our estimate."""
        async with self._lock:
            self.tokens += tokens_refunded
            log_event("REFUND", index, model, f"Correcting estimate. Budget restored by {tokens_refunded} -> {int(self.tokens)}.")

# %% [markdown]
# #### Cell 6: Provider-specific API calling functions

# %%
import math
import copy

async def call_openai_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int,
        json_schema: dict,
        openai_max_tokens: int 
    ) -> tuple[str, dict, dict]:
    """
    Prepares a provider-specific schema and handles an API call to OpenAI.
    """
    
    openai_schema = copy.deepcopy(json_schema)

    def add_additional_properties(schema_part):
        if isinstance(schema_part, dict):
            if schema_part.get("type") == "object":
                schema_part["additionalProperties"] = False
            for value in schema_part.values():
                add_additional_properties(value)
        elif isinstance(schema_part, list):
            for item in schema_part:
                add_additional_properties(item)

    add_additional_properties(openai_schema)
    openai_schema_wrapper = {
        "name": "manifest_formalization", 
        "strict": True, 
        "schema": openai_schema
    }
    
    messages = [{"role": "system", "content": system_prompt}, 
                {"role": "user", "content": user_prompt}]
    
    model_info = f"{model} (Index {index})"
    
    response_with_headers = await with_api_retries(
        lambda: openai_client_async.chat.completions.with_raw_response.create(
            model=model, 
            messages=messages, 
            temperature=0, 
            max_tokens=openai_max_tokens, 
            response_format={"type": "json_schema", "json_schema": openai_schema_wrapper} # type: ignore
        ),
        model_info=model_info
    )
    
    response = response_with_headers.parse()
    text_response = response.choices[0].message.content
    
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage:
        usage["input_tokens"] = response.usage.prompt_tokens
        usage["output_tokens"] = response.usage.completion_tokens
        if hasattr(response.usage, 'prompt_tokens_details') and response.usage.prompt_tokens_details:
             usage["cached_tokens"] = response.usage.prompt_tokens_details.get("cached_tokens", 0)

    headers = response_with_headers.headers
    rate_limit_info = {
        "limit_requests": headers.get("x-ratelimit-limit-requests"),
        "limit_tokens": headers.get("x-ratelimit-limit-tokens"),
        "remaining_requests": headers.get("x-ratelimit-remaining-requests"),
        "remaining_tokens": headers.get("x-ratelimit-remaining-tokens"),
        "reset_requests": headers.get("x-ratelimit-reset-requests"),
        "reset_tokens": headers.get("x-ratelimit-reset-tokens"),
    }
             
    return text_response, usage, rate_limit_info


async def call_google_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int,
        json_schema: dict
    ):
    """
    Handles a Google API call with schema enforcement and a safe
    upper bound on output tokens to prevent runaway generation.
    """
    
    safety_settings = {
        "HARM_CATEGORY_HARASSMENT": "BLOCK_NONE",
        "HARM_CATEGORY_HATE_SPEECH": "BLOCK_NONE",
        "HARM_CATEGORY_SEXUALLY_EXPLICIT": "BLOCK_NONE",
        "HARM_CATEGORY_DANGEROUS_CONTENT": "BLOCK_NONE",
    }
    
    gemini = genai.GenerativeModel(
        model_name=model,
        system_instruction=system_prompt,
        safety_settings=safety_settings
    )
    
    cfg = genai.types.GenerationConfig(
        temperature=0, 
        max_output_tokens=8192, # Safe upper bound
        response_mime_type="application/json",
        response_schema=json_schema
    )
    
    model_info = f"{model} (Index {index})"

    response = await with_api_retries(
        lambda: gemini.generate_content_async(user_prompt, generation_config=cfg),
        model_info=model_info
    )

    if not response.parts:
        raise ValueError(f"Google API returned an empty response for Index {index}.")

    text_response = response.text
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage_metadata:
        usage["input_tokens"] = response.usage_metadata.prompt_token_count
        usage["output_tokens"] = response.usage_metadata.candidates_token_count
        
    return text_response, usage

# %% [markdown]
# #### Cell 7: Single API call function

# %%
import datetime
import json

async def run_single_api_call(
    provider: str,
    model: str,
    index: int,
    tier: str,
    dataset: 'datasets.Dataset',
    system_prompt: str,
    output_dir: Path,
    provider_sem: asyncio.Semaphore,
    json_schema: dict,
    coordinator: RateLimitCoordinator,
    openai_max_tokens: int,
    ):
    """
    Runs a single API call, but first checks if the output file already
    exists to avoid re-generating completed work.
    """

    output_path = output_dir / str(index) / f"{provider}_{model}.txt"
    if output_path.exists() and output_path.stat().st_size > 0:
        log_event("SKIPPED", index, model, "Output file already exists.")
        return {
            "provider": provider, "model": model, "index": index,
            "status": "Skipped", "time_s": 0,
            "input_tokens": 0, "output_tokens": 0, "cached_tokens": 0,
            "utc_completed": datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="seconds")
        }
        
    async with provider_sem:
        user_prompt = append_sample_to_user_prompt(tier=tier, index=index, dataset=dataset)

        tokens_needed = 0
        if provider == "openai":
            estimated_prompt_tokens = len(user_prompt.split()) * 1.25
            tokens_needed = int(estimated_prompt_tokens + openai_max_tokens)
            await coordinator.get_tokens(index, model, tokens_needed)

        start_time = time.time()
        status = "Failed"
        usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}

        try:
            if provider == "openai":
                text_response, usage, _ = await call_openai_async(
                    model, system_prompt, user_prompt, index, json_schema, openai_max_tokens
                )
                log_event("SUCCESS", index, model, f"Call OK. Usage: {json.dumps(usage)}")
                
                true_cost = usage['input_tokens'] + usage['output_tokens']
                refund_amount = tokens_needed - true_cost
                if refund_amount > 0:
                    await coordinator.refund_tokens(index, model, refund_amount)
                    
            elif provider == "google":
                text_response, usage = await call_google_async(
                    model, system_prompt, user_prompt, index, json_schema
                )
                log_event("SUCCESS", index, model, f"Call OK. Usage: {json.dumps(usage)}")
            
            status = "Success"

        except Exception as e:
            log_event("ERROR", index, model, f"{type(e).__name__}: {str(e).splitlines()[0]}")
            text_response = f"--- ERROR ---\nIndex: {index}, Model: {model}\n{type(e).__name__}: {e}"
            
        finally:
            if status == "Failed" and provider == "openai" and tokens_needed > 0:
                await coordinator.return_tokens(index, model, tokens_needed)

        output_path.parent.mkdir(parents=True, exist_ok=True)
        output_path.write_text(text_response, encoding='utf-8')
        
        elapsed = time.time() - start_time
        
        return {
            "provider": provider, "model": model, "index": index,
            "status": status, "time_s": round(elapsed, 2),
            "input_tokens": usage["input_tokens"], "output_tokens": usage["output_tokens"],
            "cached_tokens": usage["cached_tokens"],
            "utc_completed": datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="seconds")
        }

# %% [markdown]
# #### Cell 8: Main manifest generation functions

# %%
from tqdm.notebook import tqdm
import pandas as pd

async def generate_manifests_parallel_fixed(
    indices_to_generate: list[int],
    tier: str = CURRENT_TIER,
    dataset: 'datasets.Dataset' = GSM8K_TRAIN,
    model_dict: dict[str, str] = MODEL_DICT,
    system_prompt: str = SYSTEM_PROMPT,
    concurrency_limits: dict[str, int] = API_CONCURRENCY_LIMITS,
    json_schema: dict = BASE_MANIFEST_SCHEMA,
    openai_max_tokens: int = 4000
    ):
    """
    Fully parallel version with a robust token bucket coordinator for OpenAI.
    """
    print("--- Starting Manifest Generation (Token Bucket) ---")
    start_time = time.time()

    openai_coordinator = RateLimitCoordinator(refill_rate_per_sec=800, max_tokens=30000)
    await openai_coordinator.start()
    
    provider_semaphores = {prov: asyncio.Semaphore(limit) for prov, limit in concurrency_limits.items()}
    output_dir = TIER_OUTPUT_DIRS[tier]
    
    all_tasks = []
    for index in indices_to_generate:
        for provider, model in model_dict.items():
            task = asyncio.create_task(
                run_single_api_call(
                    provider=provider, model=model, index=index,
                    tier=tier, dataset=dataset, system_prompt=system_prompt,
                    output_dir=output_dir, provider_sem=provider_semaphores[provider],
                    json_schema=json_schema,
                    coordinator=openai_coordinator,
                    openai_max_tokens=openai_max_tokens
                )
            )
            all_tasks.append(task)
    
    print(f"Created {len(all_tasks)} total API call tasks")
    
    results = []
    try:
        with tqdm(total=len(all_tasks), desc="API Calls") as pbar:
            for task in asyncio.as_completed(all_tasks):
                result = await task
                results.append(result)
                pbar.update(1)
    finally:
        await openai_coordinator.stop()
    
    df = pd.DataFrame(results)
    run_ts = datetime.datetime.now(datetime.timezone.utc).strftime("%Y%m%d_%H%M%S")
    csv_path = output_dir / f"generation_performance_{run_ts}.csv"
    df.to_csv(csv_path, index=False)
    
    end_time = time.time()
    print(f"\n--- Manifest Generation Complete ---")
    print(f"Processed {len(indices_to_generate)} indices in {end_time - start_time:.2f} seconds.")
    print(f"Performance log saved to: {csv_path}")
    
    success_count = len(df[df['status'] == 'Success'])
    total_calls = len(df)
    if total_calls > 0:
      print(f"Success rate: {success_count}/{total_calls} ({100*success_count/total_calls:.1f}%)")
    
    return df

# %% [markdown]
# #### Cell 9: Running the main manifest generation function

# %%
LOWER_LIMIT = 0
UPPER_LIMIT = 3000
INDICES_TO_GENERATE = [idx for idx in CURRENT_INDICES if idx <= UPPER_LIMIT and idx >= LOWER_LIMIT]

print(f"Starting generation for {len(INDICES_TO_GENERATE)} indices in {CURRENT_TIER} between {LOWER_LIMIT} and {UPPER_LIMIT}.")

perf_df = await generate_manifests_parallel_fixed(indices_to_generate=INDICES_TO_GENERATE)

print("\n--- Generation Performance Summary ---")
perf_df.head()
# Out:
# Starting generation for 185 indices in tier4 between 0 and 3000.
# --- Starting Manifest Generation (Token Bucket) ---
# Created 370 total API call tasks
# API Calls:   0%|          | 0/370 [00:00<?, ?it/s]
# 2025-07-10T20:13:58.545+00:00 [ GRANT ] [Idx 1   ] [Mdl: gpt-4.1        ] [Task Task-4  ] Permission granted. Budget: 30000 -> 22497
# 2025-07-10T20:13:58.553+00:00 [ GRANT ] [Idx 37  ] [Mdl: gpt-4.1        ] [Task Task-6  ] Permission granted. Budget: 22497 -> 14885
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752178438.564921 12870979 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# 2025-07-10T20:14:00.547+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 16485 / 30000
# 2025-07-10T20:14:03.635+00:00 [SUCCESS] [Idx 1   ] [Mdl: gemini-2.5-flash] [Task Task-5  ] Call OK. Usage: {"input_tokens": 7105, "output_tokens": 393, "cached_tokens": 0}
# 2025-07-10T20:14:04.044+00:00 [SUCCESS] [Idx 612 ] [Mdl: gemini-2.5-flash] [Task Task-59 ] Call OK. Usage: {"input_tokens": 7155, "output_tokens": 497, "cached_tokens": 0}
# 2025-07-10T20:14:04.217+00:00 [SUCCESS] [Idx 506 ] [Mdl: gemini-2.5-flash] [Task Task-45 ] Call OK. Usage: {"input_tokens": 7161, "output_tokens": 504, "cached_tokens": 0}
# 2025-07-10T20:14:04.820+00:00 [SUCCESS] [Idx 1   ] [Mdl: gpt-4.1        ] [Task Task-4  ] Call OK. Usage: {"input_tokens": 6359, "output_tokens": 336, "cached_tokens": 6144}
# 2025-07-10T20:14:04.820+00:00 [REFUND ] [Idx 1   ] [Mdl: gpt-4.1        ] [Task Task-4  ] Correcting estimate. Budget restored by 808 -> 20493.
# 2025-07-10T20:14:04.822+00:00 [ GRANT ] [Idx 64  ] [Mdl: gpt-4.1        ] [Task Task-8  ] Permission granted. Budget: 20493 -> 12927
# 2025-07-10T20:14:05.171+00:00 [SUCCESS] [Idx 340 ] [Mdl: gemini-2.5-flash] [Task Task-31 ] Call OK. Usage: {"input_tokens": 7181, "output_tokens": 738, "cached_tokens": 0}
# 2025-07-10T20:14:05.546+00:00 [SUCCESS] [Idx 460 ] [Mdl: gemini-2.5-flash] [Task Task-41 ] Call OK. Usage: {"input_tokens": 7263, "output_tokens": 634, "cached_tokens": 0}
# 2025-07-10T20:14:05.839+00:00 [SUCCESS] [Idx 437 ] [Mdl: gemini-2.5-flash] [Task Task-37 ] Call OK. Usage: {"input_tokens": 7222, "output_tokens": 805, "cached_tokens": 0}
# 2025-07-10T20:14:05.892+00:00 [SUCCESS] [Idx 552 ] [Mdl: gemini-2.5-flash] [Task Task-49 ] Call OK. Usage: {"input_tokens": 7184, "output_tokens": 567, "cached_tokens": 0}
# 2025-07-10T20:14:06.911+00:00 [SUCCESS] [Idx 626 ] [Mdl: gemini-2.5-flash] [Task Task-63 ] Call OK. Usage: {"input_tokens": 7174, "output_tokens": 598, "cached_tokens": 0}
# 2025-07-10T20:14:06.912+00:00 [SUCCESS] [Idx 37  ] [Mdl: gemini-2.5-flash] [Task Task-7  ] Call OK. Usage: {"input_tokens": 7291, "output_tokens": 1021, "cached_tokens": 0}
# 2025-07-10T20:14:07.041+00:00 [SUCCESS] [Idx 64  ] [Mdl: gemini-2.5-flash] [Task Task-9  ] Call OK. Usage: {"input_tokens": 7256, "output_tokens": 1058, "cached_tokens": 0}
# 2025-07-10T20:14:07.144+00:00 [SUCCESS] [Idx 601 ] [Mdl: gemini-2.5-flash] [Task Task-57 ] Call OK. Usage: {"input_tokens": 7254, "output_tokens": 773, "cached_tokens": 0}
# 2025-07-10T20:14:07.178+00:00 [SUCCESS] [Idx 267 ] [Mdl: gemini-2.5-flash] [Task Task-23 ] Call OK. Usage: {"input_tokens": 7290, "output_tokens": 977, "cached_tokens": 0}
# 2025-07-10T20:14:07.408+00:00 [SUCCESS] [Idx 470 ] [Mdl: gemini-2.5-flash] [Task Task-43 ] Call OK. Usage: {"input_tokens": 7323, "output_tokens": 934, "cached_tokens": 0}
# 2025-07-10T20:14:07.935+00:00 [SUCCESS] [Idx 37  ] [Mdl: gpt-4.1        ] [Task Task-6  ] Call OK. Usage: {"input_tokens": 6534, "output_tokens": 790, "cached_tokens": 0}
# 2025-07-10T20:14:07.935+00:00 [REFUND ] [Idx 37  ] [Mdl: gpt-4.1        ] [Task Task-6  ] Correcting estimate. Budget restored by 288 -> 15615.
# 2025-07-10T20:14:07.936+00:00 [ GRANT ] [Idx 123 ] [Mdl: gpt-4.1        ] [Task Task-10 ] Permission granted. Budget: 15615 -> 8025
# 2025-07-10T20:14:07.939+00:00 [SUCCESS] [Idx 140 ] [Mdl: gemini-2.5-flash] [Task Task-13 ] Call OK. Usage: {"input_tokens": 7335, "output_tokens": 1196, "cached_tokens": 0}
# 2025-07-10T20:14:07.941+00:00 [SUCCESS] [Idx 525 ] [Mdl: gemini-2.5-flash] [Task Task-47 ] Call OK. Usage: {"input_tokens": 7310, "output_tokens": 918, "cached_tokens": 0}
# 2025-07-10T20:14:07.980+00:00 [SUCCESS] [Idx 583 ] [Mdl: gemini-2.5-flash] [Task Task-55 ] Call OK. Usage: {"input_tokens": 7345, "output_tokens": 1025, "cached_tokens": 0}
# 2025-07-10T20:14:08.169+00:00 [SUCCESS] [Idx 234 ] [Mdl: gemini-2.5-flash] [Task Task-19 ] Call OK. Usage: {"input_tokens": 7299, "output_tokens": 733, "cached_tokens": 0}
# 2025-07-10T20:14:09.369+00:00 [SUCCESS] [Idx 562 ] [Mdl: gemini-2.5-flash] [Task Task-53 ] Call OK. Usage: {"input_tokens": 7285, "output_tokens": 1253, "cached_tokens": 0}
# 2025-07-10T20:14:09.370+00:00 [SUCCESS] [Idx 679 ] [Mdl: gemini-2.5-flash] [Task Task-67 ] Call OK. Usage: {"input_tokens": 7102, "output_tokens": 438, "cached_tokens": 0}
# 2025-07-10T20:14:09.567+00:00 [SUCCESS] [Idx 323 ] [Mdl: gemini-2.5-flash] [Task Task-27 ] Call OK. Usage: {"input_tokens": 7230, "output_tokens": 748, "cached_tokens": 0}
# 2025-07-10T20:14:10.188+00:00 [SUCCESS] [Idx 370 ] [Mdl: gemini-2.5-flash] [Task Task-35 ] Call OK. Usage: {"input_tokens": 7309, "output_tokens": 1054, "cached_tokens": 0}
# 2025-07-10T20:14:10.190+00:00 [SUCCESS] [Idx 672 ] [Mdl: gemini-2.5-flash] [Task Task-65 ] Call OK. Usage: {"input_tokens": 7208, "output_tokens": 655, "cached_tokens": 0}
# 2025-07-10T20:14:10.520+00:00 [SUCCESS] [Idx 123 ] [Mdl: gemini-2.5-flash] [Task Task-11 ] Call OK. Usage: {"input_tokens": 7217, "output_tokens": 706, "cached_tokens": 0}
# 2025-07-10T20:14:10.557+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 10425 / 30000
# 2025-07-10T20:14:10.634+00:00 [SUCCESS] [Idx 714 ] [Mdl: gemini-2.5-flash] [Task Task-71 ] Call OK. Usage: {"input_tokens": 7127, "output_tokens": 423, "cached_tokens": 0}
# 2025-07-10T20:14:11.177+00:00 [SUCCESS] [Idx 717 ] [Mdl: gemini-2.5-flash] [Task Task-73 ] Call OK. Usage: {"input_tokens": 7129, "output_tokens": 619, "cached_tokens": 0}
# 2025-07-10T20:14:12.645+00:00 [SUCCESS] [Idx 804 ] [Mdl: gemini-2.5-flash] [Task Task-83 ] Call OK. Usage: {"input_tokens": 7138, "output_tokens": 515, "cached_tokens": 0}
# 2025-07-10T20:14:12.761+00:00 [SUCCESS] [Idx 722 ] [Mdl: gemini-2.5-flash] [Task Task-75 ] Call OK. Usage: {"input_tokens": 7181, "output_tokens": 773, "cached_tokens": 0}
# 2025-07-10T20:14:12.798+00:00 [SUCCESS] [Idx 894 ] [Mdl: gemini-2.5-flash] [Task Task-95 ] Call OK. Usage: {"input_tokens": 7081, "output_tokens": 389, "cached_tokens": 0}
# 2025-07-10T20:14:13.669+00:00 [SUCCESS] [Idx 343 ] [Mdl: gemini-2.5-flash] [Task Task-33 ] Call OK. Usage: {"input_tokens": 7241, "output_tokens": 896, "cached_tokens": 0}
# 2025-07-10T20:14:13.670+00:00 [SUCCESS] [Idx 820 ] [Mdl: gemini-2.5-flash] [Task Task-87 ] Call OK. Usage: {"input_tokens": 7186, "output_tokens": 677, "cached_tokens": 0}
# 2025-07-10T20:14:13.767+00:00 [SUCCESS] [Idx 759 ] [Mdl: gemini-2.5-flash] [Task Task-77 ] Call OK. Usage: {"input_tokens": 7321, "output_tokens": 1127, "cached_tokens": 0}
# 2025-07-10T20:14:14.900+00:00 [SUCCESS] [Idx 880 ] [Mdl: gemini-2.5-flash] [Task Task-91 ] Call OK. Usage: {"input_tokens": 7174, "output_tokens": 712, "cached_tokens": 0}
# 2025-07-10T20:14:15.078+00:00 [SUCCESS] [Idx 64  ] [Mdl: gpt-4.1        ] [Task Task-8  ] Call OK. Usage: {"input_tokens": 6475, "output_tokens": 804, "cached_tokens": 6144}
# 2025-07-10T20:14:15.078+00:00 [REFUND ] [Idx 64  ] [Mdl: gpt-4.1        ] [Task Task-8  ] Correcting estimate. Budget restored by 287 -> 13912.
# 2025-07-10T20:14:15.080+00:00 [ GRANT ] [Idx 140 ] [Mdl: gpt-4.1        ] [Task Task-12 ] Permission granted. Budget: 13912 -> 6254
# 2025-07-10T20:14:15.334+00:00 [SUCCESS] [Idx 762 ] [Mdl: gemini-2.5-flash] [Task Task-81 ] Call OK. Usage: {"input_tokens": 7226, "output_tokens": 902, "cached_tokens": 0}
# 2025-07-10T20:14:15.519+00:00 [SUCCESS] [Idx 978 ] [Mdl: gemini-2.5-flash] [Task Task-107] Call OK. Usage: {"input_tokens": 7124, "output_tokens": 492, "cached_tokens": 0}
# 2025-07-10T20:14:15.681+00:00 [SUCCESS] [Idx 942 ] [Mdl: gemini-2.5-flash] [Task Task-101] Call OK. Usage: {"input_tokens": 7155, "output_tokens": 595, "cached_tokens": 0}
# 2025-07-10T20:14:16.126+00:00 [SUCCESS] [Idx 998 ] [Mdl: gemini-2.5-flash] [Task Task-109] Call OK. Usage: {"input_tokens": 7212, "output_tokens": 480, "cached_tokens": 0}
# 2025-07-10T20:14:16.317+00:00 [SUCCESS] [Idx 698 ] [Mdl: gemini-2.5-flash] [Task Task-69 ] Call OK. Usage: {"input_tokens": 7130, "output_tokens": 435, "cached_tokens": 0}
# 2025-07-10T20:14:17.766+00:00 [SUCCESS] [Idx 943 ] [Mdl: gemini-2.5-flash] [Task Task-103] Call OK. Usage: {"input_tokens": 7205, "output_tokens": 795, "cached_tokens": 0}
# 2025-07-10T20:14:17.951+00:00 [SUCCESS] [Idx 1015] [Mdl: gemini-2.5-flash] [Task Task-115] Call OK. Usage: {"input_tokens": 7153, "output_tokens": 583, "cached_tokens": 0}
# 2025-07-10T20:14:18.404+00:00 [SUCCESS] [Idx 1057] [Mdl: gemini-2.5-flash] [Task Task-117] Call OK. Usage: {"input_tokens": 7122, "output_tokens": 556, "cached_tokens": 0}
# 2025-07-10T20:14:18.539+00:00 [SUCCESS] [Idx 946 ] [Mdl: gemini-2.5-flash] [Task Task-105] Call OK. Usage: {"input_tokens": 7259, "output_tokens": 940, "cached_tokens": 0}
# 2025-07-10T20:14:18.653+00:00 [SUCCESS] [Idx 1010] [Mdl: gemini-2.5-flash] [Task Task-113] Call OK. Usage: {"input_tokens": 7232, "output_tokens": 711, "cached_tokens": 0}
# 2025-07-10T20:14:18.880+00:00 [SUCCESS] [Idx 1009] [Mdl: gemini-2.5-flash] [Task Task-111] Call OK. Usage: {"input_tokens": 7197, "output_tokens": 820, "cached_tokens": 0}
# 2025-07-10T20:14:19.200+00:00 [SUCCESS] [Idx 817 ] [Mdl: gemini-2.5-flash] [Task Task-85 ] Call OK. Usage: {"input_tokens": 7320, "output_tokens": 1246, "cached_tokens": 0}
# 2025-07-10T20:14:20.224+00:00 [SUCCESS] [Idx 554 ] [Mdl: gemini-2.5-flash] [Task Task-51 ] Call OK. Usage: {"input_tokens": 7208, "output_tokens": 772, "cached_tokens": 0}
# 2025-07-10T20:14:20.225+00:00 [SUCCESS] [Idx 1115] [Mdl: gemini-2.5-flash] [Task Task-125] Call OK. Usage: {"input_tokens": 7201, "output_tokens": 727, "cached_tokens": 0}
# 2025-07-10T20:14:20.568+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 11054 / 30000
# 2025-07-10T20:14:20.685+00:00 [SUCCESS] [Idx 1180] [Mdl: gemini-2.5-flash] [Task Task-135] Call OK. Usage: {"input_tokens": 7169, "output_tokens": 454, "cached_tokens": 0}
# 2025-07-10T20:14:20.718+00:00 [SUCCESS] [Idx 123 ] [Mdl: gpt-4.1        ] [Task Task-10 ] Call OK. Usage: {"input_tokens": 6452, "output_tokens": 566, "cached_tokens": 6144}
# 2025-07-10T20:14:20.718+00:00 [REFUND ] [Idx 123 ] [Mdl: gpt-4.1        ] [Task Task-10 ] Correcting estimate. Budget restored by 572 -> 11626.
# 2025-07-10T20:14:20.719+00:00 [ GRANT ] [Idx 193 ] [Mdl: gpt-4.1        ] [Task Task-14 ] Permission granted. Budget: 11626 -> 4001
# 2025-07-10T20:14:21.451+00:00 [SUCCESS] [Idx 334 ] [Mdl: gemini-2.5-flash] [Task Task-29 ] Call OK. Usage: {"input_tokens": 7411, "output_tokens": 1435, "cached_tokens": 0}
# 2025-07-10T20:14:22.136+00:00 [SUCCESS] [Idx 886 ] [Mdl: gemini-2.5-flash] [Task Task-93 ] Call OK. Usage: {"input_tokens": 7284, "output_tokens": 1045, "cached_tokens": 0}
# 2025-07-10T20:14:22.138+00:00 [SUCCESS] [Idx 1091] [Mdl: gemini-2.5-flash] [Task Task-121] Call OK. Usage: {"input_tokens": 7235, "output_tokens": 649, "cached_tokens": 0}
# 2025-07-10T20:14:22.285+00:00 [SUCCESS] [Idx 1133] [Mdl: gemini-2.5-flash] [Task Task-129] Call OK. Usage: {"input_tokens": 7251, "output_tokens": 919, "cached_tokens": 0}
# 2025-07-10T20:14:22.455+00:00 [SUCCESS] [Idx 193 ] [Mdl: gemini-2.5-flash] [Task Task-15 ] Call OK. Usage: {"input_tokens": 7213, "output_tokens": 397, "cached_tokens": 0}
# 2025-07-10T20:14:22.887+00:00 [SUCCESS] [Idx 1111] [Mdl: gemini-2.5-flash] [Task Task-123] Call OK. Usage: {"input_tokens": 7274, "output_tokens": 872, "cached_tokens": 0}
# 2025-07-10T20:14:23.700+00:00 [SUCCESS] [Idx 904 ] [Mdl: gemini-2.5-flash] [Task Task-97 ] Call OK. Usage: {"input_tokens": 7197, "output_tokens": 733, "cached_tokens": 0}
# 2025-07-10T20:14:23.701+00:00 [SUCCESS] [Idx 1209] [Mdl: gemini-2.5-flash] [Task Task-141] Call OK. Usage: {"input_tokens": 7139, "output_tokens": 569, "cached_tokens": 0}
# 2025-07-10T20:14:24.116+00:00 [SUCCESS] [Idx 1262] [Mdl: gemini-2.5-flash] [Task Task-147] Call OK. Usage: {"input_tokens": 7123, "output_tokens": 586, "cached_tokens": 0}
# 2025-07-10T20:14:24.729+00:00 [SUCCESS] [Idx 1240] [Mdl: gemini-2.5-flash] [Task Task-143] Call OK. Usage: {"input_tokens": 7258, "output_tokens": 693, "cached_tokens": 0}
# 2025-07-10T20:14:24.732+00:00 [SUCCESS] [Idx 623 ] [Mdl: gemini-2.5-flash] [Task Task-61 ] Call OK. Usage: {"input_tokens": 7188, "output_tokens": 817, "cached_tokens": 0}
# 2025-07-10T20:14:25.352+00:00 [SUCCESS] [Idx 1146] [Mdl: gemini-2.5-flash] [Task Task-131] Call OK. Usage: {"input_tokens": 7351, "output_tokens": 1161, "cached_tokens": 0}
# 2025-07-10T20:14:26.406+00:00 [SUCCESS] [Idx 1153] [Mdl: gemini-2.5-flash] [Task Task-133] Call OK. Usage: {"input_tokens": 7283, "output_tokens": 1071, "cached_tokens": 0}
# 2025-07-10T20:14:26.559+00:00 [SUCCESS] [Idx 1365] [Mdl: gemini-2.5-flash] [Task Task-155] Call OK. Usage: {"input_tokens": 7249, "output_tokens": 750, "cached_tokens": 0}
# 2025-07-10T20:14:26.702+00:00 [SUCCESS] [Idx 193 ] [Mdl: gpt-4.1        ] [Task Task-14 ] Call OK. Usage: {"input_tokens": 6473, "output_tokens": 440, "cached_tokens": 6144}
# 2025-07-10T20:14:26.702+00:00 [REFUND ] [Idx 193 ] [Mdl: gpt-4.1        ] [Task Task-14 ] Correcting estimate. Budget restored by 712 -> 9513.
# 2025-07-10T20:14:26.704+00:00 [ GRANT ] [Idx 198 ] [Mdl: gpt-4.1        ] [Task Task-16 ] Permission granted. Budget: 9513 -> 1923
# 2025-07-10T20:14:26.739+00:00 [SUCCESS] [Idx 1273] [Mdl: gemini-2.5-flash] [Task Task-149] Call OK. Usage: {"input_tokens": 7189, "output_tokens": 725, "cached_tokens": 0}
# 2025-07-10T20:14:26.957+00:00 [SUCCESS] [Idx 1193] [Mdl: gemini-2.5-flash] [Task Task-139] Call OK. Usage: {"input_tokens": 7287, "output_tokens": 1095, "cached_tokens": 0}
# 2025-07-10T20:14:27.303+00:00 [SUCCESS] [Idx 929 ] [Mdl: gemini-2.5-flash] [Task Task-99 ] Call OK. Usage: {"input_tokens": 7251, "output_tokens": 931, "cached_tokens": 0}
# 2025-07-10T20:14:27.458+00:00 [SUCCESS] [Idx 1317] [Mdl: gemini-2.5-flash] [Task Task-151] Call OK. Usage: {"input_tokens": 7221, "output_tokens": 813, "cached_tokens": 0}
# 2025-07-10T20:14:27.490+00:00 [SUCCESS] [Idx 1120] [Mdl: gemini-2.5-flash] [Task Task-127] Call OK. Usage: {"input_tokens": 7456, "output_tokens": 1546, "cached_tokens": 0}
# 2025-07-10T20:14:27.761+00:00 [SUCCESS] [Idx 1371] [Mdl: gemini-2.5-flash] [Task Task-157] Call OK. Usage: {"input_tokens": 7213, "output_tokens": 640, "cached_tokens": 0}
# 2025-07-10T20:14:28.212+00:00 [SUCCESS] [Idx 303 ] [Mdl: gemini-2.5-flash] [Task Task-25 ] Call OK. Usage: {"input_tokens": 7334, "output_tokens": 1520, "cached_tokens": 0}
# 2025-07-10T20:14:28.213+00:00 [SUCCESS] [Idx 1242] [Mdl: gemini-2.5-flash] [Task Task-145] Call OK. Usage: {"input_tokens": 7379, "output_tokens": 1077, "cached_tokens": 0}
# 2025-07-10T20:14:28.333+00:00 [SUCCESS] [Idx 1187] [Mdl: gemini-2.5-flash] [Task Task-137] Call OK. Usage: {"input_tokens": 7358, "output_tokens": 1177, "cached_tokens": 0}
# 2025-07-10T20:14:29.256+00:00 [SUCCESS] [Idx 1510] [Mdl: gemini-2.5-flash] [Task Task-169] Call OK. Usage: {"input_tokens": 7156, "output_tokens": 590, "cached_tokens": 0}
# 2025-07-10T20:14:29.409+00:00 [SUCCESS] [Idx 1319] [Mdl: gemini-2.5-flash] [Task Task-153] Call OK. Usage: {"input_tokens": 7342, "output_tokens": 1073, "cached_tokens": 0}
# 2025-07-10T20:14:30.581+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 5123 / 30000
# 2025-07-10T20:14:30.781+00:00 [SUCCESS] [Idx 1641] [Mdl: gemini-2.5-flash] [Task Task-183] Call OK. Usage: {"input_tokens": 7100, "output_tokens": 417, "cached_tokens": 0}
# 2025-07-10T20:14:31.489+00:00 [SUCCESS] [Idx 1508] [Mdl: gemini-2.5-flash] [Task Task-167] Call OK. Usage: {"input_tokens": 7296, "output_tokens": 1003, "cached_tokens": 0}
# 2025-07-10T20:14:31.605+00:00 [SUCCESS] [Idx 867 ] [Mdl: gemini-2.5-flash] [Task Task-89 ] Call OK. Usage: {"input_tokens": 7197, "output_tokens": 741, "cached_tokens": 0}
# 2025-07-10T20:14:31.738+00:00 [SUCCESS] [Idx 1386] [Mdl: gemini-2.5-flash] [Task Task-159] Call OK. Usage: {"input_tokens": 7370, "output_tokens": 1364, "cached_tokens": 0}
# 2025-07-10T20:14:31.823+00:00 [SUCCESS] [Idx 1498] [Mdl: gemini-2.5-flash] [Task Task-165] Call OK. Usage: {"input_tokens": 7339, "output_tokens": 891, "cached_tokens": 0}
# 2025-07-10T20:14:31.929+00:00 [SUCCESS] [Idx 1636] [Mdl: gemini-2.5-flash] [Task Task-181] Call OK. Usage: {"input_tokens": 7186, "output_tokens": 775, "cached_tokens": 0}
# 2025-07-10T20:14:31.977+00:00 [SUCCESS] [Idx 1681] [Mdl: gemini-2.5-flash] [Task Task-191] Call OK. Usage: {"input_tokens": 7150, "output_tokens": 439, "cached_tokens": 0}
# 2025-07-10T20:14:32.626+00:00 [SUCCESS] [Idx 1653] [Mdl: gemini-2.5-flash] [Task Task-185] Call OK. Usage: {"input_tokens": 7145, "output_tokens": 565, "cached_tokens": 0}
# 2025-07-10T20:14:32.753+00:00 [SUCCESS] [Idx 1656] [Mdl: gemini-2.5-flash] [Task Task-187] Call OK. Usage: {"input_tokens": 7243, "output_tokens": 663, "cached_tokens": 0}
# 2025-07-10T20:14:33.276+00:00 [SUCCESS] [Idx 1613] [Mdl: gemini-2.5-flash] [Task Task-179] Call OK. Usage: {"input_tokens": 7296, "output_tokens": 1163, "cached_tokens": 0}
# 2025-07-10T20:14:33.740+00:00 [SUCCESS] [Idx 1455] [Mdl: gemini-2.5-flash] [Task Task-161] Call OK. Usage: {"input_tokens": 7279, "output_tokens": 1161, "cached_tokens": 0}
# 2025-07-10T20:14:34.295+00:00 [SUCCESS] [Idx 1668] [Mdl: gemini-2.5-flash] [Task Task-189] Call OK. Usage: {"input_tokens": 7133, "output_tokens": 464, "cached_tokens": 0}
# 2025-07-10T20:14:34.315+00:00 [SUCCESS] [Idx 1743] [Mdl: gemini-2.5-flash] [Task Task-201] Call OK. Usage: {"input_tokens": 7220, "output_tokens": 678, "cached_tokens": 0}
# 2025-07-10T20:14:34.478+00:00 [SUCCESS] [Idx 1476] [Mdl: gemini-2.5-flash] [Task Task-163] Call OK. Usage: {"input_tokens": 7311, "output_tokens": 1028, "cached_tokens": 0}
# 2025-07-10T20:14:34.765+00:00 [SUCCESS] [Idx 1576] [Mdl: gemini-2.5-flash] [Task Task-173] Call OK. Usage: {"input_tokens": 7319, "output_tokens": 913, "cached_tokens": 0}
# 2025-07-10T20:14:34.766+00:00 [ ERROR ] [Idx 442 ] [Mdl: gemini-2.5-flash] [Task Task-39 ] ValueError: Google API returned an empty response for Index 442.
# 2025-07-10T20:14:35.174+00:00 [ ERROR ] [Idx 198 ] [Mdl: gemini-2.5-flash] [Task Task-17 ] ValueError: Google API returned an empty response for Index 198.
# 2025-07-10T20:14:35.197+00:00 [ ERROR ] [Idx 261 ] [Mdl: gemini-2.5-flash] [Task Task-21 ] ValueError: Google API returned an empty response for Index 261.
# 2025-07-10T20:14:36.199+00:00 [SUCCESS] [Idx 1549] [Mdl: gemini-2.5-flash] [Task Task-171] Call OK. Usage: {"input_tokens": 7282, "output_tokens": 1008, "cached_tokens": 0}
# 2025-07-10T20:14:36.201+00:00 [SUCCESS] [Idx 1793] [Mdl: gemini-2.5-flash] [Task Task-211] Call OK. Usage: {"input_tokens": 7163, "output_tokens": 440, "cached_tokens": 0}
# 2025-07-10T20:14:36.407+00:00 [SUCCESS] [Idx 1600] [Mdl: gemini-2.5-flash] [Task Task-177] Call OK. Usage: {"input_tokens": 7220, "output_tokens": 712, "cached_tokens": 0}
# 2025-07-10T20:14:36.813+00:00 [SUCCESS] [Idx 760 ] [Mdl: gemini-2.5-flash] [Task Task-79 ] Call OK. Usage: {"input_tokens": 7280, "output_tokens": 1209, "cached_tokens": 0}
# 2025-07-10T20:14:36.814+00:00 [SUCCESS] [Idx 1727] [Mdl: gemini-2.5-flash] [Task Task-197] Call OK. Usage: {"input_tokens": 7222, "output_tokens": 917, "cached_tokens": 0}
# 2025-07-10T20:14:36.814+00:00 [SUCCESS] [Idx 1753] [Mdl: gemini-2.5-flash] [Task Task-205] Call OK. Usage: {"input_tokens": 7258, "output_tokens": 828, "cached_tokens": 0}
# 2025-07-10T20:14:36.822+00:00 [SUCCESS] [Idx 140 ] [Mdl: gpt-4.1        ] [Task Task-12 ] Call OK. Usage: {"input_tokens": 6542, "output_tokens": 985, "cached_tokens": 6144}
# 2025-07-10T20:14:36.822+00:00 [REFUND ] [Idx 140 ] [Mdl: gpt-4.1        ] [Task Task-12 ] Correcting estimate. Budget restored by 131 -> 10054.
# 2025-07-10T20:14:36.823+00:00 [ GRANT ] [Idx 234 ] [Mdl: gpt-4.1        ] [Task Task-18 ] Permission granted. Budget: 10054 -> 2418
# 2025-07-10T20:14:37.633+00:00 [SUCCESS] [Idx 1744] [Mdl: gemini-2.5-flash] [Task Task-203] Call OK. Usage: {"input_tokens": 7243, "output_tokens": 914, "cached_tokens": 0}
# 2025-07-10T20:14:38.452+00:00 [SUCCESS] [Idx 1590] [Mdl: gemini-2.5-flash] [Task Task-175] Call OK. Usage: {"input_tokens": 7213, "output_tokens": 1014, "cached_tokens": 0}
# 2025-07-10T20:14:38.454+00:00 [SUCCESS] [Idx 1735] [Mdl: gemini-2.5-flash] [Task Task-199] Call OK. Usage: {"input_tokens": 7291, "output_tokens": 1190, "cached_tokens": 0}
# 2025-07-10T20:14:39.193+00:00 [SUCCESS] [Idx 1762] [Mdl: gemini-2.5-flash] [Task Task-209] Call OK. Usage: {"input_tokens": 7260, "output_tokens": 833, "cached_tokens": 0}
# 2025-07-10T20:14:39.452+00:00 [SUCCESS] [Idx 1860] [Mdl: gemini-2.5-flash] [Task Task-225] Call OK. Usage: {"input_tokens": 7205, "output_tokens": 773, "cached_tokens": 0}
# 2025-07-10T20:14:39.620+00:00 [SUCCESS] [Idx 1875] [Mdl: gemini-2.5-flash] [Task Task-227] Call OK. Usage: {"input_tokens": 7187, "output_tokens": 713, "cached_tokens": 0}
# 2025-07-10T20:14:40.502+00:00 [SUCCESS] [Idx 1757] [Mdl: gemini-2.5-flash] [Task Task-207] Call OK. Usage: {"input_tokens": 7236, "output_tokens": 809, "cached_tokens": 0}
# 2025-07-10T20:14:40.504+00:00 [SUCCESS] [Idx 1830] [Mdl: gemini-2.5-flash] [Task Task-217] Call OK. Usage: {"input_tokens": 7219, "output_tokens": 653, "cached_tokens": 0}
# 2025-07-10T20:14:40.598+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 5618 / 30000
# 2025-07-10T20:14:40.620+00:00 [SUCCESS] [Idx 2008] [Mdl: gemini-2.5-flash] [Task Task-241] Call OK. Usage: {"input_tokens": 7146, "output_tokens": 455, "cached_tokens": 0}
# 2025-07-10T20:14:40.730+00:00 [SUCCESS] [Idx 1913] [Mdl: gemini-2.5-flash] [Task Task-233] Call OK. Usage: {"input_tokens": 7203, "output_tokens": 649, "cached_tokens": 0}
# 2025-07-10T20:14:40.755+00:00 [SUCCESS] [Idx 1893] [Mdl: gemini-2.5-flash] [Task Task-229] Call OK. Usage: {"input_tokens": 7258, "output_tokens": 714, "cached_tokens": 0}
# 2025-07-10T20:14:40.904+00:00 [SUCCESS] [Idx 1846] [Mdl: gemini-2.5-flash] [Task Task-221] Call OK. Usage: {"input_tokens": 7290, "output_tokens": 945, "cached_tokens": 0}
# 2025-07-10T20:14:40.973+00:00 [SUCCESS] [Idx 2088] [Mdl: gemini-2.5-flash] [Task Task-245] Call OK. Usage: {"input_tokens": 7172, "output_tokens": 490, "cached_tokens": 0}
# 2025-07-10T20:14:41.118+00:00 [SUCCESS] [Idx 2013] [Mdl: gemini-2.5-flash] [Task Task-243] Call OK. Usage: {"input_tokens": 7133, "output_tokens": 572, "cached_tokens": 0}
# 2025-07-10T20:14:41.633+00:00 [SUCCESS] [Idx 2135] [Mdl: gemini-2.5-flash] [Task Task-253] Call OK. Usage: {"input_tokens": 7153, "output_tokens": 512, "cached_tokens": 0}
# 2025-07-10T20:14:41.633+00:00 [SUCCESS] [Idx 1936] [Mdl: gemini-2.5-flash] [Task Task-237] Call OK. Usage: {"input_tokens": 7202, "output_tokens": 810, "cached_tokens": 0}
# 2025-07-10T20:14:42.549+00:00 [SUCCESS] [Idx 1855] [Mdl: gemini-2.5-flash] [Task Task-223] Call OK. Usage: {"input_tokens": 7143, "output_tokens": 592, "cached_tokens": 0}
# 2025-07-10T20:14:43.366+00:00 [SUCCESS] [Idx 2144] [Mdl: gemini-2.5-flash] [Task Task-255] Call OK. Usage: {"input_tokens": 7231, "output_tokens": 647, "cached_tokens": 0}
# 2025-07-10T20:14:43.428+00:00 [SUCCESS] [Idx 1720] [Mdl: gemini-2.5-flash] [Task Task-195] Call OK. Usage: {"input_tokens": 7154, "output_tokens": 393, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2482). Retrying in 10.95s... (Attempt 1/10)
# 2025-07-10T20:14:43.899+00:00 [SUCCESS] [Idx 1975] [Mdl: gemini-2.5-flash] [Task Task-239] Call OK. Usage: {"input_tokens": 7331, "output_tokens": 1082, "cached_tokens": 0}
# 2025-07-10T20:14:43.966+00:00 [SUCCESS] [Idx 2121] [Mdl: gemini-2.5-flash] [Task Task-249] Call OK. Usage: {"input_tokens": 7255, "output_tokens": 818, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2486). Retrying in 10.98s... (Attempt 1/10)
# 2025-07-10T20:14:44.027+00:00 [SUCCESS] [Idx 1711] [Mdl: gemini-2.5-flash] [Task Task-193] Call OK. Usage: {"input_tokens": 7350, "output_tokens": 1271, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2507). Retrying in 10.62s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2512). Retrying in 10.16s... (Attempt 1/10)
# 2025-07-10T20:14:44.160+00:00 [SUCCESS] [Idx 2167] [Mdl: gemini-2.5-flash] [Task Task-257] Call OK. Usage: {"input_tokens": 7254, "output_tokens": 827, "cached_tokens": 0}
# 2025-07-10T20:14:44.163+00:00 [SUCCESS] [Idx 2293] [Mdl: gemini-2.5-flash] [Task Task-267] Call OK. Usage: {"input_tokens": 7112, "output_tokens": 397, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2537). Retrying in 10.27s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2539). Retrying in 10.38s... (Attempt 1/10)
# 2025-07-10T20:14:44.542+00:00 [SUCCESS] [Idx 2132] [Mdl: gemini-2.5-flash] [Task Task-251] Call OK. Usage: {"input_tokens": 7296, "output_tokens": 888, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2546). Retrying in 10.24s... (Attempt 1/10)
# 2025-07-10T20:14:45.281+00:00 [SUCCESS] [Idx 1842] [Mdl: gemini-2.5-flash] [Task Task-219] Call OK. Usage: {"input_tokens": 7327, "output_tokens": 930, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2555). Retrying in 10.79s... (Attempt 1/10)
# 2025-07-10T20:14:45.410+00:00 [SUCCESS] [Idx 2250] [Mdl: gemini-2.5-flash] [Task Task-263] Call OK. Usage: {"input_tokens": 7209, "output_tokens": 702, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2570). Retrying in 10.59s... (Attempt 1/10)
# 2025-07-10T20:14:45.672+00:00 [SUCCESS] [Idx 2102] [Mdl: gemini-2.5-flash] [Task Task-247] Call OK. Usage: {"input_tokens": 7335, "output_tokens": 1054, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2575). Retrying in 10.82s... (Attempt 1/10)
# 2025-07-10T20:14:46.428+00:00 [SUCCESS] [Idx 2411] [Mdl: gemini-2.5-flash] [Task Task-279] Call OK. Usage: {"input_tokens": 7167, "output_tokens": 530, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2584). Retrying in 10.85s... (Attempt 1/10)
# 2025-07-10T20:14:46.827+00:00 [SUCCESS] [Idx 2299] [Mdl: gemini-2.5-flash] [Task Task-269] Call OK. Usage: {"input_tokens": 7143, "output_tokens": 570, "cached_tokens": 0}
# 2025-07-10T20:14:46.899+00:00 [SUCCESS] [Idx 2307] [Mdl: gemini-2.5-flash] [Task Task-271] Call OK. Usage: {"input_tokens": 7204, "output_tokens": 623, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2635). Retrying in 10.03s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2680). Retrying in 10.79s... (Attempt 1/10)
# 2025-07-10T20:14:47.325+00:00 [SUCCESS] [Idx 2342] [Mdl: gemini-2.5-flash] [Task Task-273] Call OK. Usage: {"input_tokens": 7246, "output_tokens": 719, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2695). Retrying in 10.07s... (Attempt 1/10)
# 2025-07-10T20:14:47.436+00:00 [SUCCESS] [Idx 2416] [Mdl: gemini-2.5-flash] [Task Task-281] Call OK. Usage: {"input_tokens": 7244, "output_tokens": 846, "cached_tokens": 0}
# 2025-07-10T20:14:47.462+00:00 [SUCCESS] [Idx 2420] [Mdl: gemini-2.5-flash] [Task Task-283] Call OK. Usage: {"input_tokens": 7235, "output_tokens": 609, "cached_tokens": 0}
# 2025-07-10T20:14:47.474+00:00 [SUCCESS] [Idx 2359] [Mdl: gemini-2.5-flash] [Task Task-275] Call OK. Usage: {"input_tokens": 7197, "output_tokens": 690, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2721). Retrying in 10.86s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2741). Retrying in 10.87s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2752). Retrying in 10.04s... (Attempt 1/10)
# 2025-07-10T20:14:47.874+00:00 [SUCCESS] [Idx 198 ] [Mdl: gpt-4.1        ] [Task Task-16 ] Call OK. Usage: {"input_tokens": 6510, "output_tokens": 930, "cached_tokens": 6144}
# 2025-07-10T20:14:47.874+00:00 [REFUND ] [Idx 198 ] [Mdl: gpt-4.1        ] [Task Task-16 ] Correcting estimate. Budget restored by 150 -> 11368.
# 2025-07-10T20:14:47.876+00:00 [ GRANT ] [Idx 261 ] [Mdl: gpt-4.1        ] [Task Task-20 ] Permission granted. Budget: 11368 -> 3663
# 2025-07-10T20:14:47.895+00:00 [SUCCESS] [Idx 2407] [Mdl: gemini-2.5-flash] [Task Task-277] Call OK. Usage: {"input_tokens": 7266, "output_tokens": 867, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2755). Retrying in 10.47s... (Attempt 1/10)
# 2025-07-10T20:14:48.138+00:00 [ ERROR ] [Idx 1081] [Mdl: gemini-2.5-flash] [Task Task-119] ValueError: Google API returned an empty response for Index 1081.
# 🕒 Rate limit on gpt-4.1 (Index 234). Retrying in 10.01s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2762). Retrying in 10.02s... (Attempt 1/10)
# 2025-07-10T20:14:48.694+00:00 [SUCCESS] [Idx 2190] [Mdl: gemini-2.5-flash] [Task Task-259] Call OK. Usage: {"input_tokens": 7402, "output_tokens": 1375, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2765). Retrying in 10.00s... (Attempt 1/10)
# 2025-07-10T20:14:48.999+00:00 [SUCCESS] [Idx 2479] [Mdl: gemini-2.5-flash] [Task Task-291] Call OK. Usage: {"input_tokens": 7201, "output_tokens": 615, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2780). Retrying in 10.37s... (Attempt 1/10)
# 2025-07-10T20:14:50.534+00:00 [SUCCESS] [Idx 2474] [Mdl: gemini-2.5-flash] [Task Task-289] Call OK. Usage: {"input_tokens": 7242, "output_tokens": 760, "cached_tokens": 0}
# 2025-07-10T20:14:50.609+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 6063 / 30000
# 🕒 Rate limit on gemini-2.5-flash (Index 2794). Retrying in 10.11s... (Attempt 1/10)
# 2025-07-10T20:14:51.459+00:00 [SUCCESS] [Idx 1909] [Mdl: gemini-2.5-flash] [Task Task-231] Call OK. Usage: {"input_tokens": 7255, "output_tokens": 910, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2796). Retrying in 10.84s... (Attempt 1/10)
# 2025-07-10T20:14:51.618+00:00 [SUCCESS] [Idx 2421] [Mdl: gemini-2.5-flash] [Task Task-285] Call OK. Usage: {"input_tokens": 7278, "output_tokens": 1086, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2798). Retrying in 10.10s... (Attempt 1/10)
# 2025-07-10T20:14:52.310+00:00 [SUCCESS] [Idx 2212] [Mdl: gemini-2.5-flash] [Task Task-261] Call OK. Usage: {"input_tokens": 7325, "output_tokens": 1083, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2802). Retrying in 10.01s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2512). Retrying in 20.13s... (Attempt 2/10)
# 2025-07-10T20:14:54.549+00:00 [SUCCESS] [Idx 2437] [Mdl: gemini-2.5-flash] [Task Task-287] Call OK. Usage: {"input_tokens": 7244, "output_tokens": 830, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2482). Retrying in 20.96s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2537). Retrying in 20.45s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2816). Retrying in 10.96s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2539). Retrying in 20.79s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2507). Retrying in 20.93s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2546). Retrying in 20.14s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2486). Retrying in 20.49s... (Attempt 2/10)
# 2025-07-10T20:14:55.862+00:00 [SUCCESS] [Idx 1925] [Mdl: gemini-2.5-flash] [Task Task-235] Call OK. Usage: {"input_tokens": 7306, "output_tokens": 1325, "cached_tokens": 0}
# 🕒 Rate limit on gemini-2.5-flash (Index 2844). Retrying in 10.40s... (Attempt 1/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2570). Retrying in 20.18s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2555). Retrying in 20.39s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2575). Retrying in 20.92s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2635). Retrying in 20.16s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2584). Retrying in 20.86s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2695). Retrying in 20.67s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2752). Retrying in 20.87s... (Attempt 2/10)
# 🕒 Rate limit on gemini-2.5-flash (Index 2680). Retrying in 20.31s... (Attempt 2/10)
# 2025-07-10T20:14:59.484+00:00 [SUCCESS] [Idx 1819] [Mdl: gemini-2.5-flash] [Task Task-215] Call OK. Usage: {"input_tokens": 7467, "output_tokens": 1365, "cached_tokens": 0}
# 2025-07-10T20:15:00.619+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 14063 / 30000
# 2025-07-10T20:15:01.393+00:00 [SUCCESS] [Idx 1817] [Mdl: gemini-2.5-flash] [Task Task-213] Call OK. Usage: {"input_tokens": 7433, "output_tokens": 1303, "cached_tokens": 0}
# 2025-07-10T20:15:03.031+00:00 [SUCCESS] [Idx 2741] [Mdl: gemini-2.5-flash] [Task Task-323] Call OK. Usage: {"input_tokens": 7183, "output_tokens": 448, "cached_tokens": 0}
# 2025-07-10T20:15:03.641+00:00 [SUCCESS] [Idx 2721] [Mdl: gemini-2.5-flash] [Task Task-321] Call OK. Usage: {"input_tokens": 7160, "output_tokens": 434, "cached_tokens": 0}
# 2025-07-10T20:15:04.054+00:00 [SUCCESS] [Idx 2762] [Mdl: gemini-2.5-flash] [Task Task-329] Call OK. Usage: {"input_tokens": 7226, "output_tokens": 684, "cached_tokens": 0}
# 2025-07-10T20:15:04.871+00:00 [SUCCESS] [Idx 2845] [Mdl: gemini-2.5-flash] [Task Task-347] Call OK. Usage: {"input_tokens": 7164, "output_tokens": 478, "cached_tokens": 0}
# 2025-07-10T20:15:05.566+00:00 [SUCCESS] [Idx 261 ] [Mdl: gpt-4.1        ] [Task Task-20 ] Call OK. Usage: {"input_tokens": 6640, "output_tokens": 1235, "cached_tokens": 6144}
# 2025-07-10T20:15:05.566+00:00 [ GRANT ] [Idx 267 ] [Mdl: gpt-4.1        ] [Task Task-22 ] Permission granted. Budget: 17263 -> 9615
# 2025-07-10T20:15:05.820+00:00 [SUCCESS] [Idx 2765] [Mdl: gemini-2.5-flash] [Task Task-331] Call OK. Usage: {"input_tokens": 7154, "output_tokens": 452, "cached_tokens": 0}
# 2025-07-10T20:15:07.631+00:00 [SUCCESS] [Idx 2270] [Mdl: gemini-2.5-flash] [Task Task-265] Call OK. Usage: {"input_tokens": 7318, "output_tokens": 1296, "cached_tokens": 0}
# 2025-07-10T20:15:08.354+00:00 [SUCCESS] [Idx 234 ] [Mdl: gpt-4.1        ] [Task Task-18 ] Call OK. Usage: {"input_tokens": 6538, "output_tokens": 575, "cached_tokens": 6144}
# 2025-07-10T20:15:08.354+00:00 [REFUND ] [Idx 234 ] [Mdl: gpt-4.1        ] [Task Task-18 ] Correcting estimate. Budget restored by 523 -> 12538.
# 2025-07-10T20:15:08.356+00:00 [ GRANT ] [Idx 303 ] [Mdl: gpt-4.1        ] [Task Task-24 ] Permission granted. Budget: 12538 -> 4872
# 2025-07-10T20:15:08.393+00:00 [SUCCESS] [Idx 2755] [Mdl: gemini-2.5-flash] [Task Task-327] Call OK. Usage: {"input_tokens": 7269, "output_tokens": 904, "cached_tokens": 0}
# 2025-07-10T20:15:09.174+00:00 [SUCCESS] [Idx 2847] [Mdl: gemini-2.5-flash] [Task Task-349] Call OK. Usage: {"input_tokens": 7283, "output_tokens": 913, "cached_tokens": 0}
# 2025-07-10T20:15:09.582+00:00 [SUCCESS] [Idx 2796] [Mdl: gemini-2.5-flash] [Task Task-337] Call OK. Usage: {"input_tokens": 7221, "output_tokens": 857, "cached_tokens": 0}
# 2025-07-10T20:15:09.740+00:00 [SUCCESS] [Idx 2880] [Mdl: gemini-2.5-flash] [Task Task-353] Call OK. Usage: {"input_tokens": 7240, "output_tokens": 625, "cached_tokens": 0}
# 2025-07-10T20:15:09.775+00:00 [SUCCESS] [Idx 2798] [Mdl: gemini-2.5-flash] [Task Task-339] Call OK. Usage: {"input_tokens": 7207, "output_tokens": 898, "cached_tokens": 0}
# 2025-07-10T20:15:09.985+00:00 [SUCCESS] [Idx 2780] [Mdl: gemini-2.5-flash] [Task Task-333] Call OK. Usage: {"input_tokens": 7307, "output_tokens": 985, "cached_tokens": 0}
# 2025-07-10T20:15:10.435+00:00 [SUCCESS] [Idx 2884] [Mdl: gemini-2.5-flash] [Task Task-355] Call OK. Usage: {"input_tokens": 7182, "output_tokens": 622, "cached_tokens": 0}
# 2025-07-10T20:15:10.640+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 7272 / 30000
# 2025-07-10T20:15:10.810+00:00 [SUCCESS] [Idx 2853] [Mdl: gemini-2.5-flash] [Task Task-351] Call OK. Usage: {"input_tokens": 7224, "output_tokens": 977, "cached_tokens": 0}
# 2025-07-10T20:15:10.810+00:00 [SUCCESS] [Idx 2794] [Mdl: gemini-2.5-flash] [Task Task-335] Call OK. Usage: {"input_tokens": 7279, "output_tokens": 1260, "cached_tokens": 0}
# 2025-07-10T20:15:10.859+00:00 [SUCCESS] [Idx 2916] [Mdl: gemini-2.5-flash] [Task Task-359] Call OK. Usage: {"input_tokens": 7159, "output_tokens": 464, "cached_tokens": 0}
# 2025-07-10T20:15:11.772+00:00 [SUCCESS] [Idx 2904] [Mdl: gemini-2.5-flash] [Task Task-357] Call OK. Usage: {"input_tokens": 7176, "output_tokens": 725, "cached_tokens": 0}
# 2025-07-10T20:15:13.270+00:00 [SUCCESS] [Idx 2816] [Mdl: gemini-2.5-flash] [Task Task-343] Call OK. Usage: {"input_tokens": 7165, "output_tokens": 630, "cached_tokens": 0}
# 2025-07-10T20:15:14.087+00:00 [SUCCESS] [Idx 2938] [Mdl: gemini-2.5-flash] [Task Task-363] Call OK. Usage: {"input_tokens": 7204, "output_tokens": 520, "cached_tokens": 0}
# 2025-07-10T20:15:15.164+00:00 [SUCCESS] [Idx 2978] [Mdl: gemini-2.5-flash] [Task Task-371] Call OK. Usage: {"input_tokens": 7129, "output_tokens": 519, "cached_tokens": 0}
# 2025-07-10T20:15:15.738+00:00 [SUCCESS] [Idx 2987] [Mdl: gemini-2.5-flash] [Task Task-373] Call OK. Usage: {"input_tokens": 7185, "output_tokens": 615, "cached_tokens": 0}
# 2025-07-10T20:15:15.875+00:00 [SUCCESS] [Idx 2955] [Mdl: gemini-2.5-flash] [Task Task-367] Call OK. Usage: {"input_tokens": 7207, "output_tokens": 723, "cached_tokens": 0}
# 2025-07-10T20:15:17.160+00:00 [SUCCESS] [Idx 2940] [Mdl: gemini-2.5-flash] [Task Task-365] Call OK. Usage: {"input_tokens": 7346, "output_tokens": 1033, "cached_tokens": 0}
# 2025-07-10T20:15:18.181+00:00 [SUCCESS] [Idx 2802] [Mdl: gemini-2.5-flash] [Task Task-341] Call OK. Usage: {"input_tokens": 7341, "output_tokens": 1270, "cached_tokens": 0}
# 2025-07-10T20:15:19.847+00:00 [SUCCESS] [Idx 2844] [Mdl: gemini-2.5-flash] [Task Task-345] Call OK. Usage: {"input_tokens": 7189, "output_tokens": 517, "cached_tokens": 0}
# 2025-07-10T20:15:20.439+00:00 [SUCCESS] [Idx 2969] [Mdl: gemini-2.5-flash] [Task Task-369] Call OK. Usage: {"input_tokens": 7254, "output_tokens": 634, "cached_tokens": 0}
# 2025-07-10T20:15:20.652+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 15272 / 30000
# 2025-07-10T20:15:21.015+00:00 [SUCCESS] [Idx 2537] [Mdl: gemini-2.5-flash] [Task Task-301] Call OK. Usage: {"input_tokens": 7148, "output_tokens": 528, "cached_tokens": 0}
# 2025-07-10T20:15:21.665+00:00 [SUCCESS] [Idx 2539] [Mdl: gemini-2.5-flash] [Task Task-303] Call OK. Usage: {"input_tokens": 7217, "output_tokens": 573, "cached_tokens": 0}
# 🕒 Rate limit on gpt-4.1 (Index 303). Retrying in 10.18s... (Attempt 1/10)
# 2025-07-10T20:15:22.487+00:00 [SUCCESS] [Idx 2482] [Mdl: gemini-2.5-flash] [Task Task-293] Call OK. Usage: {"input_tokens": 7216, "output_tokens": 629, "cached_tokens": 0}
# 2025-07-10T20:15:22.894+00:00 [SUCCESS] [Idx 2546] [Mdl: gemini-2.5-flash] [Task Task-305] Call OK. Usage: {"input_tokens": 7235, "output_tokens": 909, "cached_tokens": 0}
# 2025-07-10T20:15:23.009+00:00 [SUCCESS] [Idx 2486] [Mdl: gemini-2.5-flash] [Task Task-295] Call OK. Usage: {"input_tokens": 7240, "output_tokens": 874, "cached_tokens": 0}
# 2025-07-10T20:15:23.511+00:00 [SUCCESS] [Idx 2575] [Mdl: gemini-2.5-flash] [Task Task-311] Call OK. Usage: {"input_tokens": 7187, "output_tokens": 559, "cached_tokens": 0}
# 2025-07-10T20:15:24.738+00:00 [SUCCESS] [Idx 2635] [Mdl: gemini-2.5-flash] [Task Task-315] Call OK. Usage: {"input_tokens": 7262, "output_tokens": 966, "cached_tokens": 0}
# 2025-07-10T20:15:24.741+00:00 [SUCCESS] [Idx 2584] [Mdl: gemini-2.5-flash] [Task Task-313] Call OK. Usage: {"input_tokens": 7247, "output_tokens": 767, "cached_tokens": 0}
# 2025-07-10T20:15:25.010+00:00 [SUCCESS] [Idx 2752] [Mdl: gemini-2.5-flash] [Task Task-325] Call OK. Usage: {"input_tokens": 7229, "output_tokens": 553, "cached_tokens": 0}
# 2025-07-10T20:15:25.341+00:00 [SUCCESS] [Idx 2512] [Mdl: gemini-2.5-flash] [Task Task-299] Call OK. Usage: {"input_tokens": 7492, "output_tokens": 1461, "cached_tokens": 0}
# 2025-07-10T20:15:25.965+00:00 [SUCCESS] [Idx 2680] [Mdl: gemini-2.5-flash] [Task Task-317] Call OK. Usage: {"input_tokens": 7201, "output_tokens": 709, "cached_tokens": 0}
# 2025-07-10T20:15:26.584+00:00 [SUCCESS] [Idx 267 ] [Mdl: gpt-4.1        ] [Task Task-22 ] Call OK. Usage: {"input_tokens": 6534, "output_tokens": 764, "cached_tokens": 6144}
# 2025-07-10T20:15:26.584+00:00 [REFUND ] [Idx 267 ] [Mdl: gpt-4.1        ] [Task Task-22 ] Correcting estimate. Budget restored by 350 -> 19622.
# 2025-07-10T20:15:26.585+00:00 [ GRANT ] [Idx 323 ] [Mdl: gpt-4.1        ] [Task Task-26 ] Permission granted. Budget: 19622 -> 12005
# 2025-07-10T20:15:26.589+00:00 [SUCCESS] [Idx 2507] [Mdl: gemini-2.5-flash] [Task Task-297] Call OK. Usage: {"input_tokens": 7283, "output_tokens": 950, "cached_tokens": 0}
# 2025-07-10T20:15:27.426+00:00 [SUCCESS] [Idx 2570] [Mdl: gemini-2.5-flash] [Task Task-309] Call OK. Usage: {"input_tokens": 7169, "output_tokens": 529, "cached_tokens": 0}
# 2025-07-10T20:15:27.923+00:00 [SUCCESS] [Idx 2695] [Mdl: gemini-2.5-flash] [Task Task-319] Call OK. Usage: {"input_tokens": 7234, "output_tokens": 821, "cached_tokens": 0}
# 2025-07-10T20:15:30.664+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 16005 / 30000
# 2025-07-10T20:15:36.824+00:00 [SUCCESS] [Idx 2555] [Mdl: gemini-2.5-flash] [Task Task-307] Call OK. Usage: {"input_tokens": 7189, "output_tokens": 625, "cached_tokens": 0}
# 2025-07-10T20:15:40.100+00:00 [SUCCESS] [Idx 323 ] [Mdl: gpt-4.1        ] [Task Task-26 ] Call OK. Usage: {"input_tokens": 6472, "output_tokens": 501, "cached_tokens": 6144}
# 2025-07-10T20:15:40.101+00:00 [REFUND ] [Idx 323 ] [Mdl: gpt-4.1        ] [Task Task-26 ] Correcting estimate. Budget restored by 644 -> 23849.
# 2025-07-10T20:15:40.103+00:00 [ GRANT ] [Idx 334 ] [Mdl: gpt-4.1        ] [Task Task-28 ] Permission granted. Budget: 23849 -> 16132
# 2025-07-10T20:15:40.674+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 16932 / 30000
# 2025-07-10T20:15:41.734+00:00 [ ERROR ] [Idx 2937] [Mdl: gemini-2.5-flash] [Task Task-361] ValueError: Google API returned an empty response for Index 2937.
# 🕒 Rate limit on gpt-4.1 (Index 303). Retrying in 20.05s... (Attempt 2/10)
# 2025-07-10T20:15:50.686+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 24932 / 30000
# 2025-07-10T20:15:57.919+00:00 [SUCCESS] [Idx 334 ] [Mdl: gpt-4.1        ] [Task Task-28 ] Call OK. Usage: {"input_tokens": 6656, "output_tokens": 1151, "cached_tokens": 6144}
# 2025-07-10T20:15:57.921+00:00 [ GRANT ] [Idx 340 ] [Mdl: gpt-4.1        ] [Task Task-30 ] Permission granted. Budget: 30000 -> 22457
# 2025-07-10T20:16:00.698+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 24857 / 30000
# 2025-07-10T20:16:10.001+00:00 [SUCCESS] [Idx 340 ] [Mdl: gpt-4.1        ] [Task Task-30 ] Call OK. Usage: {"input_tokens": 6423, "output_tokens": 595, "cached_tokens": 6144}
# 2025-07-10T20:16:10.002+00:00 [REFUND ] [Idx 340 ] [Mdl: gpt-4.1        ] [Task Task-30 ] Correcting estimate. Budget restored by 525 -> 30525.
# 2025-07-10T20:16:10.003+00:00 [ GRANT ] [Idx 343 ] [Mdl: gpt-4.1        ] [Task Task-32 ] Permission granted. Budget: 30525 -> 22962
# 2025-07-10T20:16:10.710+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23762 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 303). Retrying in 40.54s... (Attempt 3/10)
# 2025-07-10T20:16:20.722+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:16:26.150+00:00 [SUCCESS] [Idx 343 ] [Mdl: gpt-4.1        ] [Task Task-32 ] Call OK. Usage: {"input_tokens": 6461, "output_tokens": 658, "cached_tokens": 6144}
# 2025-07-10T20:16:26.150+00:00 [REFUND ] [Idx 343 ] [Mdl: gpt-4.1        ] [Task Task-32 ] Correcting estimate. Budget restored by 444 -> 30444.
# 2025-07-10T20:16:26.152+00:00 [ GRANT ] [Idx 370 ] [Mdl: gpt-4.1        ] [Task Task-34 ] Permission granted. Budget: 30444 -> 22798
# 2025-07-10T20:16:30.733+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 26798 / 30000
# 2025-07-10T20:16:39.834+00:00 [SUCCESS] [Idx 370 ] [Mdl: gpt-4.1        ] [Task Task-34 ] Call OK. Usage: {"input_tokens": 6555, "output_tokens": 778, "cached_tokens": 6144}
# 2025-07-10T20:16:39.834+00:00 [REFUND ] [Idx 370 ] [Mdl: gpt-4.1        ] [Task Task-34 ] Correcting estimate. Budget restored by 313 -> 30313.
# 2025-07-10T20:16:39.836+00:00 [ GRANT ] [Idx 437 ] [Mdl: gpt-4.1        ] [Task Task-36 ] Permission granted. Budget: 30313 -> 22723
# 2025-07-10T20:16:40.744+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23523 / 30000
# 2025-07-10T20:16:50.756+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:16:54.652+00:00 [SUCCESS] [Idx 437 ] [Mdl: gpt-4.1        ] [Task Task-36 ] Call OK. Usage: {"input_tokens": 6469, "output_tokens": 664, "cached_tokens": 6144}
# 2025-07-10T20:16:54.653+00:00 [REFUND ] [Idx 437 ] [Mdl: gpt-4.1        ] [Task Task-36 ] Correcting estimate. Budget restored by 457 -> 30457.
# 2025-07-10T20:16:54.654+00:00 [ GRANT ] [Idx 442 ] [Mdl: gpt-4.1        ] [Task Task-38 ] Permission granted. Budget: 30457 -> 22780
# 2025-07-10T20:17:00.767+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 28380 / 30000
# 2025-07-10T20:17:08.370+00:00 [SUCCESS] [Idx 442 ] [Mdl: gpt-4.1        ] [Task Task-38 ] Call OK. Usage: {"input_tokens": 6531, "output_tokens": 731, "cached_tokens": 6144}
# 2025-07-10T20:17:08.371+00:00 [REFUND ] [Idx 442 ] [Mdl: gpt-4.1        ] [Task Task-38 ] Correcting estimate. Budget restored by 415 -> 30415.
# 2025-07-10T20:17:08.372+00:00 [ GRANT ] [Idx 460 ] [Mdl: gpt-4.1        ] [Task Task-40 ] Permission granted. Budget: 30415 -> 22824
# 2025-07-10T20:17:10.626+00:00 [SUCCESS] [Idx 303 ] [Mdl: gpt-4.1        ] [Task Task-24 ] Call OK. Usage: {"input_tokens": 6558, "output_tokens": 976, "cached_tokens": 6144}
# 2025-07-10T20:17:10.626+00:00 [REFUND ] [Idx 303 ] [Mdl: gpt-4.1        ] [Task Task-24 ] Correcting estimate. Budget restored by 132 -> 24556.
# 2025-07-10T20:17:10.628+00:00 [ GRANT ] [Idx 470 ] [Mdl: gpt-4.1        ] [Task Task-42 ] Permission granted. Budget: 24556 -> 16904
# 2025-07-10T20:17:10.780+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 17704 / 30000
# 2025-07-10T20:17:20.792+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 25704 / 30000
# 2025-07-10T20:17:30.804+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:17:36.185+00:00 [SUCCESS] [Idx 460 ] [Mdl: gpt-4.1        ] [Task Task-40 ] Call OK. Usage: {"input_tokens": 6464, "output_tokens": 453, "cached_tokens": 6144}
# 2025-07-10T20:17:36.185+00:00 [REFUND ] [Idx 460 ] [Mdl: gpt-4.1        ] [Task Task-40 ] Correcting estimate. Budget restored by 674 -> 30674.
# 2025-07-10T20:17:36.187+00:00 [ GRANT ] [Idx 506 ] [Mdl: gpt-4.1        ] [Task Task-44 ] Permission granted. Budget: 30674 -> 23131
# 2025-07-10T20:17:39.300+00:00 [SUCCESS] [Idx 470 ] [Mdl: gpt-4.1        ] [Task Task-42 ] Call OK. Usage: {"input_tokens": 6534, "output_tokens": 687, "cached_tokens": 6144}
# 2025-07-10T20:17:39.300+00:00 [REFUND ] [Idx 470 ] [Mdl: gpt-4.1        ] [Task Task-42 ] Correcting estimate. Budget restored by 431 -> 25962.
# 2025-07-10T20:17:39.302+00:00 [ GRANT ] [Idx 525 ] [Mdl: gpt-4.1        ] [Task Task-46 ] Permission granted. Budget: 25962 -> 18270
# 2025-07-10T20:17:40.815+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 19870 / 30000
# 2025-07-10T20:17:50.826+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 27870 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 506). Retrying in 10.94s... (Attempt 1/10)
# ...
# 2025-07-10T20:51:10.599+00:00 [REFUND ] [Idx 2752] [Mdl: gpt-4.1        ] [Task Task-324] Correcting estimate. Budget restored by 661 -> 29896.
# 2025-07-10T20:51:10.601+00:00 [ GRANT ] [Idx 2762] [Mdl: gpt-4.1        ] [Task Task-328] Permission granted. Budget: 29896 -> 22311
# 2025-07-10T20:51:16.007+00:00 [SUCCESS] [Idx 2755] [Mdl: gpt-4.1        ] [Task Task-326] Call OK. Usage: {"input_tokens": 6500, "output_tokens": 740, "cached_tokens": 6144}
# 2025-07-10T20:51:16.007+00:00 [REFUND ] [Idx 2755] [Mdl: gpt-4.1        ] [Task Task-326] Correcting estimate. Budget restored by 366 -> 26677.
# 2025-07-10T20:51:16.009+00:00 [ GRANT ] [Idx 2765] [Mdl: gpt-4.1        ] [Task Task-330] Permission granted. Budget: 26677 -> 19124
# 2025-07-10T20:51:20.379+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23124 / 30000
# 2025-07-10T20:51:30.390+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2762). Retrying in 10.05s... (Attempt 1/10)
# 2025-07-10T20:51:40.401+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:51:50.412+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:51:53.064+00:00 [SUCCESS] [Idx 2765] [Mdl: gpt-4.1        ] [Task Task-330] Call OK. Usage: {"input_tokens": 6401, "output_tokens": 342, "cached_tokens": 6144}
# 2025-07-10T20:51:53.064+00:00 [REFUND ] [Idx 2765] [Mdl: gpt-4.1        ] [Task Task-330] Correcting estimate. Budget restored by 810 -> 30810.
# 2025-07-10T20:51:53.066+00:00 [ GRANT ] [Idx 2780] [Mdl: gpt-4.1        ] [Task Task-332] Permission granted. Budget: 30810 -> 23199
# 2025-07-10T20:51:56.047+00:00 [SUCCESS] [Idx 2762] [Mdl: gpt-4.1        ] [Task Task-328] Call OK. Usage: {"input_tokens": 6455, "output_tokens": 539, "cached_tokens": 6144}
# 2025-07-10T20:51:56.047+00:00 [REFUND ] [Idx 2762] [Mdl: gpt-4.1        ] [Task Task-328] Correcting estimate. Budget restored by 591 -> 26190.
# 2025-07-10T20:51:56.049+00:00 [ GRANT ] [Idx 2794] [Mdl: gpt-4.1        ] [Task Task-334] Permission granted. Budget: 26190 -> 18629
# 2025-07-10T20:52:00.424+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 22629 / 30000
# 2025-07-10T20:52:09.868+00:00 [SUCCESS] [Idx 2780] [Mdl: gpt-4.1        ] [Task Task-332] Call OK. Usage: {"input_tokens": 6536, "output_tokens": 801, "cached_tokens": 6144}
# 2025-07-10T20:52:09.868+00:00 [REFUND ] [Idx 2780] [Mdl: gpt-4.1        ] [Task Task-332] Correcting estimate. Budget restored by 274 -> 30103.
# 2025-07-10T20:52:09.869+00:00 [ GRANT ] [Idx 2796] [Mdl: gpt-4.1        ] [Task Task-336] Permission granted. Budget: 30103 -> 22538
# 2025-07-10T20:52:10.436+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23338 / 30000
# 2025-07-10T20:52:12.531+00:00 [SUCCESS] [Idx 2794] [Mdl: gpt-4.1        ] [Task Task-334] Call OK. Usage: {"input_tokens": 6499, "output_tokens": 1035, "cached_tokens": 6144}
# 2025-07-10T20:52:12.531+00:00 [REFUND ] [Idx 2794] [Mdl: gpt-4.1        ] [Task Task-334] Correcting estimate. Budget restored by 27 -> 24965.
# 2025-07-10T20:52:12.533+00:00 [ GRANT ] [Idx 2798] [Mdl: gpt-4.1        ] [Task Task-338] Permission granted. Budget: 24965 -> 17429
# 2025-07-10T20:52:20.447+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23829 / 30000
# 2025-07-10T20:52:30.458+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:52:37.871+00:00 [SUCCESS] [Idx 2796] [Mdl: gpt-4.1        ] [Task Task-336] Call OK. Usage: {"input_tokens": 6444, "output_tokens": 719, "cached_tokens": 6144}
# 2025-07-10T20:52:37.871+00:00 [REFUND ] [Idx 2796] [Mdl: gpt-4.1        ] [Task Task-336] Correcting estimate. Budget restored by 402 -> 30402.
# 2025-07-10T20:52:37.873+00:00 [ GRANT ] [Idx 2802] [Mdl: gpt-4.1        ] [Task Task-340] Permission granted. Budget: 30402 -> 22762
# 2025-07-10T20:52:38.225+00:00 [SUCCESS] [Idx 2798] [Mdl: gpt-4.1        ] [Task Task-338] Call OK. Usage: {"input_tokens": 6435, "output_tokens": 675, "cached_tokens": 6144}
# 2025-07-10T20:52:38.225+00:00 [REFUND ] [Idx 2798] [Mdl: gpt-4.1        ] [Task Task-338] Correcting estimate. Budget restored by 426 -> 23188.
# 2025-07-10T20:52:38.226+00:00 [ GRANT ] [Idx 2816] [Mdl: gpt-4.1        ] [Task Task-342] Permission granted. Budget: 23188 -> 15672
# 2025-07-10T20:52:40.470+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 18072 / 30000
# 2025-07-10T20:52:50.482+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 26072 / 30000
# 2025-07-10T20:53:00.494+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2802). Retrying in 10.90s... (Attempt 1/10)
# 2025-07-10T20:53:05.780+00:00 [SUCCESS] [Idx 2816] [Mdl: gpt-4.1        ] [Task Task-342] Call OK. Usage: {"input_tokens": 6395, "output_tokens": 547, "cached_tokens": 6144}
# 2025-07-10T20:53:05.781+00:00 [REFUND ] [Idx 2816] [Mdl: gpt-4.1        ] [Task Task-342] Correcting estimate. Budget restored by 574 -> 30574.
# 2025-07-10T20:53:05.782+00:00 [ GRANT ] [Idx 2844] [Mdl: gpt-4.1        ] [Task Task-344] Permission granted. Budget: 30574 -> 23011
# 2025-07-10T20:53:10.507+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 27011 / 30000
# 2025-07-10T20:53:18.495+00:00 [SUCCESS] [Idx 2844] [Mdl: gpt-4.1        ] [Task Task-344] Call OK. Usage: {"input_tokens": 6439, "output_tokens": 416, "cached_tokens": 6144}
# 2025-07-10T20:53:18.495+00:00 [REFUND ] [Idx 2844] [Mdl: gpt-4.1        ] [Task Task-344] Correcting estimate. Budget restored by 708 -> 30708.
# 2025-07-10T20:53:18.497+00:00 [ GRANT ] [Idx 2845] [Mdl: gpt-4.1        ] [Task Task-346] Permission granted. Budget: 30708 -> 23141
# 2025-07-10T20:53:20.519+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 25541 / 30000
# 2025-07-10T20:53:22.779+00:00 [SUCCESS] [Idx 2802] [Mdl: gpt-4.1        ] [Task Task-340] Call OK. Usage: {"input_tokens": 6557, "output_tokens": 1005, "cached_tokens": 6144}
# 2025-07-10T20:53:22.779+00:00 [REFUND ] [Idx 2802] [Mdl: gpt-4.1        ] [Task Task-340] Correcting estimate. Budget restored by 78 -> 27219.
# 2025-07-10T20:53:22.781+00:00 [ GRANT ] [Idx 2847] [Mdl: gpt-4.1        ] [Task Task-348] Permission granted. Budget: 27219 -> 19586
# 2025-07-10T20:53:30.531+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 25986 / 30000
# 2025-07-10T20:53:40.542+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2845). Retrying in 10.89s... (Attempt 1/10)
# 2025-07-10T20:53:50.552+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:53:51.041+00:00 [SUCCESS] [Idx 2847] [Mdl: gpt-4.1        ] [Task Task-348] Call OK. Usage: {"input_tokens": 6530, "output_tokens": 765, "cached_tokens": 6144}
# 2025-07-10T20:53:51.041+00:00 [REFUND ] [Idx 2847] [Mdl: gpt-4.1        ] [Task Task-348] Correcting estimate. Budget restored by 338 -> 30338.
# 2025-07-10T20:53:51.043+00:00 [ GRANT ] [Idx 2853] [Mdl: gpt-4.1        ] [Task Task-350] Permission granted. Budget: 30338 -> 22775
# 2025-07-10T20:54:00.564+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:54:01.305+00:00 [SUCCESS] [Idx 2845] [Mdl: gpt-4.1        ] [Task Task-346] Call OK. Usage: {"input_tokens": 6407, "output_tokens": 395, "cached_tokens": 6144}
# 2025-07-10T20:54:01.305+00:00 [REFUND ] [Idx 2845] [Mdl: gpt-4.1        ] [Task Task-346] Correcting estimate. Budget restored by 765 -> 30765.
# 2025-07-10T20:54:01.307+00:00 [ GRANT ] [Idx 2880] [Mdl: gpt-4.1        ] [Task Task-352] Permission granted. Budget: 30765 -> 23163
# 2025-07-10T20:54:03.125+00:00 [SUCCESS] [Idx 2853] [Mdl: gpt-4.1        ] [Task Task-350] Call OK. Usage: {"input_tokens": 6454, "output_tokens": 699, "cached_tokens": 6144}
# 2025-07-10T20:54:03.125+00:00 [REFUND ] [Idx 2853] [Mdl: gpt-4.1        ] [Task Task-350] Correcting estimate. Budget restored by 410 -> 25173.
# 2025-07-10T20:54:03.126+00:00 [ GRANT ] [Idx 2884] [Mdl: gpt-4.1        ] [Task Task-354] Permission granted. Budget: 25173 -> 17618
# 2025-07-10T20:54:10.576+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 24018 / 30000
# 2025-07-10T20:54:20.589+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2880). Retrying in 10.35s... (Attempt 1/10)
# 2025-07-10T20:54:30.159+00:00 [SUCCESS] [Idx 2884] [Mdl: gpt-4.1        ] [Task Task-354] Call OK. Usage: {"input_tokens": 6414, "output_tokens": 521, "cached_tokens": 6144}
# 2025-07-10T20:54:30.160+00:00 [REFUND ] [Idx 2884] [Mdl: gpt-4.1        ] [Task Task-354] Correcting estimate. Budget restored by 620 -> 30620.
# 2025-07-10T20:54:30.161+00:00 [ GRANT ] [Idx 2904] [Mdl: gpt-4.1        ] [Task Task-356] Permission granted. Budget: 30620 -> 23089
# 2025-07-10T20:54:30.600+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23889 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2880). Retrying in 20.53s... (Attempt 2/10)
# 2025-07-10T20:54:40.611+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:54:45.723+00:00 [SUCCESS] [Idx 2904] [Mdl: gpt-4.1        ] [Task Task-356] Call OK. Usage: {"input_tokens": 6410, "output_tokens": 566, "cached_tokens": 6144}
# 2025-07-10T20:54:45.723+00:00 [REFUND ] [Idx 2904] [Mdl: gpt-4.1        ] [Task Task-356] Correcting estimate. Budget restored by 555 -> 30555.
# 2025-07-10T20:54:45.725+00:00 [ GRANT ] [Idx 2916] [Mdl: gpt-4.1        ] [Task Task-358] Permission granted. Budget: 30555 -> 23003
# 2025-07-10T20:54:50.623+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 27003 / 30000
# 2025-07-10T20:54:56.310+00:00 [SUCCESS] [Idx 2916] [Mdl: gpt-4.1        ] [Task Task-358] Call OK. Usage: {"input_tokens": 6405, "output_tokens": 377, "cached_tokens": 6144}
# 2025-07-10T20:54:56.311+00:00 [REFUND ] [Idx 2916] [Mdl: gpt-4.1        ] [Task Task-358] Correcting estimate. Budget restored by 770 -> 30770.
# 2025-07-10T20:54:56.313+00:00 [ GRANT ] [Idx 2937] [Mdl: gpt-4.1        ] [Task Task-360] Permission granted. Budget: 30770 -> 23114
# 2025-07-10T20:55:00.635+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 27114 / 30000
# 2025-07-10T20:55:10.647+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:55:10.711+00:00 [SUCCESS] [Idx 2880] [Mdl: gpt-4.1        ] [Task Task-352] Call OK. Usage: {"input_tokens": 6462, "output_tokens": 502, "cached_tokens": 6144}
# 2025-07-10T20:55:10.711+00:00 [REFUND ] [Idx 2880] [Mdl: gpt-4.1        ] [Task Task-352] Correcting estimate. Budget restored by 638 -> 30638.
# 2025-07-10T20:55:10.712+00:00 [ GRANT ] [Idx 2938] [Mdl: gpt-4.1        ] [Task Task-362] Permission granted. Budget: 30638 -> 23111
# 2025-07-10T20:55:16.653+00:00 [SUCCESS] [Idx 2937] [Mdl: gpt-4.1        ] [Task Task-360] Call OK. Usage: {"input_tokens": 6578, "output_tokens": 1082, "cached_tokens": 6144}
# 2025-07-10T20:55:16.655+00:00 [ GRANT ] [Idx 2940] [Mdl: gpt-4.1        ] [Task Task-364] Permission granted. Budget: 27111 -> 19413
# 2025-07-10T20:55:20.664+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 23413 / 30000
# 2025-07-10T20:55:30.676+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2938). Retrying in 10.71s... (Attempt 1/10)
# 2025-07-10T20:55:40.688+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 30000 / 30000
# 2025-07-10T20:55:42.253+00:00 [SUCCESS] [Idx 2940] [Mdl: gpt-4.1        ] [Task Task-364] Call OK. Usage: {"input_tokens": 6578, "output_tokens": 865, "cached_tokens": 6144}
# 2025-07-10T20:55:42.253+00:00 [REFUND ] [Idx 2940] [Mdl: gpt-4.1        ] [Task Task-364] Correcting estimate. Budget restored by 255 -> 30255.
# 2025-07-10T20:55:42.255+00:00 [ GRANT ] [Idx 2955] [Mdl: gpt-4.1        ] [Task Task-366] Permission granted. Budget: 30255 -> 22682
# 2025-07-10T20:55:50.699+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 29882 / 30000
# 2025-07-10T20:55:54.541+00:00 [SUCCESS] [Idx 2938] [Mdl: gpt-4.1        ] [Task Task-362] Call OK. Usage: {"input_tokens": 6416, "output_tokens": 432, "cached_tokens": 6144}
# 2025-07-10T20:55:54.541+00:00 [REFUND ] [Idx 2938] [Mdl: gpt-4.1        ] [Task Task-362] Correcting estimate. Budget restored by 679 -> 30679.
# 2025-07-10T20:55:54.543+00:00 [ GRANT ] [Idx 2969] [Mdl: gpt-4.1        ] [Task Task-368] Permission granted. Budget: 30679 -> 23073
# 2025-07-10T20:55:55.062+00:00 [SUCCESS] [Idx 2955] [Mdl: gpt-4.1        ] [Task Task-366] Call OK. Usage: {"input_tokens": 6444, "output_tokens": 567, "cached_tokens": 6144}
# 2025-07-10T20:55:55.062+00:00 [REFUND ] [Idx 2955] [Mdl: gpt-4.1        ] [Task Task-366] Correcting estimate. Budget restored by 562 -> 24435.
# 2025-07-10T20:55:55.064+00:00 [ GRANT ] [Idx 2978] [Mdl: gpt-4.1        ] [Task Task-370] Permission granted. Budget: 24435 -> 16925
# 2025-07-10T20:56:00.710+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 21725 / 30000
# 2025-07-10T20:56:10.721+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 29725 / 30000
# 2025-07-10T20:57:17.999+00:00 [SUCCESS] [Idx 2978] [Mdl: gpt-4.1        ] [Task Task-370] Call OK. Usage: {"input_tokens": 6375, "output_tokens": 406, "cached_tokens": 6144}
# 2025-07-10T20:57:18.000+00:00 [REFUND ] [Idx 2978] [Mdl: gpt-4.1        ] [Task Task-370] Correcting estimate. Budget restored by 729 -> 30729.
# 2025-07-10T20:57:18.003+00:00 [ GRANT ] [Idx 2987] [Mdl: gpt-4.1        ] [Task Task-372] Permission granted. Budget: 30729 -> 23168
# 2025-07-10T20:57:20.527+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-3  ] Bucket budget at 25568 / 30000
# 2025-07-10T20:57:21.631+00:00 [SUCCESS] [Idx 2987] [Mdl: gpt-4.1        ] [Task Task-372] Call OK. Usage: {"input_tokens": 6414, "output_tokens": 480, "cached_tokens": 6144}
# 2025-07-10T20:57:21.631+00:00 [REFUND ] [Idx 2987] [Mdl: gpt-4.1        ] [Task Task-372] Correcting estimate. Budget restored by 667 -> 27035.
# 2025-07-10T20:57:25.824+00:00 [SUCCESS] [Idx 2969] [Mdl: gpt-4.1        ] [Task Task-368] Call OK. Usage: {"input_tokens": 6479, "output_tokens": 634, "cached_tokens": 6144}
# 2025-07-10T20:57:25.825+00:00 [REFUND ] [Idx 2969] [Mdl: gpt-4.1        ] [Task Task-368] Correcting estimate. Budget restored by 493 -> 30493.
#
# --- Manifest Generation Complete ---
# Processed 185 indices in 2607.31 seconds.
# Performance log saved to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-gen-txt/tier4/generation_performance_20250710_205725.csv
# Success rate: 365/370 (98.6%)
#
# --- Generation Performance Summary ---
#   provider             model  index   status  time_s  input_tokens  \
# 0   google  gemini-2.5-flash      1  Success    5.09          7105
# 1   google  gemini-2.5-flash    612  Success    5.48          7155
# 2   google  gemini-2.5-flash    506  Success    5.66          7161
# 3   openai           gpt-4.1      1  Success    6.28          6359
# 4   google  gemini-2.5-flash    340  Success    6.61          7181
#
#    output_tokens  cached_tokens              utc_completed
# 0            393              0  2025-07-10T20:14:03+00:00
# 1            497              0  2025-07-10T20:14:04+00:00
# 2            504              0  2025-07-10T20:14:04+00:00
# 3            336           6144  2025-07-10T20:14:04+00:00
# 4            738              0  2025-07-10T20:14:05+00:00
