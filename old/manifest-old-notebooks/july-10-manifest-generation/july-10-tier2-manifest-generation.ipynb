# %% [markdown]
# #### Cell 1: Paths

# %%
from pathlib import Path

def find_project_root():
    """Traverse upwards to find the project root, marked by the .git folder."""
    current_path = Path.cwd()
    while current_path != current_path.parent:
        if (current_path / ".git").is_dir():
            return current_path
        current_path = current_path.parent
    raise FileNotFoundError("Could not find project root. Is this a git repository?")

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / 'data'

# To contain generated manifest txt files
MANIFEST_OUTPUT_DIR = DATA_DIR / "tier-manifests-gen-txt" 

# Contains sample manifest json files, questions answers, and user prompt prefixes
MANIFEST_EXAMPLES_DIR = DATA_DIR / "tier-manifests-examples-json" 

TIER_OUTPUT_DIRS = {f"tier{i}": MANIFEST_OUTPUT_DIR / f"tier{i}" for i in range(1, 6)}
TIER_EXAMPLES_DIRS = {f"tier{i}": MANIFEST_EXAMPLES_DIR / f"tier{i}" for i in range(1, 6)}

# Make the directory for the tier if it doesn't exist
for tier_dir in TIER_OUTPUT_DIRS.values():
    tier_dir.mkdir(parents=True, exist_ok=True)

for tier_dir in TIER_EXAMPLES_DIRS.values():
    tier_dir.mkdir(parents=True, exist_ok=True)

print(f"Project root found at: {PROJECT_ROOT}")
print(f"Data directory found at: {DATA_DIR}")
print(f"Raw manifest output directory set to: {MANIFEST_OUTPUT_DIR}")
# Out:
# Project root found at: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math
# Data directory found at: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data
# Raw manifest output directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-gen-txt

# %% [markdown]
# #### Cell 2: Dataset and tier definitions

# %%
import datasets
from datasets import load_dataset 
import re

GSM8K_TRAIN = load_dataset("gsm8k", "main", split="train")

def has_computational_division(solution_text: str):
    """Returns True if a '/' is followed by optional whitespace and then a digit."""
    pattern = re.compile(r'/\s*\d')
    return bool(pattern.search(solution_text))


def has_float(solution_text: str):
    """Returns True if the solution text contains a floating-point number."""
    pattern = re.compile(r'(?<!\d)\.\d+|\d+\.\d+')
    return bool(pattern.search(solution_text))


def is_symbolic(solution_text: str):
    """Returns True if the solution contains a symbolic reasoning line (Let @ ...)."""
    pattern = re.compile(r'^Let [a-zA-Z] ', re.MULTILINE)
    return bool(pattern.search(solution_text))


def mutually_disjoint_tiers(dataset: datasets.Dataset):
    tiers = {}
    symbolic_set = set(
        idx for idx, sample in enumerate(dataset)
        if is_symbolic(sample.get("answer", ""))
    )
    non_symbolic_indices = [
        idx for idx in range(len(dataset)) if idx not in symbolic_set
    ]

    # Tier 1: Only integer arithmetic (no floats, no computational division)
    tiers["tier1"] = sorted([
        idx for idx in non_symbolic_indices
        if not has_float(dataset[idx].get("answer", "")) and not has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 2: Float arithmetic, no computational division
    tiers["tier2"] = sorted([
        idx for idx in non_symbolic_indices
        if has_float(dataset[idx].get("answer", "")) and not has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 3: Computational division, no floats
    tiers["tier3"] = sorted([
        idx for idx in non_symbolic_indices
        if not has_float(dataset[idx].get("answer", "")) and has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 4: Both floats and computational division
    tiers["tier4"] = sorted([
        idx for idx in non_symbolic_indices
        if has_float(dataset[idx].get("answer", "")) and has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 5: Symbolic reasoning (Let @ ...)
    tiers["tier5"] = sorted(symbolic_set)

    return tiers


TIER_LISTS = mutually_disjoint_tiers(GSM8K_TRAIN)

# Display the number of samples in each tier
for tier, indices in TIER_LISTS.items():
    print(f"{tier:<10}: {len(indices)} samples")
print(f"{'Total':<10}: {len(GSM8K_TRAIN)} samples")
# Out:
# tier1     : 2767 samples
# tier2     : 837 samples
# tier3     : 3113 samples
# tier4     : 544 samples
# tier5     : 212 samples
# Total     : 7473 samples

# %% [markdown]
# #### **Selecting the current tier for this notebook**

# %%
### --- Select the tier ONCE for this notebook --- ###
CURRENT_TIER = "tier2"

CURRENT_INDICES = TIER_LISTS[CURRENT_TIER]
CURRENT_TIER_OUTPUT_DIR = TIER_OUTPUT_DIRS[CURRENT_TIER]
CURRENT_TIER_EXAMPLES_DIR = TIER_EXAMPLES_DIRS[CURRENT_TIER]

print(f"Tier for this notebook: {CURRENT_TIER}")
print(f"Number of samples in {CURRENT_TIER}: {len(CURRENT_INDICES)}")
print(f"Output directory for {CURRENT_TIER}: {CURRENT_TIER_OUTPUT_DIR}")
print(f"Examples directory for {CURRENT_TIER}: {CURRENT_TIER_EXAMPLES_DIR}")
# Out:
# Tier for this notebook: tier2
# Number of samples in tier2: 837
# Output directory for tier2: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-gen-txt/tier2
# Examples directory for tier2: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-examples-json/tier2

# %% [markdown]
# #### Cell 3: Prompt creation

# %%
import json


def sanitize_text(text: str):
    """
    Replaces a comprehensive set of problematic Unicode characters with their
    ASCII equivalents to prevent model generation and string parsing errors.
    """
    replacements = {
        # Mathematical Operators
        "\u2212": "-",  # Minus Sign
        "\u00d7": "*",  # Multiplication Sign
        "\u00f7": "/",  # Division Sign
        "\u22c5": "*",  # Dot Operator
        
        # Typographic Quotes
        "\u201c": '"',  # Left Double Quotation Mark
        "\u201d": '"',  # Right Double Quotation Mark
        "\u2018": "'",  # Left Single Quotation Mark
        "\u2019": "'",  # Right Single Quotation Mark
        
        # Typographic Dashes
        "\u2014": "-",  # Em Dash
        "\u2013": "-",  # En Dash
        
        # Other
        "\u2026": "...", # Horizontal Ellipsis
        "\u00a0": " ",  # Non-breaking Space
    }
    for uni, ascii_char in replacements.items():
        text = text.replace(uni, ascii_char)
    return text


def build_solution_mapping(
        index: int, 
        dataset: 'datasets.Dataset' = GSM8K_TRAIN,
        exclude_FA: bool = True
    ):
    """
    Extracts the natural language solution, sanitizes it, and structures
    it into a line-numbered dictionary.
    """
    solution_mapping = {}
    solution_text = dataset[index]["answer"]
    sanitized_solution_text = sanitize_text(solution_text)
    
    # --- CORRECTION: Use the sanitized variable ---
    lines = [ln.strip() for ln in sanitized_solution_text.splitlines() if ln.strip()]

    if lines and re.match(r"^####\s*[\d\.,]+$", lines[-1]):
        solution_mapping["FA"] = lines.pop(-1).strip()

    for i, line in enumerate(lines, 1):
        solution_mapping[f"L{i}"] = line

    if exclude_FA and "FA" in solution_mapping:
        del solution_mapping["FA"]

    return solution_mapping


BASE_MANIFEST_SCHEMA = {
    "type": "object",
    "properties": {
        "function_code": {
            "type": "string",
            "description": "A single string containing a complete, self-contained Python function that constitutes an end-to-end formalization of the solution."
        },
        "logical_steps": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "line_number": {"type": "string"},
                    "question_inputs": {"type": "array", "items": {"type": "string"}},
                    "WK_inputs": {"type": "array", "items": {"type": "string"}},
                    "output_variable": {"type": "string"},
                    "solution_line_template": {"type": "string"}
                },
                "required": ["line_number", "question_inputs", "WK_inputs", "output_variable", "solution_line_template"]
            }
        }
    },
    "required": ["function_code", "logical_steps"]
}


SYSTEM_PROMPT = """You are a data formalization expert who excels in mathematical reasoning and writing python code. You will be presented with a math word problem accompanied by a step-by-step natural language solution. You goal is to carefully and meticulously analyze the given question and solution, and formalize it by converting it into a structured json object that deconstructs the logic of the solution.

You MUST follow all rules and formatting instructions provided in the user prompt without deviation. Your entire output MUST be a single JSON object wrapped in ```json ... ```. Do not include any text or explanation before or after the JSON object."""

STATIC_PREFIXES = {}
for tier in TIER_LISTS.keys():
    prefix_file = TIER_EXAMPLES_DIRS[tier] / f"{tier}_user_prompt_prefix.txt"
    with open(prefix_file, 'r', encoding='utf-8') as f:
        STATIC_PREFIXES[tier] = f.read()


def append_sample_to_user_prompt(
        tier: str, 
        index: int, 
        dataset: datasets.Dataset = GSM8K_TRAIN
    ):
    """
    Appends a chosen sample from the GSM8K dataset to the user prompt for a specific tier. Returns the complete user prompt, ready to be sent to the LLM for manifest generation.
    """
    if tier not in TIER_LISTS:
        raise ValueError(f"Invalid tier: {tier}. Must be one of {list(TIER_LISTS.keys())}.")

    sample = dataset[index]
    question = sample['question']
    answer = build_solution_mapping(index, dataset)

    task_block = f"""## Input

**Index:**:
{index}

**Question:**:
{question}

**Solution mapping:**:
{json.dumps(answer, indent=2)}

## Output

"""
    return STATIC_PREFIXES[tier] + task_block


# Example usage
idx = CURRENT_INDICES[0]
user_prompt = append_sample_to_user_prompt(CURRENT_TIER, idx, GSM8K_TRAIN)
print(f"User prompt for index {idx} in {CURRENT_TIER} has {len(user_prompt)} characters:")
print("-"*80)
print(user_prompt)
# Out:
# User prompt for index 9 in tier2 has 18046 characters:
# --------------------------------------------------------------------------------
# In the TASK below, you will be given a math problem and its corresponding step-by-step solution. Each step in the solution is numbered (e.g. "L1", "L2" and so on), and many of the steps include calculator annotations (e.g. "<<20*0.1=2>>"). Your goal is to convert this information into a structured JSON object according to the following schema and detailed instructions.
#
# # Detailed Field Instructions
#
# ## 1. "function_code"
#
# This string must contain a Python function with the following characteristics:
#
# *   **1.A. No Imports:** You should not have ANY imports. The very first line MUST be the function definition (i.e. `def solve():`).
# *   **1.B. Function Naming & Docstring:** The function must be named `solve`, and it should not have any args. It must begin with a docstring that has exactly two lines:
#     *   **1.B.i.** The first line must be: "Index: [Index]." using the index from the task header.
#     *   **1.B.ii.** The second line must be a succinct, one-sentence description of what the function returns (e.g., "Returns: the total cost of wages and taxes.").
# *   **1.C. Line comments:** For each solution line that is used to compute the final answer, include a comment of the form `# L1`, `# L2` and so on, which references the line number.
#     *   **1.C.i.** Such a comment must immediately be followed by a code block that precisely formalizes the corresponding solution line. More details about code blocks are provided in 1.D below.
#     *   **1.C.ii.** If a solution line does not contain any computation relevant to the final answer, then omit it completely from the function code and do NOT add a corresponding line comment.
# *   **1.D. Code blocks:** Each code block constitutes a complete formalization of its corresponding solution line. It must consist of the following:
#     *   **1.D.i. Input Variables** First, define any NEW variables needed for the computation, i.e. that will be used for the first time in the solution. Each input variable MUST be followed by a comment (`#`) in the same line. These variables fall into two categories:
#         *   "question_inputs": These are variables whose values are stated in or can be extracted from the question text (only the question text, NOT the answer text). The comment for these variables should quote or refer to the phrase in the question text from which it is extracted.
#         *   "WK_inputs": These are variables drawn from common-sense "World Knowledge" (e.g. `minutes_per_hour = 60`, `dozen = 12`). The comment for these variables MUST simply say `# WK`.
#     *   **1.D.ii. Output Variables** Second, there should be EXACTLY ONE line of code which formalizes the computation in the solution line and assigns the resulting value to a new variable (this is the "output_variable" field).
# *   **1.E. The Direct Substitution Rule:** This is the MOST IMPORTANT RULE, which ensures that the "solution_line_template" is purely identical to the original solution line except that numerical values in computations have been replaced with variable placeholders: You MUST define variables in such a way that they can be DIRECTLY SUBSTITUTED into the solution line without changing any operators or surrounding text in the line.
# *   **1.F. Final Answer:** The line that assigns the final result to the `answer` variable must be immediately preceded by a line containing only the comment `# FA`. The last line of the function must always return the `answer` variable.
#
# ## 2. "solution_line_template"
#
# *   **2.A.** The template should be EXACTLY identical to the original solution line, with the ONLY CHANGES being that every NUMERICAL value used in a computation is replaced by its corresponding `{variable_name}` placeholder. This applies to the entire content of the solution line, including the inside and outside of the calculator annotations.
# *   **2.B.** In particular, EVERY SINGLE numerical value appearing inside the calculator annotation (`<<..>>`) MUST be replaced with a `{variable_name}` placeholder.
# *   **2.C.** Note: some quantities may appear as words in the solution line (e.g. "twice as many"). Do NOT attempt to replace these with variable name placeholders.
# *   **2.D.** The Direct Substitution Rule will ensure that for correctly defined variables, it will be possible to replace the numerical values with variable name placeholders while leaving all surrounding text, symbols, and operators unchanged. Thus, in a correct "solution_line_template", the calculator annotation will not contain any numerical values, and moreover, replacing each `{variable_name}` by its value should exactly recover the original solution line, including the original calculator annotation.
#
# # Examples
#
# Given below are three examples that illustrate what a perfect formalization will look like. For each example, you are given the following:
#
# *   Input: consisting of an index, question, and solution mapping.
# *   Output: complete output, following the correct JSON schema.
#
# In all examples, you will observe the following:
#
# *   **A rigid adherence to the Direct Substitution Rule (1.E)**. This is the most important principle. The `solution_line_template` must be an exact copy of the original solution line, with only computational numbers replaced by `{variable}` placeholders. Every other point follows from this rule.
#
# *   **How to formalize numbers depends entirely on how they appear in the solution text.** The goal is to create variables so that the numerical values can be directly substituted.
#     *   **Simple Case:** In **Example 3**, the calculation uses `.8`. This is formalized with a single variable: `insurance_coverage_percent = 0.8`. In **Example 1**, "half an hour" is used in a calculation as `.5`, so it is formalized as `chase_duration = 0.5`.
#     *   **Complex Case (Inconsistent Text):** A solution can be inconsistent, using multiple representations for the same concept. The Direct Substitution Rule must still be followed, even if it requires creating multiple variables. For instnace, in line L2 of **Example 2**:
#         *   The text "10%" requires `discount_percent_num = 10`.
#         *   The text ".10" requires `discount_percent_decimal = 0.10`.
#         *   The calculation `10 * .01` inside the annotation requires `percent_factor = 0.01` to represent the `.01` that does not appear elsewhere.
#         *   This results in three distinct variables to satisfy the substitution rule for one conceptual idea.
#
# *   **Strict adherence to defining only NEW variables** in each step's `question_inputs` and `WK_inputs` lists. For instance, in **Example 1**, `fast_speed` is defined in L2 and then simply re-used in the computation for L4 without being listed as an input again.
#
# *   Comments for `question_inputs` must cite the question text only, **NEVER** the solution text. Note how `percent_factor = 0.01` in **Example 2** is correctly labeled `# WK` because that fact constitutes common-sense World Knowledge and is not present in the question text.
#
# ## Example 1
#
# ### Input
#
# **Index:**
# 2401
#
# **Question:**
# A wild tiger escapes the zoo.  He escapes at 1 AM and zookeepers do not notice he is missing until 4 AM.  He runs at a speed of 25 mph.  It takes 2 more hours to find him but after 4 hours of running, the tiger slows his speed to 10 mph.  He then gets chased for half an hour going 50 mph.  How far away from the zoo was he caught?
#
# **Solution mapping:**
# {
#   "L1": "He was running for 4-1=<<4-1=3>>3 hours",
#   "L2": "So in that time he runs 3*25=<<3*25=75>>75 miles",
#   "L3": "Since he slowed down after 4 hours, the time he spent running at 25mph was an additional 4-3=<<4-3=1>>1 hours",
#   "L4": "So in the first hour they were finding him, he ran 1*25=<<1*25=25>>25 miles",
#   "L5": "In the second hour they were finding him, he ran 1*10=<<1*10=10>>10 miles",
#   "L6": "Finally, during the chase, he ran 50*.5=<<50*.5=25>>25 miles",
#   "L7": "So he is 75+25+10+25=<<75+25+10+25=135>>135 miles away"
# }
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 2401.\n    Returns: how far away from the zoo the tiger was caught.\n    \"\"\"\n    # L1\n    notice_time = 4 # notice he is missing until 4 AM\n    escape_time = 1 # escapes at 1 AM\n    initial_run_duration = notice_time - escape_time\n\n    # L2\n    fast_speed = 25 # runs at a speed of 25 mph\n    distance_before_notice = initial_run_duration * fast_speed\n\n    # L3\n    time_before_slow = 4 # after 4 hours of running\n    additional_fast_run_duration = time_before_slow - initial_run_duration\n\n    # L4\n    additional_fast_distance = additional_fast_run_duration * fast_speed\n\n    # L5\n    slow_run_duration = 1 # In the second hour\n    slow_speed = 10 # slows his speed to 10 mph\n    slow_distance = slow_run_duration * slow_speed\n\n    # L6\n    chase_speed = 50 # going 50 mph\n    chase_duration = 0.5 # for half an hour\n    chase_distance = chase_speed * chase_duration\n\n    # L7\n    total_distance = distance_before_notice + additional_fast_distance + slow_distance + chase_distance\n\n    # FA\n    answer = total_distance\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["notice_time", "escape_time"],
#       "WK_inputs": [],
#       "output_variable": "initial_run_duration",
#       "solution_line_template": "He was running for {notice_time}-{escape_time}=<<{notice_time}-{escape_time}={initial_run_duration}>>{initial_run_duration} hours"
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": ["fast_speed"],
#       "WK_inputs": [],
#       "output_variable": "distance_before_notice",
#       "solution_line_template": "So in that time he runs {initial_run_duration}*{fast_speed}=<<{initial_run_duration}*{fast_speed}={distance_before_notice}>>{distance_before_notice} miles"
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["time_before_slow"],
#       "WK_inputs": [],
#       "output_variable": "additional_fast_run_duration",
#       "solution_line_template": "Since he slowed down after 4 hours, the time he spent running at 25mph was an additional {time_before_slow}-{initial_run_duration}=<<{time_before_slow}-{initial_run_duration}={additional_fast_run_duration}>>{additional_fast_run_duration} hours"
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "additional_fast_distance",
#       "solution_line_template": "So in the first hour they were finding him, he ran {additional_fast_run_duration}*{fast_speed}=<<{additional_fast_run_duration}*{fast_speed}={additional_fast_distance}>>{additional_fast_distance} miles"
#     },
#     {
#       "line_number": "L5",
#       "question_inputs": ["slow_speed", "slow_run_duration"],
#       "WK_inputs": [],
#       "output_variable": "slow_distance",
#       "solution_line_template": "In the second hour they were finding him, he ran {slow_run_duration}*{slow_speed}=<<{slow_run_duration}*{slow_speed}={slow_distance}>>{slow_distance} miles"
#     },
#     {
#       "line_number": "L6",
#       "question_inputs": ["chase_speed", "chase_duration"],
#       "WK_inputs": [],
#       "output_variable": "chase_distance",
#       "solution_line_template": "Finally, during the chase, he ran {chase_speed}*{chase_duration}=<<{chase_speed}*{chase_duration}={chase_distance}>>{chase_distance} miles"
#     },
#     {
#       "line_number": "L7",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "total_distance",
#       "solution_line_template": "So he is {distance_before_notice}+{additional_fast_distance}+{slow_distance}+{chase_distance}=<<{distance_before_notice}+{additional_fast_distance}+{slow_distance}+{chase_distance}={total_distance}>>{total_distance} miles away"
#     }
#   ]
# }
# ```
#
# ## Example 2
#
# ### Input
#
# **Index:**
# 2918
#
# **Question:**
# Monica charges $25.00 per person when catering a dinner party.  For repeat customers, she offers a 10% discount.  Phoebe is a repeat customer who is having a dinner party for 20 guests.  How much will Monica make from the party?
#
# **Solution mapping:**
# {
#   "L1": "Phoebe is having 20 guests and Monica charges $25.00 per person so that’s 20*25 = $<<20*25=500.00>>500.00",
#   "L2": "Phoebe is a repeat customer so she gets 10% off of $500.00 so that’s .10*500 = $<<10*.01*500=50.00>>50.00 discount",
#   "L3": "Monica is charging $500.00 minus the repeat customer discount of $50.00 so she will make 500-50 = $<<500-50=450.00>>450.00"
# }
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 2918.\n    Returns: the amount Monica will make from the party.\n    \"\"\"\n    # L1\n    num_guests = 20 # 20 guests\n    cost_per_person = 25.00 # $25.00 per person\n    base_cost = num_guests * cost_per_person\n\n    # L2\n    discount_percent_decimal = 0.10 # from solution text: .10*500\n    discount_percent_num = 10 # 10% discount\n    percent_factor = 0.01 # WK\n    discount_amount = discount_percent_num * percent_factor * base_cost\n\n    # L3\n    final_cost = base_cost - discount_amount\n\n    # FA\n    answer = final_cost\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["num_guests", "cost_per_person"],
#       "WK_inputs": [],
#       "output_variable": "base_cost",
#       "solution_line_template": "Phoebe is having {num_guests} guests and Monica charges ${cost_per_person} per person so that’s {num_guests}*{cost_per_person} = $<<{num_guests}*{cost_per_person}={base_cost}>>{base_cost}"
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": ["discount_percent_num", "discount_percent_decimal"],
#       "WK_inputs": ["percent_factor"],
#       "output_variable": "discount_amount",
#       "solution_line_template": "Phoebe is a repeat customer so she gets {discount_percent_num}% off of ${base_cost} so that’s {discount_percent_decimal}*{base_cost} = $<<{discount_percent_num}*{percent_factor}*{base_cost}={discount_amount}>>{discount_amount} discount"
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "final_cost",
#       "solution_line_template": "Monica is charging ${base_cost} minus the repeat customer discount of ${discount_amount} so she will make {base_cost}-{discount_amount} = $<<{base_cost}-{discount_amount}={final_cost}>>{final_cost}"
#     }
#   ]
# }
# ```
#
# ## Example 3
#
# ### Input
#
# **Index:**
# 4822
#
# **Question:**
# James needs to get a new pair of glasses.  His frames cost $200 and the lenses cost $500.  Insurance will cover 80% of the cost of lenses and he has a $50 off coupon for frames.  How much does everything cost?
#
# **Solution mapping:**
# {
#   "L1": "He gets 500*.8=$<<500*.8=400>>400 off the cost of lenses",
#   "L2": "That means the lenses cost 500-400=$<<500-400=100>>100",
#   "L3": "The frames cost 200-50=$<<200-50=150>>150",
#   "L4": "So he pays 100+150=$<<100+150=250>>250"
# }
# ```
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 4822.\n    Returns: the total cost for the glasses.\n    \"\"\"\n    # L1\n    lenses_cost = 500 # lenses cost $500\n    insurance_coverage_percent = 0.8 # cover 80% of the cost\n    lenses_coverage_amount = lenses_cost * insurance_coverage_percent\n\n    # L2\n    final_lenses_cost = lenses_cost - lenses_coverage_amount\n\n    # L3\n    frames_cost = 200 # frames cost $200\n    coupon_discount = 50 # $50 off coupon\n    final_frames_cost = frames_cost - coupon_discount\n\n    # L4\n    total_cost = final_lenses_cost + final_frames_cost\n\n    # FA\n    answer = total_cost\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["lenses_cost", "insurance_coverage_percent"],
#       "WK_inputs": [],
#       "output_variable": "lenses_coverage_amount",
#       "solution_line_template": "He gets {lenses_cost}*{insurance_coverage_percent}=$<<{lenses_cost}*{insurance_coverage_percent}={lenses_coverage_amount}>>{lenses_coverage_amount} off the cost of lenses"
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "final_lenses_cost",
#       "solution_line_template": "That means the lenses cost {lenses_cost}-{lenses_coverage_amount}=$<<{lenses_cost}-{lenses_coverage_amount}={final_lenses_cost}>>{final_lenses_cost}"
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["frames_cost", "coupon_discount"],
#       "WK_inputs": [],
#       "output_variable": "final_frames_cost",
#       "solution_line_template": "The frames cost {frames_cost}-{coupon_discount}=$<<{frames_cost}-{coupon_discount}={final_frames_cost}>>{final_frames_cost}"
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "total_cost",
#       "solution_line_template": "So he pays {final_lenses_cost}+{final_frames_cost}=$<<{final_lenses_cost}+{final_frames_cost}={total_cost}>>{total_cost}"
#     }
#   ]
# }
# ```
#
# ## Input
#
# **Index:**:
# 9
#
# **Question:**:
# Tina makes $18.00 an hour.  If she works more than 8 hours per shift, she is eligible for overtime, which is paid by your hourly wage + 1/2 your hourly wage.  If she works 10 hours every day for 5 days, how much money does she make?
#
# **Solution mapping:**:
# {
#   "L1": "She works 8 hours a day for $18 per hour so she makes 8*18 = $<<8*18=144.00>>144.00 per 8-hour shift",
#   "L2": "She works 10 hours a day and anything over 8 hours is eligible for overtime, so she gets 10-8 = <<10-8=2>>2 hours of overtime",
#   "L3": "Overtime is calculated as time and a half so and she makes $18/hour so her overtime pay is 18*.5 = $<<18*.5=9.00>>9.00",
#   "L4": "Her overtime pay is 18+9 = $<<18+9=27.00>>27.00",
#   "L5": "Her base pay is $144.00 per 8-hour shift and she works 5 days and makes 5 * $144 = $<<144*5=720.00>>720.00",
#   "L6": "Her overtime pay is $27.00 per hour and she works 2 hours of overtime per day and makes 27*2 = $<<27*2=54.00>>54.00 in overtime pay",
#   "L7": "2 hours of overtime pay for 5 days means she makes 54*5 = $270.00",
#   "L8": "In 5 days her base pay is $720.00 and she makes $270.00 in overtime pay so she makes $720 + $270 = $<<720+270=990.00>>990.00"
# }
#
# ## Output

# %% [markdown]
# #### Cell 4: API clients, concurrency limits, models

# %%
# Imports for API clients and related functionality
import os
import openai
import google.generativeai as genai
import anthropic
import asyncio
import nest_asyncio
from openai import AsyncOpenAI
from anthropic import AsyncClient
from dotenv import load_dotenv

# This must be done once per kernel to allow asyncio to run in a Jupyter notebook..
nest_asyncio.apply()

# Load API Keys from .env file
load_dotenv()
print("Loaded environment variables from .env file.")

# Initialize Asynchronous API Clients
try:
    openai_client_async = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    anthropic_client_async = AsyncClient(api_key=os.getenv("ANTHROPIC_API_KEY"))
    genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
    print("API clients initialized successfully.")
except TypeError:
    print("API key not found for one or more services. Please check your .env file.")
    # Assign None to prevent errors in subsequent cells
    openai_client_async = None
    anthropic_client_async = None

# Define API Concurrency Limits to prevent 429 "Too Many Requests" errors.
API_CONCURRENCY_LIMITS = {
    "google": 30,    
    "anthropic": 2, 
    "openai": 2,    
}
print(f"API concurrency limits set to: {API_CONCURRENCY_LIMITS}")

MODEL_DICT = {
  "openai": "gpt-4.1",
  "google": "gemini-2.5-flash"
}

MODELS = [f"{provider}_{model}" for provider, model in MODEL_DICT.items()]
print(f"Available models: {MODELS}")
# Out:
# Loaded environment variables from .env file.
# API clients initialized successfully.
# API concurrency limits set to: {'google': 30, 'anthropic': 2, 'openai': 2}
# Available models: ['openai_gpt-4.1', 'google_gemini-2.5-flash']

# %% [markdown]
# #### Cell 5: Helper functions to avoid rate limits in API calls

# %%
import time
import random

import threading
import datetime


_log_lock = threading.Lock()
def log_event(
        level: str, 
        index: int, 
        model: str, 
        message: str
    ):
    """A thread-safe logger for concurrent operations."""
    with _log_lock:
        ts = datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="milliseconds")
        task_id = asyncio.current_task().get_name()
        print(f"{ts} [{level:^7s}] [Idx {index:<4}] [Mdl: {model:<15}] [Task {task_id:<8}] {message}")
 

async def with_api_retries(
        send_coroutine_factory,
        *,
        model_info: str,  # For informative logging
        max_attempts: int = 10,
        base_wait_seconds: int = 10
    ):
    """A wrapper to handle API retries with exponential backoff."""
    for attempt in range(max_attempts):
        try:
            return await send_coroutine_factory()
        except (openai.RateLimitError, anthropic.RateLimitError, Exception) as e:
            # Check for specific rate limit error types or a 429 status code in the error string
            if isinstance(e, (openai.RateLimitError, anthropic.RateLimitError)) or "429" in str(e):
                if attempt == max_attempts - 1:
                    print(f"❌ Final attempt failed for {model_info}. Giving up.")
                    raise
                
                # Exponential backoff with jitter
                wait_time = base_wait_seconds * (2 ** attempt) + random.uniform(0, 1)
                
                # More informative error message
                print(f"🕒 Rate limit on {model_info}. Retrying in {wait_time:.2f}s... (Attempt {attempt + 1}/{max_attempts})")
                await asyncio.sleep(wait_time)
            else:
                # If it's not a rate limit error, re-raise immediately
                raise
    return None


class RateLimitCoordinator:
    def __init__(self, refill_rate_per_sec: float, max_tokens: int):
        self.refill_rate_per_sec = refill_rate_per_sec
        self.max_tokens = float(max_tokens)
        self.tokens = self.max_tokens
        self._lock = asyncio.Lock()
        self._refill_task = None
        
    async def _refill(self):
        """The background task that refills the token bucket at 1-second intervals."""
        while True:
            await asyncio.sleep(1)
            async with self._lock:
                self.tokens = min(self.max_tokens, self.tokens + self.refill_rate_per_sec)
                if int(time.time()) % 10 == 0:
                    log_event("REFILL", -1, "Coordinator", f"Bucket budget at {int(self.tokens)} / {int(self.max_tokens)}")

    async def start(self):
        if self._refill_task is None:
            self._refill_task = asyncio.create_task(self._refill())

    async def stop(self):
        if self._refill_task:
            self._refill_task.cancel()
            self._refill_task = None

    async def get_tokens(self, index: int, model: str, tokens_needed: int):
        while True:
            async with self._lock:
                if self.tokens >= tokens_needed:
                    self.tokens -= tokens_needed
                    log_event("GRANT", index, model, f"Permission granted. Budget: {int(self.tokens + tokens_needed)} -> {int(self.tokens)}")
                    return
            
            deficit = tokens_needed - self.tokens
            wait_time = max(0.1, deficit / self.refill_rate_per_sec) # Ensure at least a small wait
            
            log_event("WAIT", index, model, f"Budget low. Needed: {tokens_needed}, Have: {int(self.tokens)}. Waiting ~{wait_time:.2f}s...")
            await asyncio.sleep(wait_time)

    async def return_tokens(self, index: int, model: str, tokens_returned: int):
        async with self._lock:
            self.tokens += tokens_returned
            log_event("RETURN", index, model, f"Tokens returned on failure. Budget restored to {int(self.tokens)}.")

    async def refund_tokens(self, index: int, model: str, tokens_refunded: int):
        """Refunds tokens to the budget after a successful call, correcting our estimate."""
        async with self._lock:
            self.tokens += tokens_refunded
            log_event("REFUND", index, model, f"Correcting estimate. Budget restored by {tokens_refunded} -> {int(self.tokens)}.")

# %% [markdown]
# #### Cell 6: Provider-specific API calling functions

# %%
import math
import copy

async def call_openai_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int,
        json_schema: dict,
        openai_max_tokens: int 
    ) -> tuple[str, dict, dict]:
    """
    Prepares a provider-specific schema and handles an API call to OpenAI.
    """
    
    openai_schema = copy.deepcopy(json_schema)

    def add_additional_properties(schema_part):
        if isinstance(schema_part, dict):
            if schema_part.get("type") == "object":
                schema_part["additionalProperties"] = False
            for value in schema_part.values():
                add_additional_properties(value)
        elif isinstance(schema_part, list):
            for item in schema_part:
                add_additional_properties(item)

    add_additional_properties(openai_schema)
    openai_schema_wrapper = {
        "name": "manifest_formalization", 
        "strict": True, 
        "schema": openai_schema
    }
    
    messages = [{"role": "system", "content": system_prompt}, 
                {"role": "user", "content": user_prompt}]
    
    model_info = f"{model} (Index {index})"
    
    response_with_headers = await with_api_retries(
        lambda: openai_client_async.chat.completions.with_raw_response.create(
            model=model, 
            messages=messages, 
            temperature=0, 
            max_tokens=openai_max_tokens, 
            response_format={"type": "json_schema", "json_schema": openai_schema_wrapper} # type: ignore
        ),
        model_info=model_info
    )
    
    response = response_with_headers.parse()
    text_response = response.choices[0].message.content
    
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage:
        usage["input_tokens"] = response.usage.prompt_tokens
        usage["output_tokens"] = response.usage.completion_tokens
        if hasattr(response.usage, 'prompt_tokens_details') and response.usage.prompt_tokens_details:
             usage["cached_tokens"] = response.usage.prompt_tokens_details.get("cached_tokens", 0)

    headers = response_with_headers.headers
    rate_limit_info = {
        "limit_requests": headers.get("x-ratelimit-limit-requests"),
        "limit_tokens": headers.get("x-ratelimit-limit-tokens"),
        "remaining_requests": headers.get("x-ratelimit-remaining-requests"),
        "remaining_tokens": headers.get("x-ratelimit-remaining-tokens"),
        "reset_requests": headers.get("x-ratelimit-reset-requests"),
        "reset_tokens": headers.get("x-ratelimit-reset-tokens"),
    }
             
    return text_response, usage, rate_limit_info


async def call_google_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int,
        json_schema: dict
    ):
    """
    Handles a Google API call with schema enforcement and a safe
    upper bound on output tokens to prevent runaway generation.
    """
    
    safety_settings = {
        "HARM_CATEGORY_HARASSMENT": "BLOCK_NONE",
        "HARM_CATEGORY_HATE_SPEECH": "BLOCK_NONE",
        "HARM_CATEGORY_SEXUALLY_EXPLICIT": "BLOCK_NONE",
        "HARM_CATEGORY_DANGEROUS_CONTENT": "BLOCK_NONE",
    }
    
    gemini = genai.GenerativeModel(
        model_name=model,
        system_instruction=system_prompt,
        safety_settings=safety_settings
    )
    
    cfg = genai.types.GenerationConfig(
        temperature=0, 
        max_output_tokens=8192, # Safe upper bound
        response_mime_type="application/json",
        response_schema=json_schema
    )
    
    model_info = f"{model} (Index {index})"

    response = await with_api_retries(
        lambda: gemini.generate_content_async(user_prompt, generation_config=cfg),
        model_info=model_info
    )

    if not response.parts:
        raise ValueError(f"Google API returned an empty response for Index {index}.")

    text_response = response.text
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage_metadata:
        usage["input_tokens"] = response.usage_metadata.prompt_token_count
        usage["output_tokens"] = response.usage_metadata.candidates_token_count
        
    return text_response, usage

# %% [markdown]
# #### Cell 7: Single API call function

# %%
import datetime
import json

async def run_single_api_call(
    provider: str,
    model: str,
    index: int,
    tier: str,
    dataset: 'datasets.Dataset',
    system_prompt: str,
    output_dir: Path,
    provider_sem: asyncio.Semaphore,
    json_schema: dict,
    coordinator: RateLimitCoordinator,
    openai_max_tokens: int,
    ):
    """
    Runs a single API call, but first checks if the output file already
    exists to avoid re-generating completed work.
    """

    output_path = output_dir / str(index) / f"{provider}_{model}.txt"
    if output_path.exists() and output_path.stat().st_size > 0:
        log_event("SKIPPED", index, model, "Output file already exists.")
        return {
            "provider": provider, "model": model, "index": index,
            "status": "Skipped", "time_s": 0,
            "input_tokens": 0, "output_tokens": 0, "cached_tokens": 0,
            "utc_completed": datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="seconds")
        }
        
    async with provider_sem:
        user_prompt = append_sample_to_user_prompt(tier=tier, index=index, dataset=dataset)

        tokens_needed = 0
        if provider == "openai":
            estimated_prompt_tokens = len(user_prompt.split()) * 1.25
            tokens_needed = int(estimated_prompt_tokens + openai_max_tokens)
            await coordinator.get_tokens(index, model, tokens_needed)

        start_time = time.time()
        status = "Failed"
        usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}

        try:
            if provider == "openai":
                text_response, usage, _ = await call_openai_async(
                    model, system_prompt, user_prompt, index, json_schema, openai_max_tokens
                )
                log_event("SUCCESS", index, model, f"Call OK. Usage: {json.dumps(usage)}")
                
                true_cost = usage['input_tokens'] + usage['output_tokens']
                refund_amount = tokens_needed - true_cost
                if refund_amount > 0:
                    await coordinator.refund_tokens(index, model, refund_amount)
                    
            elif provider == "google":
                text_response, usage = await call_google_async(
                    model, system_prompt, user_prompt, index, json_schema
                )
                log_event("SUCCESS", index, model, f"Call OK. Usage: {json.dumps(usage)}")
            
            status = "Success"

        except Exception as e:
            log_event("ERROR", index, model, f"{type(e).__name__}: {str(e).splitlines()[0]}")
            text_response = f"--- ERROR ---\nIndex: {index}, Model: {model}\n{type(e).__name__}: {e}"
            
        finally:
            if status == "Failed" and provider == "openai" and tokens_needed > 0:
                await coordinator.return_tokens(index, model, tokens_needed)

        output_path.parent.mkdir(parents=True, exist_ok=True)
        output_path.write_text(text_response, encoding='utf-8')
        
        elapsed = time.time() - start_time
        
        return {
            "provider": provider, "model": model, "index": index,
            "status": status, "time_s": round(elapsed, 2),
            "input_tokens": usage["input_tokens"], "output_tokens": usage["output_tokens"],
            "cached_tokens": usage["cached_tokens"],
            "utc_completed": datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="seconds")
        }

# %% [markdown]
# #### Cell 8: Main manifest generation functions

# %%
from tqdm.notebook import tqdm
import pandas as pd

async def generate_manifests_parallel_fixed(
    indices_to_generate: list[int],
    tier: str = CURRENT_TIER,
    dataset: 'datasets.Dataset' = GSM8K_TRAIN,
    model_dict: dict[str, str] = MODEL_DICT,
    system_prompt: str = SYSTEM_PROMPT,
    concurrency_limits: dict[str, int] = API_CONCURRENCY_LIMITS,
    json_schema: dict = BASE_MANIFEST_SCHEMA,
    openai_max_tokens: int = 4000
    ):
    """
    Fully parallel version with a robust token bucket coordinator for OpenAI.
    """
    print("--- Starting Manifest Generation (Token Bucket) ---")
    start_time = time.time()

    openai_coordinator = RateLimitCoordinator(refill_rate_per_sec=800, max_tokens=30000)
    await openai_coordinator.start()
    
    provider_semaphores = {prov: asyncio.Semaphore(limit) for prov, limit in concurrency_limits.items()}
    output_dir = TIER_OUTPUT_DIRS[tier]
    
    all_tasks = []
    for index in indices_to_generate:
        for provider, model in model_dict.items():
            task = asyncio.create_task(
                run_single_api_call(
                    provider=provider, model=model, index=index,
                    tier=tier, dataset=dataset, system_prompt=system_prompt,
                    output_dir=output_dir, provider_sem=provider_semaphores[provider],
                    json_schema=json_schema,
                    coordinator=openai_coordinator,
                    openai_max_tokens=openai_max_tokens
                )
            )
            all_tasks.append(task)
    
    print(f"Created {len(all_tasks)} total API call tasks")
    
    results = []
    try:
        with tqdm(total=len(all_tasks), desc="API Calls") as pbar:
            for task in asyncio.as_completed(all_tasks):
                result = await task
                results.append(result)
                pbar.update(1)
    finally:
        await openai_coordinator.stop()
    
    df = pd.DataFrame(results)
    run_ts = datetime.datetime.now(datetime.timezone.utc).strftime("%Y%m%d_%H%M%S")
    csv_path = output_dir / f"generation_performance_{run_ts}.csv"
    df.to_csv(csv_path, index=False)
    
    end_time = time.time()
    print(f"\n--- Manifest Generation Complete ---")
    print(f"Processed {len(indices_to_generate)} indices in {end_time - start_time:.2f} seconds.")
    print(f"Performance log saved to: {csv_path}")
    
    success_count = len(df[df['status'] == 'Success'])
    total_calls = len(df)
    if total_calls > 0:
      print(f"Success rate: {success_count}/{total_calls} ({100*success_count/total_calls:.1f}%)")
    
    return df

# %% [markdown]
# #### Cell 9: Running the main manifest generation function

# %%
# --- Test Run Configuration ---
# Generate manifests for all indices up to 200 for the current tier.
LOWER_LIMIT = 200
UPPER_LIMIT = 3000
INDICES_TO_GENERATE = [idx for idx in CURRENT_INDICES if idx <= UPPER_LIMIT and idx >= LOWER_LIMIT]

print(f"Starting test run for {len(INDICES_TO_GENERATE)} indices in {CURRENT_TIER} between {LOWER_LIMIT} and {UPPER_LIMIT}.")

# Run the parallel generation function with the test indices.
# This will test the full pipeline, including the new RateLimitCoordinator.
perf_df = await generate_manifests_parallel_fixed(indices_to_generate=INDICES_TO_GENERATE)

# Display the head of the resulting performance dataframe to verify execution.
print("\n--- Test Run Performance Summary ---")
perf_df.head()
# Out:
# Starting test run for 311 indices in tier2 between 200 and 3000.
# --- Starting Manifest Generation (Token Bucket) ---
# Created 622 total API call tasks
# API Calls:   0%|          | 0/622 [00:00<?, ?it/s]
# 2025-07-10T18:57:25.806+00:00 [SKIPPED] [Idx 210 ] [Mdl: gpt-4.1        ] [Task Task-3  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 210 ] [Mdl: gemini-2.5-flash] [Task Task-4  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 211 ] [Mdl: gpt-4.1        ] [Task Task-5  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 211 ] [Mdl: gemini-2.5-flash] [Task Task-6  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 215 ] [Mdl: gpt-4.1        ] [Task Task-7  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 215 ] [Mdl: gemini-2.5-flash] [Task Task-8  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 228 ] [Mdl: gpt-4.1        ] [Task Task-9  ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 228 ] [Mdl: gemini-2.5-flash] [Task Task-10 ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 242 ] [Mdl: gpt-4.1        ] [Task Task-11 ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 242 ] [Mdl: gemini-2.5-flash] [Task Task-12 ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 248 ] [Mdl: gpt-4.1        ] [Task Task-13 ] Output file already exists.
# 2025-07-10T18:57:25.807+00:00 [SKIPPED] [Idx 248 ] [Mdl: gemini-2.5-flash] [Task Task-14 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 250 ] [Mdl: gpt-4.1        ] [Task Task-15 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 250 ] [Mdl: gemini-2.5-flash] [Task Task-16 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 251 ] [Mdl: gpt-4.1        ] [Task Task-17 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 251 ] [Mdl: gemini-2.5-flash] [Task Task-18 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 257 ] [Mdl: gpt-4.1        ] [Task Task-19 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 257 ] [Mdl: gemini-2.5-flash] [Task Task-20 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 263 ] [Mdl: gpt-4.1        ] [Task Task-21 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 263 ] [Mdl: gemini-2.5-flash] [Task Task-22 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 265 ] [Mdl: gpt-4.1        ] [Task Task-23 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 265 ] [Mdl: gemini-2.5-flash] [Task Task-24 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 270 ] [Mdl: gpt-4.1        ] [Task Task-25 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 270 ] [Mdl: gemini-2.5-flash] [Task Task-26 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 275 ] [Mdl: gpt-4.1        ] [Task Task-27 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 275 ] [Mdl: gemini-2.5-flash] [Task Task-28 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 278 ] [Mdl: gpt-4.1        ] [Task Task-29 ] Output file already exists.
# 2025-07-10T18:57:25.808+00:00 [SKIPPED] [Idx 278 ] [Mdl: gemini-2.5-flash] [Task Task-30 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 280 ] [Mdl: gpt-4.1        ] [Task Task-31 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 280 ] [Mdl: gemini-2.5-flash] [Task Task-32 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 284 ] [Mdl: gpt-4.1        ] [Task Task-33 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 284 ] [Mdl: gemini-2.5-flash] [Task Task-34 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 287 ] [Mdl: gpt-4.1        ] [Task Task-35 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 287 ] [Mdl: gemini-2.5-flash] [Task Task-36 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 291 ] [Mdl: gpt-4.1        ] [Task Task-37 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 291 ] [Mdl: gemini-2.5-flash] [Task Task-38 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 300 ] [Mdl: gpt-4.1        ] [Task Task-39 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 300 ] [Mdl: gemini-2.5-flash] [Task Task-40 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 310 ] [Mdl: gpt-4.1        ] [Task Task-41 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 310 ] [Mdl: gemini-2.5-flash] [Task Task-42 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 320 ] [Mdl: gpt-4.1        ] [Task Task-43 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 320 ] [Mdl: gemini-2.5-flash] [Task Task-44 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 322 ] [Mdl: gpt-4.1        ] [Task Task-45 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 322 ] [Mdl: gemini-2.5-flash] [Task Task-46 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 330 ] [Mdl: gpt-4.1        ] [Task Task-47 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 330 ] [Mdl: gemini-2.5-flash] [Task Task-48 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 335 ] [Mdl: gpt-4.1        ] [Task Task-49 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 335 ] [Mdl: gemini-2.5-flash] [Task Task-50 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 339 ] [Mdl: gpt-4.1        ] [Task Task-51 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 339 ] [Mdl: gemini-2.5-flash] [Task Task-52 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 344 ] [Mdl: gpt-4.1        ] [Task Task-53 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 344 ] [Mdl: gemini-2.5-flash] [Task Task-54 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 348 ] [Mdl: gpt-4.1        ] [Task Task-55 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 348 ] [Mdl: gemini-2.5-flash] [Task Task-56 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 368 ] [Mdl: gpt-4.1        ] [Task Task-57 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 368 ] [Mdl: gemini-2.5-flash] [Task Task-58 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 369 ] [Mdl: gpt-4.1        ] [Task Task-59 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 369 ] [Mdl: gemini-2.5-flash] [Task Task-60 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 377 ] [Mdl: gpt-4.1        ] [Task Task-61 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 377 ] [Mdl: gemini-2.5-flash] [Task Task-62 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 378 ] [Mdl: gpt-4.1        ] [Task Task-63 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 378 ] [Mdl: gemini-2.5-flash] [Task Task-64 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 379 ] [Mdl: gpt-4.1        ] [Task Task-65 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 379 ] [Mdl: gemini-2.5-flash] [Task Task-66 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 386 ] [Mdl: gpt-4.1        ] [Task Task-67 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 386 ] [Mdl: gemini-2.5-flash] [Task Task-68 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 398 ] [Mdl: gpt-4.1        ] [Task Task-69 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 398 ] [Mdl: gemini-2.5-flash] [Task Task-70 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 402 ] [Mdl: gpt-4.1        ] [Task Task-71 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 402 ] [Mdl: gemini-2.5-flash] [Task Task-72 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 417 ] [Mdl: gpt-4.1        ] [Task Task-73 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 417 ] [Mdl: gemini-2.5-flash] [Task Task-74 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 445 ] [Mdl: gpt-4.1        ] [Task Task-75 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 445 ] [Mdl: gemini-2.5-flash] [Task Task-76 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 456 ] [Mdl: gpt-4.1        ] [Task Task-77 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 456 ] [Mdl: gemini-2.5-flash] [Task Task-78 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 461 ] [Mdl: gpt-4.1        ] [Task Task-79 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 461 ] [Mdl: gemini-2.5-flash] [Task Task-80 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 469 ] [Mdl: gpt-4.1        ] [Task Task-81 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 469 ] [Mdl: gemini-2.5-flash] [Task Task-82 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 479 ] [Mdl: gpt-4.1        ] [Task Task-83 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 479 ] [Mdl: gemini-2.5-flash] [Task Task-84 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 492 ] [Mdl: gpt-4.1        ] [Task Task-85 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 492 ] [Mdl: gemini-2.5-flash] [Task Task-86 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 505 ] [Mdl: gpt-4.1        ] [Task Task-87 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 505 ] [Mdl: gemini-2.5-flash] [Task Task-88 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 508 ] [Mdl: gpt-4.1        ] [Task Task-89 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 508 ] [Mdl: gemini-2.5-flash] [Task Task-90 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 509 ] [Mdl: gpt-4.1        ] [Task Task-91 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 509 ] [Mdl: gemini-2.5-flash] [Task Task-92 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 519 ] [Mdl: gpt-4.1        ] [Task Task-93 ] Output file already exists.
# 2025-07-10T18:57:25.809+00:00 [SKIPPED] [Idx 519 ] [Mdl: gemini-2.5-flash] [Task Task-94 ] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 535 ] [Mdl: gpt-4.1        ] [Task Task-95 ] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 535 ] [Mdl: gemini-2.5-flash] [Task Task-96 ] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 547 ] [Mdl: gpt-4.1        ] [Task Task-97 ] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 547 ] [Mdl: gemini-2.5-flash] [Task Task-98 ] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 548 ] [Mdl: gpt-4.1        ] [Task Task-99 ] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 548 ] [Mdl: gemini-2.5-flash] [Task Task-100] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 556 ] [Mdl: gpt-4.1        ] [Task Task-101] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 556 ] [Mdl: gemini-2.5-flash] [Task Task-102] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 560 ] [Mdl: gpt-4.1        ] [Task Task-103] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 560 ] [Mdl: gemini-2.5-flash] [Task Task-104] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 567 ] [Mdl: gpt-4.1        ] [Task Task-105] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 567 ] [Mdl: gemini-2.5-flash] [Task Task-106] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 574 ] [Mdl: gpt-4.1        ] [Task Task-107] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [SKIPPED] [Idx 574 ] [Mdl: gemini-2.5-flash] [Task Task-108] Output file already exists.
# 2025-07-10T18:57:25.810+00:00 [ GRANT ] [Idx 578 ] [Mdl: gpt-4.1        ] [Task Task-109] Permission granted. Budget: 30000 -> 23238
# 2025-07-10T18:57:25.814+00:00 [SKIPPED] [Idx 578 ] [Mdl: gemini-2.5-flash] [Task Task-110] Output file already exists.
# 2025-07-10T18:57:25.814+00:00 [ GRANT ] [Idx 596 ] [Mdl: gpt-4.1        ] [Task Task-111] Permission granted. Budget: 23238 -> 16553
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 596 ] [Mdl: gemini-2.5-flash] [Task Task-112] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 613 ] [Mdl: gemini-2.5-flash] [Task Task-114] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 638 ] [Mdl: gemini-2.5-flash] [Task Task-116] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 652 ] [Mdl: gemini-2.5-flash] [Task Task-118] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 655 ] [Mdl: gemini-2.5-flash] [Task Task-120] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 659 ] [Mdl: gemini-2.5-flash] [Task Task-122] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 664 ] [Mdl: gemini-2.5-flash] [Task Task-124] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 673 ] [Mdl: gemini-2.5-flash] [Task Task-126] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 676 ] [Mdl: gemini-2.5-flash] [Task Task-128] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 688 ] [Mdl: gemini-2.5-flash] [Task Task-130] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 689 ] [Mdl: gemini-2.5-flash] [Task Task-132] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 699 ] [Mdl: gemini-2.5-flash] [Task Task-134] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 700 ] [Mdl: gemini-2.5-flash] [Task Task-136] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 716 ] [Mdl: gemini-2.5-flash] [Task Task-138] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 729 ] [Mdl: gemini-2.5-flash] [Task Task-140] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 734 ] [Mdl: gemini-2.5-flash] [Task Task-142] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 736 ] [Mdl: gemini-2.5-flash] [Task Task-144] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 737 ] [Mdl: gemini-2.5-flash] [Task Task-146] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 742 ] [Mdl: gemini-2.5-flash] [Task Task-148] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 745 ] [Mdl: gemini-2.5-flash] [Task Task-150] Output file already exists.
# 2025-07-10T18:57:25.815+00:00 [SKIPPED] [Idx 754 ] [Mdl: gemini-2.5-flash] [Task Task-152] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 765 ] [Mdl: gemini-2.5-flash] [Task Task-154] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 778 ] [Mdl: gemini-2.5-flash] [Task Task-156] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 788 ] [Mdl: gemini-2.5-flash] [Task Task-158] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 797 ] [Mdl: gemini-2.5-flash] [Task Task-160] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 800 ] [Mdl: gemini-2.5-flash] [Task Task-162] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 801 ] [Mdl: gemini-2.5-flash] [Task Task-164] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 809 ] [Mdl: gemini-2.5-flash] [Task Task-166] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 813 ] [Mdl: gemini-2.5-flash] [Task Task-168] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 814 ] [Mdl: gemini-2.5-flash] [Task Task-170] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 821 ] [Mdl: gemini-2.5-flash] [Task Task-172] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 825 ] [Mdl: gemini-2.5-flash] [Task Task-174] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 839 ] [Mdl: gemini-2.5-flash] [Task Task-176] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 846 ] [Mdl: gemini-2.5-flash] [Task Task-178] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 861 ] [Mdl: gemini-2.5-flash] [Task Task-180] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 870 ] [Mdl: gemini-2.5-flash] [Task Task-182] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 872 ] [Mdl: gemini-2.5-flash] [Task Task-184] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 885 ] [Mdl: gemini-2.5-flash] [Task Task-186] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 898 ] [Mdl: gemini-2.5-flash] [Task Task-188] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 908 ] [Mdl: gemini-2.5-flash] [Task Task-190] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 915 ] [Mdl: gemini-2.5-flash] [Task Task-192] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 918 ] [Mdl: gemini-2.5-flash] [Task Task-194] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 926 ] [Mdl: gemini-2.5-flash] [Task Task-196] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 933 ] [Mdl: gemini-2.5-flash] [Task Task-198] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 937 ] [Mdl: gemini-2.5-flash] [Task Task-200] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 975 ] [Mdl: gemini-2.5-flash] [Task Task-202] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 979 ] [Mdl: gemini-2.5-flash] [Task Task-204] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 996 ] [Mdl: gemini-2.5-flash] [Task Task-206] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1005] [Mdl: gemini-2.5-flash] [Task Task-208] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1012] [Mdl: gemini-2.5-flash] [Task Task-210] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1027] [Mdl: gemini-2.5-flash] [Task Task-212] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1033] [Mdl: gemini-2.5-flash] [Task Task-214] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1041] [Mdl: gemini-2.5-flash] [Task Task-216] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1043] [Mdl: gemini-2.5-flash] [Task Task-218] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1054] [Mdl: gemini-2.5-flash] [Task Task-220] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1065] [Mdl: gemini-2.5-flash] [Task Task-222] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1069] [Mdl: gemini-2.5-flash] [Task Task-224] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1084] [Mdl: gemini-2.5-flash] [Task Task-226] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1086] [Mdl: gemini-2.5-flash] [Task Task-228] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1124] [Mdl: gemini-2.5-flash] [Task Task-230] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1127] [Mdl: gemini-2.5-flash] [Task Task-232] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1131] [Mdl: gemini-2.5-flash] [Task Task-234] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1136] [Mdl: gemini-2.5-flash] [Task Task-236] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1154] [Mdl: gemini-2.5-flash] [Task Task-238] Output file already exists.
# 2025-07-10T18:57:25.816+00:00 [SKIPPED] [Idx 1166] [Mdl: gemini-2.5-flash] [Task Task-240] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1186] [Mdl: gemini-2.5-flash] [Task Task-242] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1188] [Mdl: gemini-2.5-flash] [Task Task-244] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1191] [Mdl: gemini-2.5-flash] [Task Task-246] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1202] [Mdl: gemini-2.5-flash] [Task Task-248] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1203] [Mdl: gemini-2.5-flash] [Task Task-250] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1210] [Mdl: gemini-2.5-flash] [Task Task-252] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1218] [Mdl: gemini-2.5-flash] [Task Task-254] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1222] [Mdl: gemini-2.5-flash] [Task Task-256] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1224] [Mdl: gemini-2.5-flash] [Task Task-258] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1226] [Mdl: gemini-2.5-flash] [Task Task-260] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1232] [Mdl: gemini-2.5-flash] [Task Task-262] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1233] [Mdl: gemini-2.5-flash] [Task Task-264] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1234] [Mdl: gemini-2.5-flash] [Task Task-266] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1239] [Mdl: gemini-2.5-flash] [Task Task-268] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1279] [Mdl: gemini-2.5-flash] [Task Task-270] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1283] [Mdl: gemini-2.5-flash] [Task Task-272] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1286] [Mdl: gemini-2.5-flash] [Task Task-274] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1293] [Mdl: gemini-2.5-flash] [Task Task-276] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1295] [Mdl: gemini-2.5-flash] [Task Task-278] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1297] [Mdl: gemini-2.5-flash] [Task Task-280] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1306] [Mdl: gemini-2.5-flash] [Task Task-282] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1311] [Mdl: gemini-2.5-flash] [Task Task-284] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1322] [Mdl: gemini-2.5-flash] [Task Task-286] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1329] [Mdl: gemini-2.5-flash] [Task Task-288] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1340] [Mdl: gemini-2.5-flash] [Task Task-290] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1342] [Mdl: gemini-2.5-flash] [Task Task-292] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1350] [Mdl: gemini-2.5-flash] [Task Task-294] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1363] [Mdl: gemini-2.5-flash] [Task Task-296] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1376] [Mdl: gemini-2.5-flash] [Task Task-298] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1382] [Mdl: gemini-2.5-flash] [Task Task-300] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1390] [Mdl: gemini-2.5-flash] [Task Task-302] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1396] [Mdl: gemini-2.5-flash] [Task Task-304] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1414] [Mdl: gemini-2.5-flash] [Task Task-306] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1424] [Mdl: gemini-2.5-flash] [Task Task-308] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1435] [Mdl: gemini-2.5-flash] [Task Task-310] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1441] [Mdl: gemini-2.5-flash] [Task Task-312] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1454] [Mdl: gemini-2.5-flash] [Task Task-314] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1457] [Mdl: gemini-2.5-flash] [Task Task-316] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1458] [Mdl: gemini-2.5-flash] [Task Task-318] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1459] [Mdl: gemini-2.5-flash] [Task Task-320] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1475] [Mdl: gemini-2.5-flash] [Task Task-322] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1489] [Mdl: gemini-2.5-flash] [Task Task-324] Output file already exists.
# 2025-07-10T18:57:25.817+00:00 [SKIPPED] [Idx 1495] [Mdl: gemini-2.5-flash] [Task Task-326] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1501] [Mdl: gemini-2.5-flash] [Task Task-328] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1502] [Mdl: gemini-2.5-flash] [Task Task-330] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1504] [Mdl: gemini-2.5-flash] [Task Task-332] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1534] [Mdl: gemini-2.5-flash] [Task Task-334] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1540] [Mdl: gemini-2.5-flash] [Task Task-336] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1548] [Mdl: gemini-2.5-flash] [Task Task-338] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1559] [Mdl: gemini-2.5-flash] [Task Task-340] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1577] [Mdl: gemini-2.5-flash] [Task Task-342] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1596] [Mdl: gemini-2.5-flash] [Task Task-344] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1597] [Mdl: gemini-2.5-flash] [Task Task-346] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1606] [Mdl: gemini-2.5-flash] [Task Task-348] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1610] [Mdl: gemini-2.5-flash] [Task Task-350] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1612] [Mdl: gemini-2.5-flash] [Task Task-352] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1617] [Mdl: gemini-2.5-flash] [Task Task-354] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1625] [Mdl: gemini-2.5-flash] [Task Task-356] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1629] [Mdl: gemini-2.5-flash] [Task Task-358] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1637] [Mdl: gemini-2.5-flash] [Task Task-360] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1666] [Mdl: gemini-2.5-flash] [Task Task-362] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1673] [Mdl: gemini-2.5-flash] [Task Task-364] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1674] [Mdl: gemini-2.5-flash] [Task Task-366] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1677] [Mdl: gemini-2.5-flash] [Task Task-368] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1678] [Mdl: gemini-2.5-flash] [Task Task-370] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1685] [Mdl: gemini-2.5-flash] [Task Task-372] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1688] [Mdl: gemini-2.5-flash] [Task Task-374] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1690] [Mdl: gemini-2.5-flash] [Task Task-376] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1695] [Mdl: gemini-2.5-flash] [Task Task-378] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1703] [Mdl: gemini-2.5-flash] [Task Task-380] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1706] [Mdl: gemini-2.5-flash] [Task Task-382] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1719] [Mdl: gemini-2.5-flash] [Task Task-384] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1725] [Mdl: gemini-2.5-flash] [Task Task-386] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1756] [Mdl: gemini-2.5-flash] [Task Task-388] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1760] [Mdl: gemini-2.5-flash] [Task Task-390] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1766] [Mdl: gemini-2.5-flash] [Task Task-392] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1771] [Mdl: gemini-2.5-flash] [Task Task-394] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1780] [Mdl: gemini-2.5-flash] [Task Task-396] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1798] [Mdl: gemini-2.5-flash] [Task Task-398] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1799] [Mdl: gemini-2.5-flash] [Task Task-400] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1813] [Mdl: gemini-2.5-flash] [Task Task-402] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1818] [Mdl: gemini-2.5-flash] [Task Task-404] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1825] [Mdl: gemini-2.5-flash] [Task Task-406] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1828] [Mdl: gemini-2.5-flash] [Task Task-408] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1835] [Mdl: gemini-2.5-flash] [Task Task-410] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1839] [Mdl: gemini-2.5-flash] [Task Task-412] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1841] [Mdl: gemini-2.5-flash] [Task Task-414] Output file already exists.
# 2025-07-10T18:57:25.818+00:00 [SKIPPED] [Idx 1854] [Mdl: gemini-2.5-flash] [Task Task-416] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1884] [Mdl: gemini-2.5-flash] [Task Task-418] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1915] [Mdl: gemini-2.5-flash] [Task Task-420] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1919] [Mdl: gemini-2.5-flash] [Task Task-422] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1923] [Mdl: gemini-2.5-flash] [Task Task-424] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1949] [Mdl: gemini-2.5-flash] [Task Task-426] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1955] [Mdl: gemini-2.5-flash] [Task Task-428] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1957] [Mdl: gemini-2.5-flash] [Task Task-430] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1976] [Mdl: gemini-2.5-flash] [Task Task-432] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1983] [Mdl: gemini-2.5-flash] [Task Task-434] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1988] [Mdl: gemini-2.5-flash] [Task Task-436] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 1994] [Mdl: gemini-2.5-flash] [Task Task-438] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2015] [Mdl: gemini-2.5-flash] [Task Task-440] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2016] [Mdl: gemini-2.5-flash] [Task Task-442] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2030] [Mdl: gemini-2.5-flash] [Task Task-444] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2050] [Mdl: gemini-2.5-flash] [Task Task-446] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2055] [Mdl: gemini-2.5-flash] [Task Task-448] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2060] [Mdl: gemini-2.5-flash] [Task Task-450] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2069] [Mdl: gemini-2.5-flash] [Task Task-452] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2076] [Mdl: gemini-2.5-flash] [Task Task-454] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2078] [Mdl: gemini-2.5-flash] [Task Task-456] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2085] [Mdl: gemini-2.5-flash] [Task Task-458] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2110] [Mdl: gemini-2.5-flash] [Task Task-460] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2156] [Mdl: gemini-2.5-flash] [Task Task-462] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2160] [Mdl: gemini-2.5-flash] [Task Task-464] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2181] [Mdl: gemini-2.5-flash] [Task Task-466] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2188] [Mdl: gemini-2.5-flash] [Task Task-468] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2189] [Mdl: gemini-2.5-flash] [Task Task-470] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2196] [Mdl: gemini-2.5-flash] [Task Task-472] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2211] [Mdl: gemini-2.5-flash] [Task Task-474] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2213] [Mdl: gemini-2.5-flash] [Task Task-476] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2279] [Mdl: gemini-2.5-flash] [Task Task-478] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2281] [Mdl: gemini-2.5-flash] [Task Task-480] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2289] [Mdl: gemini-2.5-flash] [Task Task-482] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2300] [Mdl: gemini-2.5-flash] [Task Task-484] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2306] [Mdl: gemini-2.5-flash] [Task Task-486] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2317] [Mdl: gemini-2.5-flash] [Task Task-488] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2320] [Mdl: gemini-2.5-flash] [Task Task-490] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2323] [Mdl: gemini-2.5-flash] [Task Task-492] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2327] [Mdl: gemini-2.5-flash] [Task Task-494] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2331] [Mdl: gemini-2.5-flash] [Task Task-496] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2337] [Mdl: gemini-2.5-flash] [Task Task-498] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2344] [Mdl: gemini-2.5-flash] [Task Task-500] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2346] [Mdl: gemini-2.5-flash] [Task Task-502] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2353] [Mdl: gemini-2.5-flash] [Task Task-504] Output file already exists.
# 2025-07-10T18:57:25.819+00:00 [SKIPPED] [Idx 2358] [Mdl: gemini-2.5-flash] [Task Task-506] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2364] [Mdl: gemini-2.5-flash] [Task Task-508] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2369] [Mdl: gemini-2.5-flash] [Task Task-510] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2372] [Mdl: gemini-2.5-flash] [Task Task-512] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2373] [Mdl: gemini-2.5-flash] [Task Task-514] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2376] [Mdl: gemini-2.5-flash] [Task Task-516] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2387] [Mdl: gemini-2.5-flash] [Task Task-518] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2392] [Mdl: gemini-2.5-flash] [Task Task-520] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2393] [Mdl: gemini-2.5-flash] [Task Task-522] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2401] [Mdl: gemini-2.5-flash] [Task Task-524] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2408] [Mdl: gemini-2.5-flash] [Task Task-526] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2413] [Mdl: gemini-2.5-flash] [Task Task-528] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2429] [Mdl: gemini-2.5-flash] [Task Task-530] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2460] [Mdl: gemini-2.5-flash] [Task Task-532] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2491] [Mdl: gemini-2.5-flash] [Task Task-534] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2497] [Mdl: gemini-2.5-flash] [Task Task-536] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2502] [Mdl: gemini-2.5-flash] [Task Task-538] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2508] [Mdl: gemini-2.5-flash] [Task Task-540] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2534] [Mdl: gemini-2.5-flash] [Task Task-542] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2554] [Mdl: gemini-2.5-flash] [Task Task-544] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2564] [Mdl: gemini-2.5-flash] [Task Task-546] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2567] [Mdl: gemini-2.5-flash] [Task Task-548] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2576] [Mdl: gemini-2.5-flash] [Task Task-550] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2585] [Mdl: gemini-2.5-flash] [Task Task-552] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2592] [Mdl: gemini-2.5-flash] [Task Task-554] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2605] [Mdl: gemini-2.5-flash] [Task Task-556] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2625] [Mdl: gemini-2.5-flash] [Task Task-558] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2626] [Mdl: gemini-2.5-flash] [Task Task-560] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2685] [Mdl: gemini-2.5-flash] [Task Task-562] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2693] [Mdl: gemini-2.5-flash] [Task Task-564] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2702] [Mdl: gemini-2.5-flash] [Task Task-566] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2705] [Mdl: gemini-2.5-flash] [Task Task-568] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2738] [Mdl: gemini-2.5-flash] [Task Task-570] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2743] [Mdl: gemini-2.5-flash] [Task Task-572] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2784] [Mdl: gemini-2.5-flash] [Task Task-574] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2785] [Mdl: gemini-2.5-flash] [Task Task-576] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2809] [Mdl: gemini-2.5-flash] [Task Task-578] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2812] [Mdl: gemini-2.5-flash] [Task Task-580] Output file already exists.
# 2025-07-10T18:57:25.820+00:00 [SKIPPED] [Idx 2824] [Mdl: gemini-2.5-flash] [Task Task-582] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2826] [Mdl: gemini-2.5-flash] [Task Task-584] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2849] [Mdl: gemini-2.5-flash] [Task Task-586] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2855] [Mdl: gemini-2.5-flash] [Task Task-588] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2862] [Mdl: gemini-2.5-flash] [Task Task-590] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2869] [Mdl: gemini-2.5-flash] [Task Task-592] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2872] [Mdl: gemini-2.5-flash] [Task Task-594] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2876] [Mdl: gemini-2.5-flash] [Task Task-596] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2888] [Mdl: gemini-2.5-flash] [Task Task-598] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2889] [Mdl: gemini-2.5-flash] [Task Task-600] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2894] [Mdl: gemini-2.5-flash] [Task Task-602] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2897] [Mdl: gemini-2.5-flash] [Task Task-604] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2912] [Mdl: gemini-2.5-flash] [Task Task-606] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2918] [Mdl: gemini-2.5-flash] [Task Task-608] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2935] [Mdl: gemini-2.5-flash] [Task Task-610] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2942] [Mdl: gemini-2.5-flash] [Task Task-612] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2943] [Mdl: gemini-2.5-flash] [Task Task-614] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2949] [Mdl: gemini-2.5-flash] [Task Task-616] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2951] [Mdl: gemini-2.5-flash] [Task Task-618] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2967] [Mdl: gemini-2.5-flash] [Task Task-620] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2981] [Mdl: gemini-2.5-flash] [Task Task-622] Output file already exists.
# 2025-07-10T18:57:25.821+00:00 [SKIPPED] [Idx 2993] [Mdl: gemini-2.5-flash] [Task Task-624] Output file already exists.
# 2025-07-10T18:57:30.811+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 20553 / 30000
# 2025-07-10T18:57:40.821+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 28553 / 30000
# 2025-07-10T18:57:50.831+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T18:58:00.843+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T18:58:06.947+00:00 [SUCCESS] [Idx 596 ] [Mdl: gpt-4.1        ] [Task Task-111] Call OK. Usage: {"input_tokens": 4793, "output_tokens": 644, "cached_tokens": 4736}
# 2025-07-10T18:58:06.947+00:00 [REFUND ] [Idx 596 ] [Mdl: gpt-4.1        ] [Task Task-111] Correcting estimate. Budget restored by 1248 -> 31248.
# 2025-07-10T18:58:06.949+00:00 [ GRANT ] [Idx 613 ] [Mdl: gpt-4.1        ] [Task Task-113] Permission granted. Budget: 31248 -> 24592
# 2025-07-10T18:58:10.853+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 27792 / 30000
# 2025-07-10T18:58:13.497+00:00 [SUCCESS] [Idx 578 ] [Mdl: gpt-4.1        ] [Task Task-109] Call OK. Usage: {"input_tokens": 4857, "output_tokens": 1054, "cached_tokens": 4736}
# 2025-07-10T18:58:13.498+00:00 [REFUND ] [Idx 578 ] [Mdl: gpt-4.1        ] [Task Task-109] Correcting estimate. Budget restored by 851 -> 30243.
# 2025-07-10T18:58:13.499+00:00 [ GRANT ] [Idx 638 ] [Mdl: gpt-4.1        ] [Task Task-115] Permission granted. Budget: 30243 -> 23557
# 2025-07-10T18:58:17.491+00:00 [SUCCESS] [Idx 613 ] [Mdl: gpt-4.1        ] [Task Task-113] Call OK. Usage: {"input_tokens": 4711, "output_tokens": 447, "cached_tokens": 4480}
# 2025-07-10T18:58:17.491+00:00 [REFUND ] [Idx 613 ] [Mdl: gpt-4.1        ] [Task Task-113] Correcting estimate. Budget restored by 1498 -> 28255.
# 2025-07-10T18:58:17.493+00:00 [ GRANT ] [Idx 652 ] [Mdl: gpt-4.1        ] [Task Task-117] Permission granted. Budget: 28255 -> 21617
# 2025-07-10T18:58:20.865+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 24817 / 30000
# 2025-07-10T18:58:21.897+00:00 [SUCCESS] [Idx 652 ] [Mdl: gpt-4.1        ] [Task Task-117] Call OK. Usage: {"input_tokens": 4677, "output_tokens": 298, "cached_tokens": 4480}
# 2025-07-10T18:58:21.897+00:00 [REFUND ] [Idx 652 ] [Mdl: gpt-4.1        ] [Task Task-117] Correcting estimate. Budget restored by 1663 -> 27280.
# 2025-07-10T18:58:21.899+00:00 [ GRANT ] [Idx 655 ] [Mdl: gpt-4.1        ] [Task Task-119] Permission granted. Budget: 27280 -> 20613
# 2025-07-10T18:58:27.016+00:00 [SUCCESS] [Idx 638 ] [Mdl: gpt-4.1        ] [Task Task-115] Call OK. Usage: {"input_tokens": 4833, "output_tokens": 1196, "cached_tokens": 4480}
# 2025-07-10T18:58:27.017+00:00 [REFUND ] [Idx 638 ] [Mdl: gpt-4.1        ] [Task Task-115] Correcting estimate. Budget restored by 657 -> 25270.
# 2025-07-10T18:58:27.018+00:00 [ GRANT ] [Idx 659 ] [Mdl: gpt-4.1        ] [Task Task-121] Permission granted. Budget: 25270 -> 18524
# 2025-07-10T18:58:28.041+00:00 [SUCCESS] [Idx 655 ] [Mdl: gpt-4.1        ] [Task Task-119] Call OK. Usage: {"input_tokens": 4701, "output_tokens": 334, "cached_tokens": 4480}
# 2025-07-10T18:58:28.041+00:00 [REFUND ] [Idx 655 ] [Mdl: gpt-4.1        ] [Task Task-119] Correcting estimate. Budget restored by 1632 -> 20956.
# 2025-07-10T18:58:28.043+00:00 [ GRANT ] [Idx 664 ] [Mdl: gpt-4.1        ] [Task Task-123] Permission granted. Budget: 20956 -> 14274
# 2025-07-10T18:58:30.875+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 16674 / 30000
# 2025-07-10T18:58:34.593+00:00 [SUCCESS] [Idx 664 ] [Mdl: gpt-4.1        ] [Task Task-123] Call OK. Usage: {"input_tokens": 4710, "output_tokens": 411, "cached_tokens": 4480}
# 2025-07-10T18:58:34.593+00:00 [REFUND ] [Idx 664 ] [Mdl: gpt-4.1        ] [Task Task-123] Correcting estimate. Budget restored by 1561 -> 20635.
# 2025-07-10T18:58:34.595+00:00 [ GRANT ] [Idx 673 ] [Mdl: gpt-4.1        ] [Task Task-125] Permission granted. Budget: 20635 -> 14002
# 2025-07-10T18:58:40.887+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 19602 / 30000
# ...
# 2025-07-10T19:38:23.382+00:00 [REFUND ] [Idx 2785] [Mdl: gpt-4.1        ] [Task Task-575] Correcting estimate. Budget restored by 1383 -> 31325.
# 2025-07-10T19:38:23.384+00:00 [ GRANT ] [Idx 2809] [Mdl: gpt-4.1        ] [Task Task-577] Permission granted. Budget: 31325 -> 24542
# 2025-07-10T19:38:26.254+00:00 [SUCCESS] [Idx 2784] [Mdl: gpt-4.1        ] [Task Task-573] Call OK. Usage: {"input_tokens": 4774, "output_tokens": 589, "cached_tokens": 4480}
# 2025-07-10T19:38:26.254+00:00 [REFUND ] [Idx 2784] [Mdl: gpt-4.1        ] [Task Task-573] Correcting estimate. Budget restored by 1324 -> 28266.
# 2025-07-10T19:38:26.256+00:00 [ GRANT ] [Idx 2812] [Mdl: gpt-4.1        ] [Task Task-579] Permission granted. Budget: 28266 -> 21631
# 2025-07-10T19:38:30.781+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 25631 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2809). Retrying in 10.11s... (Attempt 1/10)
# 2025-07-10T19:38:40.793+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:38:42.431+00:00 [SUCCESS] [Idx 2812] [Mdl: gpt-4.1        ] [Task Task-579] Call OK. Usage: {"input_tokens": 4675, "output_tokens": 333, "cached_tokens": 4480}
# 2025-07-10T19:38:42.431+00:00 [REFUND ] [Idx 2812] [Mdl: gpt-4.1        ] [Task Task-579] Correcting estimate. Budget restored by 1627 -> 31627.
# 2025-07-10T19:38:42.433+00:00 [ GRANT ] [Idx 2824] [Mdl: gpt-4.1        ] [Task Task-581] Permission granted. Budget: 31627 -> 24974
# 2025-07-10T19:38:50.804+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:38:54.516+00:00 [SUCCESS] [Idx 2824] [Mdl: gpt-4.1        ] [Task Task-581] Call OK. Usage: {"input_tokens": 4705, "output_tokens": 477, "cached_tokens": 4480}
# 2025-07-10T19:38:54.516+00:00 [REFUND ] [Idx 2824] [Mdl: gpt-4.1        ] [Task Task-581] Correcting estimate. Budget restored by 1471 -> 31471.
# 2025-07-10T19:38:54.519+00:00 [ GRANT ] [Idx 2826] [Mdl: gpt-4.1        ] [Task Task-583] Permission granted. Budget: 31471 -> 24736
# 2025-07-10T19:39:00.815+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:39:10.827+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:39:20.839+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:39:24.213+00:00 [SUCCESS] [Idx 2826] [Mdl: gpt-4.1        ] [Task Task-583] Call OK. Usage: {"input_tokens": 4791, "output_tokens": 488, "cached_tokens": 4480}
# 2025-07-10T19:39:24.213+00:00 [REFUND ] [Idx 2826] [Mdl: gpt-4.1        ] [Task Task-583] Correcting estimate. Budget restored by 1456 -> 31456.
# 2025-07-10T19:39:24.215+00:00 [ GRANT ] [Idx 2849] [Mdl: gpt-4.1        ] [Task Task-585] Permission granted. Budget: 31456 -> 24781
# 2025-07-10T19:39:25.848+00:00 [SUCCESS] [Idx 2809] [Mdl: gpt-4.1        ] [Task Task-577] Call OK. Usage: {"input_tokens": 4858, "output_tokens": 665, "cached_tokens": 4480}
# 2025-07-10T19:39:25.848+00:00 [REFUND ] [Idx 2809] [Mdl: gpt-4.1        ] [Task Task-577] Correcting estimate. Budget restored by 1260 -> 27641.
# 2025-07-10T19:39:25.849+00:00 [ GRANT ] [Idx 2855] [Mdl: gpt-4.1        ] [Task Task-587] Permission granted. Budget: 27641 -> 20894
# 2025-07-10T19:39:29.742+00:00 [SUCCESS] [Idx 2849] [Mdl: gpt-4.1        ] [Task Task-585] Call OK. Usage: {"input_tokens": 4739, "output_tokens": 436, "cached_tokens": 4480}
# 2025-07-10T19:39:29.742+00:00 [REFUND ] [Idx 2849] [Mdl: gpt-4.1        ] [Task Task-585] Correcting estimate. Budget restored by 1500 -> 24794.
# 2025-07-10T19:39:29.744+00:00 [ GRANT ] [Idx 2862] [Mdl: gpt-4.1        ] [Task Task-589] Permission granted. Budget: 24794 -> 18091
# 2025-07-10T19:39:30.850+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 19691 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2855). Retrying in 10.37s... (Attempt 1/10)
# 2025-07-10T19:39:37.111+00:00 [SUCCESS] [Idx 2862] [Mdl: gpt-4.1        ] [Task Task-589] Call OK. Usage: {"input_tokens": 4779, "output_tokens": 519, "cached_tokens": 4480}
# 2025-07-10T19:39:37.112+00:00 [REFUND ] [Idx 2862] [Mdl: gpt-4.1        ] [Task Task-589] Correcting estimate. Budget restored by 1405 -> 25896.
# 2025-07-10T19:39:37.114+00:00 [ GRANT ] [Idx 2869] [Mdl: gpt-4.1        ] [Task Task-591] Permission granted. Budget: 25896 -> 19255
# 2025-07-10T19:39:40.861+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 22455 / 30000
# 2025-07-10T19:39:47.970+00:00 [SUCCESS] [Idx 2869] [Mdl: gpt-4.1        ] [Task Task-591] Call OK. Usage: {"input_tokens": 4691, "output_tokens": 413, "cached_tokens": 4480}
# 2025-07-10T19:39:47.970+00:00 [REFUND ] [Idx 2869] [Mdl: gpt-4.1        ] [Task Task-591] Correcting estimate. Budget restored by 1537 -> 29592.
# 2025-07-10T19:39:47.972+00:00 [ GRANT ] [Idx 2872] [Mdl: gpt-4.1        ] [Task Task-593] Permission granted. Budget: 29592 -> 22939
# 2025-07-10T19:39:50.873+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 25339 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2855). Retrying in 20.64s... (Attempt 2/10)
# 2025-07-10T19:39:56.161+00:00 [SUCCESS] [Idx 2872] [Mdl: gpt-4.1        ] [Task Task-593] Call OK. Usage: {"input_tokens": 4680, "output_tokens": 358, "cached_tokens": 4480}
# 2025-07-10T19:39:56.161+00:00 [REFUND ] [Idx 2872] [Mdl: gpt-4.1        ] [Task Task-593] Correcting estimate. Budget restored by 1615 -> 30954.
# 2025-07-10T19:39:56.162+00:00 [ GRANT ] [Idx 2876] [Mdl: gpt-4.1        ] [Task Task-595] Permission granted. Budget: 30954 -> 24247
# 2025-07-10T19:40:00.886+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 28247 / 30000
# 2025-07-10T19:40:10.499+00:00 [SUCCESS] [Idx 2876] [Mdl: gpt-4.1        ] [Task Task-595] Call OK. Usage: {"input_tokens": 4772, "output_tokens": 464, "cached_tokens": 4480}
# 2025-07-10T19:40:10.499+00:00 [REFUND ] [Idx 2876] [Mdl: gpt-4.1        ] [Task Task-595] Correcting estimate. Budget restored by 1471 -> 31471.
# 2025-07-10T19:40:10.501+00:00 [ GRANT ] [Idx 2888] [Mdl: gpt-4.1        ] [Task Task-597] Permission granted. Budget: 31471 -> 24754
# 2025-07-10T19:40:10.898+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 25554 / 30000
# 2025-07-10T19:40:20.910+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:40:25.653+00:00 [SUCCESS] [Idx 2888] [Mdl: gpt-4.1        ] [Task Task-597] Call OK. Usage: {"input_tokens": 4784, "output_tokens": 811, "cached_tokens": 4480}
# 2025-07-10T19:40:25.653+00:00 [REFUND ] [Idx 2888] [Mdl: gpt-4.1        ] [Task Task-597] Correcting estimate. Budget restored by 1122 -> 31122.
# 2025-07-10T19:40:25.655+00:00 [ GRANT ] [Idx 2889] [Mdl: gpt-4.1        ] [Task Task-599] Permission granted. Budget: 31122 -> 24444
# 2025-07-10T19:40:30.585+00:00 [SUCCESS] [Idx 2855] [Mdl: gpt-4.1        ] [Task Task-587] Call OK. Usage: {"input_tokens": 4864, "output_tokens": 836, "cached_tokens": 4480}
# 2025-07-10T19:40:30.585+00:00 [REFUND ] [Idx 2855] [Mdl: gpt-4.1        ] [Task Task-587] Correcting estimate. Budget restored by 1047 -> 29491.
# 2025-07-10T19:40:30.587+00:00 [ GRANT ] [Idx 2894] [Mdl: gpt-4.1        ] [Task Task-601] Permission granted. Budget: 29491 -> 22798
# 2025-07-10T19:40:30.919+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 23598 / 30000
# 2025-07-10T19:40:40.931+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:40:45.104+00:00 [SUCCESS] [Idx 2894] [Mdl: gpt-4.1        ] [Task Task-601] Call OK. Usage: {"input_tokens": 4729, "output_tokens": 501, "cached_tokens": 4480}
# 2025-07-10T19:40:45.104+00:00 [REFUND ] [Idx 2894] [Mdl: gpt-4.1        ] [Task Task-601] Correcting estimate. Budget restored by 1463 -> 31463.
# 2025-07-10T19:40:45.105+00:00 [ GRANT ] [Idx 2897] [Mdl: gpt-4.1        ] [Task Task-603] Permission granted. Budget: 31463 -> 24730
# 2025-07-10T19:40:45.725+00:00 [SUCCESS] [Idx 2889] [Mdl: gpt-4.1        ] [Task Task-599] Call OK. Usage: {"input_tokens": 4730, "output_tokens": 592, "cached_tokens": 4480}
# 2025-07-10T19:40:45.725+00:00 [REFUND ] [Idx 2889] [Mdl: gpt-4.1        ] [Task Task-599] Correcting estimate. Budget restored by 1356 -> 26086.
# 2025-07-10T19:40:45.727+00:00 [ GRANT ] [Idx 2912] [Mdl: gpt-4.1        ] [Task Task-605] Permission granted. Budget: 26086 -> 19381
# 2025-07-10T19:40:50.942+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 24181 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2897). Retrying in 10.71s... (Attempt 1/10)
# 2025-07-10T19:41:00.954+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:41:04.040+00:00 [SUCCESS] [Idx 2912] [Mdl: gpt-4.1        ] [Task Task-605] Call OK. Usage: {"input_tokens": 4753, "output_tokens": 556, "cached_tokens": 4480}
# 2025-07-10T19:41:04.040+00:00 [REFUND ] [Idx 2912] [Mdl: gpt-4.1        ] [Task Task-605] Correcting estimate. Budget restored by 1396 -> 31396.
# 2025-07-10T19:41:04.041+00:00 [ GRANT ] [Idx 2918] [Mdl: gpt-4.1        ] [Task Task-607] Permission granted. Budget: 31396 -> 24703
# 2025-07-10T19:41:10.966+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:41:11.564+00:00 [SUCCESS] [Idx 2918] [Mdl: gpt-4.1        ] [Task Task-607] Call OK. Usage: {"input_tokens": 4766, "output_tokens": 472, "cached_tokens": 4480}
# 2025-07-10T19:41:11.564+00:00 [REFUND ] [Idx 2918] [Mdl: gpt-4.1        ] [Task Task-607] Correcting estimate. Budget restored by 1455 -> 31455.
# 2025-07-10T19:41:11.566+00:00 [ GRANT ] [Idx 2935] [Mdl: gpt-4.1        ] [Task Task-609] Permission granted. Budget: 31455 -> 24792
# 2025-07-10T19:41:20.978+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:41:26.686+00:00 [SUCCESS] [Idx 2935] [Mdl: gpt-4.1        ] [Task Task-609] Call OK. Usage: {"input_tokens": 4721, "output_tokens": 457, "cached_tokens": 4480}
# 2025-07-10T19:41:26.686+00:00 [REFUND ] [Idx 2935] [Mdl: gpt-4.1        ] [Task Task-609] Correcting estimate. Budget restored by 1485 -> 31485.
# 2025-07-10T19:41:26.688+00:00 [ GRANT ] [Idx 2942] [Mdl: gpt-4.1        ] [Task Task-611] Permission granted. Budget: 31485 -> 24815
# 2025-07-10T19:41:26.765+00:00 [SUCCESS] [Idx 2897] [Mdl: gpt-4.1        ] [Task Task-603] Call OK. Usage: {"input_tokens": 4810, "output_tokens": 670, "cached_tokens": 4480}
# 2025-07-10T19:41:26.765+00:00 [REFUND ] [Idx 2897] [Mdl: gpt-4.1        ] [Task Task-603] Correcting estimate. Budget restored by 1253 -> 26068.
# 2025-07-10T19:41:26.766+00:00 [ GRANT ] [Idx 2943] [Mdl: gpt-4.1        ] [Task Task-613] Permission granted. Budget: 26068 -> 19303
# 2025-07-10T19:41:30.989+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 23303 / 30000
# 🕒 Rate limit on gpt-4.1 (Index 2943). Retrying in 10.14s... (Attempt 1/10)
# 2025-07-10T19:41:43.071+00:00 [SUCCESS] [Idx 2942] [Mdl: gpt-4.1        ] [Task Task-611] Call OK. Usage: {"input_tokens": 4706, "output_tokens": 373, "cached_tokens": 4480}
# 2025-07-10T19:41:43.071+00:00 [REFUND ] [Idx 2942] [Mdl: gpt-4.1        ] [Task Task-611] Correcting estimate. Budget restored by 1591 -> 31591.
# 2025-07-10T19:41:43.073+00:00 [ GRANT ] [Idx 2949] [Mdl: gpt-4.1        ] [Task Task-615] Permission granted. Budget: 31591 -> 24858
# 2025-07-10T19:41:50.010+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:41:56.160+00:00 [SUCCESS] [Idx 2949] [Mdl: gpt-4.1        ] [Task Task-615] Call OK. Usage: {"input_tokens": 4784, "output_tokens": 552, "cached_tokens": 4480}
# 2025-07-10T19:41:56.160+00:00 [REFUND ] [Idx 2949] [Mdl: gpt-4.1        ] [Task Task-615] Correcting estimate. Budget restored by 1397 -> 31397.
# 2025-07-10T19:41:56.162+00:00 [ GRANT ] [Idx 2951] [Mdl: gpt-4.1        ] [Task Task-617] Permission granted. Budget: 31397 -> 24742
# 🕒 Rate limit on gpt-4.1 (Index 2943). Retrying in 20.19s... (Attempt 2/10)
# 2025-07-10T19:42:00.022+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 27942 / 30000
# 2025-07-10T19:42:03.752+00:00 [SUCCESS] [Idx 2951] [Mdl: gpt-4.1        ] [Task Task-617] Call OK. Usage: {"input_tokens": 4685, "output_tokens": 357, "cached_tokens": 4480}
# 2025-07-10T19:42:03.752+00:00 [REFUND ] [Idx 2951] [Mdl: gpt-4.1        ] [Task Task-617] Correcting estimate. Budget restored by 1613 -> 31613.
# 2025-07-10T19:42:03.753+00:00 [ GRANT ] [Idx 2967] [Mdl: gpt-4.1        ] [Task Task-619] Permission granted. Budget: 31613 -> 24903
# 2025-07-10T19:42:10.034+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:42:20.046+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:42:28.536+00:00 [SUCCESS] [Idx 2967] [Mdl: gpt-4.1        ] [Task Task-619] Call OK. Usage: {"input_tokens": 4751, "output_tokens": 565, "cached_tokens": 4480}
# 2025-07-10T19:42:28.536+00:00 [REFUND ] [Idx 2967] [Mdl: gpt-4.1        ] [Task Task-619] Correcting estimate. Budget restored by 1394 -> 31394.
# 2025-07-10T19:42:28.537+00:00 [ GRANT ] [Idx 2981] [Mdl: gpt-4.1        ] [Task Task-621] Permission granted. Budget: 31394 -> 24747
# 2025-07-10T19:42:29.608+00:00 [SUCCESS] [Idx 2943] [Mdl: gpt-4.1        ] [Task Task-613] Call OK. Usage: {"input_tokens": 4828, "output_tokens": 765, "cached_tokens": 4480}
# 2025-07-10T19:42:29.608+00:00 [REFUND ] [Idx 2943] [Mdl: gpt-4.1        ] [Task Task-613] Correcting estimate. Budget restored by 1172 -> 26719.
# 2025-07-10T19:42:29.610+00:00 [ GRANT ] [Idx 2993] [Mdl: gpt-4.1        ] [Task Task-623] Permission granted. Budget: 26719 -> 20066
# 2025-07-10T19:42:30.058+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 20866 / 30000
# 2025-07-10T19:42:32.556+00:00 [SUCCESS] [Idx 2981] [Mdl: gpt-4.1        ] [Task Task-621] Call OK. Usage: {"input_tokens": 4686, "output_tokens": 332, "cached_tokens": 4480}
# 2025-07-10T19:42:32.556+00:00 [REFUND ] [Idx 2981] [Mdl: gpt-4.1        ] [Task Task-621] Correcting estimate. Budget restored by 1629 -> 24095.
# 2025-07-10T19:42:40.071+00:00 [REFILL ] [Idx -1  ] [Mdl: Coordinator    ] [Task Task-2  ] Bucket budget at 30000 / 30000
# 2025-07-10T19:42:46.971+00:00 [SUCCESS] [Idx 2993] [Mdl: gpt-4.1        ] [Task Task-623] Call OK. Usage: {"input_tokens": 4728, "output_tokens": 502, "cached_tokens": 4480}
# 2025-07-10T19:42:46.971+00:00 [REFUND ] [Idx 2993] [Mdl: gpt-4.1        ] [Task Task-623] Correcting estimate. Budget restored by 1423 -> 31423.
#
# --- Manifest Generation Complete ---
# Processed 311 indices in 2721.19 seconds.
# Performance log saved to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/tier-manifests-gen-txt/tier2/generation_performance_20250710_194246.csv
# Success rate: 258/622 (41.5%)
#
# --- Test Run Performance Summary ---
#   provider             model  index   status  time_s  input_tokens  \
# 0   openai           gpt-4.1    210  Skipped     0.0             0
# 1   google  gemini-2.5-flash    210  Skipped     0.0             0
# 2   openai           gpt-4.1    211  Skipped     0.0             0
# 3   google  gemini-2.5-flash    211  Skipped     0.0             0
# 4   openai           gpt-4.1    215  Skipped     0.0             0
#
#    output_tokens  cached_tokens              utc_completed
# 0              0              0  2025-07-10T18:57:25+00:00
# 1              0              0  2025-07-10T18:57:25+00:00
# 2              0              0  2025-07-10T18:57:25+00:00
# 3              0              0  2025-07-10T18:57:25+00:00
# 4              0              0  2025-07-10T18:57:25+00:00
