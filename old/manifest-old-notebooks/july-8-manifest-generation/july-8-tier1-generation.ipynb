# %% [markdown]
# ### Basic imports

# %%
import json
import re
from pathlib import Path
from typing import Dict, Any, List
import pandas as pd
from IPython.display import display, Markdown
from datasets import load_dataset

# %% [markdown]
# ### Directories and Paths

# %%
def find_project_root():
    """Traverse upwards to find the project root, marked by the .git folder."""
    current_path = Path.cwd()
    while current_path != current_path.parent:
        if (current_path / ".git").is_dir():
            return current_path
        current_path = current_path.parent
    raise FileNotFoundError("Could not find project root. Is this a git repository?")

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / 'data'
MANIFEST_OUTPUT_DIR = DATA_DIR / "july-8-manifests-raw"
SAMPLE_MANIFEST_DIR = DATA_DIR / "july-7-sample-manifests"
TIER_OUTPUT_DIRS = {f"tier{i}": MANIFEST_OUTPUT_DIR / f"tier{i}" for i in range(1, 6)}
TIER_SAMPLE_DIRS = {f"tier{i}": SAMPLE_MANIFEST_DIR / f"tier{i}" for i in range(1, 6)}

# Make the directory for the tier if it doesn't exist
for tier_dir in TIER_OUTPUT_DIRS.values():
    tier_dir.mkdir(parents=True, exist_ok=True)

for tier_dir in TIER_SAMPLE_DIRS.values():
    tier_dir.mkdir(parents=True, exist_ok=True)

print(f"Project root found at: {PROJECT_ROOT}")
print(f"Data directory found at: {DATA_DIR}")
print(f"Raw manifest output directory set to: {MANIFEST_OUTPUT_DIR}")
# Out:
# Project root found at: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math
# Data directory found at: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data
# Raw manifest output directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/july-8-manifests-raw

# %% [markdown]
# ### Loading the dataset

# %%
# Load the GSM8K dataset
GSM8K_TRAIN = load_dataset("gsm8k", "main", split="train")

# %%
def build_solution_mapping(
        index: int, 
        dataset: 'datasets.Dataset' = GSM8K_TRAIN,
        exclude_FA: bool = True
    ):
    """
    Extracts the natural language solution for a given problem index,
    cleans it, and structures it into a line-numbered dictionary.
    """
    solution_mapping = {}
    solution_text = dataset[index]["answer"]
    lines = [ln.strip() for ln in solution_text.splitlines() if ln.strip()]

    # Improved regex to handle commas in the final answer
    if lines and re.match(r"^####\s*[\d\.,]+$", lines[-1]):
        solution_mapping["FA"] = lines.pop(-1).strip()

    for i, line in enumerate(lines, 1):
        solution_mapping[f"L{i}"] = line

    if exclude_FA and "FA" in solution_mapping:
        del solution_mapping["FA"]

    return solution_mapping

def wrapper(index: int):
    sample = GSM8K_TRAIN[index]
    to_return = "=" * 50 + "\n\n"
    to_return += f"**Index:** {index}\n\n"
    to_return += "**Question:**\n"
    to_return += f"{sample['question']}\n\n"
    to_return += "**Solution mapping:**\n"
    to_return += f"{build_solution_mapping(index, GSM8K_TRAIN)}\n\n"
    return to_return

# %%
print(wrapper(2990))
# Out:
# ==================================================
#
# **Index:** 2990
#
# **Question:**
# A dragon hoards jewels and gold in its cave. A jealous king snuck in and stole three prize jewels. The dragon burned him to a crisp and stole back its jewels, along with twice as many of the king’s crown jewels from his crown that melted in the dragon’s fire. The new jewels were a third of the number of jewels the dragon had owned before. How many jewels did the dragon own in the end?
#
# **Solution mapping:**
# {'L1': 'The dragon stole 2 * 3 = <<2*3=6>>6 of the king’s crown jewels.', 'L2': 'The dragon owned 6 * 3 = <<6*3=18>>18 jewels before the theft.', 'L3': 'Thus, the dragon owned 18 + 6 = <<18+6=24>>24 jewels in the end.'}

# %% [markdown]
# ### Generating tier lists

# %%
def has_computational_division(solution_text: str) -> bool:
    """Returns True if a '/' is followed by optional whitespace and then a digit."""
    pattern = re.compile(r'/\s*\d')
    return bool(pattern.search(solution_text))

def has_float(solution_text: str) -> bool:
    """Returns True if the solution text contains a floating-point number."""
    pattern = re.compile(r'(?<!\d)\.\d+|\d+\.\d+')
    return bool(pattern.search(solution_text))

def is_symbolic(solution_text: str) -> bool:
    """Returns True if the solution contains a symbolic reasoning line (Let @ ...)."""
    pattern = re.compile(r'^Let [a-zA-Z] ', re.MULTILINE)
    return bool(pattern.search(solution_text))

def mutually_disjoint_tiers(dataset):
    tiers = {}
    symbolic_set = set(
        idx for idx, sample in enumerate(dataset)
        if is_symbolic(sample.get("answer", ""))
    )
    non_symbolic_indices = [
        idx for idx in range(len(dataset)) if idx not in symbolic_set
    ]

    # Tier 1: Only integer arithmetic (no floats, no computational division)
    tiers["tier1"] = sorted([
        idx for idx in non_symbolic_indices
        if not has_float(dataset[idx].get("answer", "")) and not has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 2: Float arithmetic, no computational division
    tiers["tier2"] = sorted([
        idx for idx in non_symbolic_indices
        if has_float(dataset[idx].get("answer", "")) and not has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 3: Computational division, no floats
    tiers["tier3"] = sorted([
        idx for idx in non_symbolic_indices
        if not has_float(dataset[idx].get("answer", "")) and has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 4: Both floats and computational division
    tiers["tier4"] = sorted([
        idx for idx in non_symbolic_indices
        if has_float(dataset[idx].get("answer", "")) and has_computational_division(dataset[idx].get("answer", ""))
    ])

    # Tier 5: Symbolic reasoning (Let @ ...)
    tiers["tier5"] = sorted(symbolic_set)

    return tiers

TIER_LISTS = mutually_disjoint_tiers(GSM8K_TRAIN)

# Display the number of samples in each tier
for tier, indices in TIER_LISTS.items():
    print(f"{tier:<10}: {len(indices)} samples")
print(f"{'Total':<10}: {len(GSM8K_TRAIN)} samples")
# Out:
# tier1     : 2767 samples
# tier2     : 837 samples
# tier3     : 3113 samples
# tier4     : 544 samples
# tier5     : 212 samples
# Total     : 7473 samples

# %% [markdown]
# ### Load the system prompt and static prefixes for each tier's user prompt

# %%
SYSTEM_PROMPT = """You are a data formalization expert who excels in mathematical reasoning and writing python code. You will be presented with a math word problem accompanied by a step-by-step natural language solution. You goal is to carefully and meticulously analyze the given question and solution, and formalize it by converting it into a structured json object that deconstructs the logic of the solution.

You MUST follow all rules and formatting instructions provided in the user prompt without deviation. Your entire output MUST be a single JSON object wrapped in ```json ... ```. Do not include any text or explanation before or after the JSON object."""

STATIC_PREFIXES = {}
for tier in TIER_LISTS.keys():
    prefix_file = TIER_SAMPLE_DIRS[tier] / f"{tier}_user_prompt_prefix.txt"
    with open(prefix_file, 'r', encoding='utf-8') as f:
        STATIC_PREFIXES[tier] = f.read()

# Display the prefix for tier 1
# print("Static prefix for tier 1:")
# print("="*50,"\n")
# print(STATIC_PREFIXES["tier1"])

# %% [markdown]
# ### A simple function to append a chosen sample to a user prompt

# %%
def build_solution_mapping(
        index: int, 
        dataset: 'datasets.Dataset' = GSM8K_TRAIN,
        exclude_FA: bool = True
    ):
    """
    Extracts the natural language solution for a given problem index,
    cleans it, and structures it into a line-numbered dictionary.
    """
    solution_mapping = {}
    solution_text = dataset[index]["answer"]
    lines = [ln.strip() for ln in solution_text.splitlines() if ln.strip()]

    # Improved regex to handle commas in the final answer
    if lines and re.match(r"^####\s*[\d\.,]+$", lines[-1]):
        solution_mapping["FA"] = lines.pop(-1).strip()

    for i, line in enumerate(lines, 1):
        solution_mapping[f"L{i}"] = line

    if exclude_FA and "FA" in solution_mapping:
        del solution_mapping["FA"]

    return solution_mapping

def append_sample_to_user_prompt(
        tier: str, 
        index: int, 
        dataset: 'datasets.Dataset' = GSM8K_TRAIN
    ):
    """
    Appends a chosen sample from the GSM8K dataset to the user prompt for a specific tier. Returns the complete user prompt, ready to be sent to the LLM for manifest generation.
    """
    if tier not in TIER_LISTS:
        raise ValueError(f"Invalid tier: {tier}. Must be one of {list(TIER_LISTS.keys())}.")

    sample = dataset[index]
    question = sample['question']
    answer = build_solution_mapping(index, dataset)

    task_block = f"""## Input

**Index:**:
{index}

**Question:**:
{question}

**Solution mapping:**:
{answer}

## Output

"""
    return STATIC_PREFIXES[tier] + task_block

# Example usage
idx = TIER_LISTS["tier1"][0]  # Get the first index from tier 1
user_prompt = append_sample_to_user_prompt("tier1", idx, GSM8K_TRAIN)
print("User prompt for tier 1, index", idx, ":\n")
print(user_prompt)
# Out:
# User prompt for tier 1, index 4 :
#
# In the TASK below, you will be given a math problem and its corresponding step-by-step solution. Each step in the solution is numbered (e.g. "L1", "L2" and so on), and many of the steps include calculator annotations (e.g. "<<20*0.1=2>>"). Your goal is to convert this information into a structured JSON object according to the following schema and detailed instructions.
#
# # JSON Schema Definition
#
# Your output must adhere to the following JSON structure:
#
# ```json
# {
#   "function_code": "A single string containing a complete, self-contained Python function that constitutes an end-to-end formalization of the solution.",
#   "logical_steps": [
#     {
#       "line_number": "The line number from the original solution (e.g., 'L1', 'L2').",
#       "question_inputs": "A (possibly empty) list of variable names with values extracted from the question text, used for the first time in this step.",
#       "WK_inputs": "A (possibly empty) list of variable names with values coming from 'world knowledge' (e.g., minutes_per_hour), used for the first time in this step.",
#       "output_variable": "The name of the variable being assigned as the result of the main computation in this step.",
#       "solution_line_template": "The complete original line from the solution, including the calculator annotation, with all computational numbers replaced by `{variable_name}` placeholders."
#     }
#   ]
# }
# ```
#
# # Detailed Field Instructions
#
# ## 1. "function_code"
#
# This string must contain a Python function with the following characteristics:
#
# *   **1.A. No Imports:** You should not have ANY imports. The very first line MUST be the function definition (i.e. `def solve():`).
# *   **1.B. Function Naming & Docstring:** The function must be named `solve`, and it should not have any args. It must begin with a docstring that has exactly two lines:
#     *   **1.B.i.** The first line must be: "Index: [Index]." using the index from the task header.
#     *   **1.B.ii.** The second line must be a succinct, one-sentence description of what the function returns (e.g., "Returns: the total cost of wages and taxes.").
# *   **1.C. Line comments:** For each solution line that is used to compute the final answer, include a comment of the form `# L1`, `# L2` and so on, which references the line number.
#     *   **1.C.i.** Such a comment must immediately be followed by a code block that precisely formalizes the corresponding solution line. More details about code blocks are provided in 1.D below.
#     *   **1.C.ii.** If a solution line does not contain any computation relevant to the final answer, then omit it completely from the function code and do NOT add a corresponding line comment.
# *   **1.D. Code blocks:** Each code block constitutes a complete formalization of its corresponding solution line. It must consist of the following:
#     *   **1.D.i. Input Variables** First, define any NEW variables needed for the computation, i.e. that will be used for the first time in the solution. Each input variable MUST be followed by a comment (`#`) in the same line. These variables fall into two categories:
#         *   "question_inputs": These are variables whose values are stated in or can be extracted from the question text (only the question text, NOT the answer text). The comment for these variables should quote or refer to the phrase in the question text from which it is extracted.
#         *   "WK_inputs": These are variables drawn from common-sense "World Knowledge" (e.g. `minutes_per_hour = 60`, `dozen = 12`). The comment for these variables MUST simply say `# WK`.
#     *   **1.D.ii. Output Variables** Second, there should be EXACTLY ONE line of code which formalizes the computation in the solution line and assigns the resulting value to a new variable (this is the "output_variable" field).
# *   **1.E. The Direct Substitution Rule:** This is the MOST IMPORTANT RULE, which ensures that the "solution_line_template" is purely identical to the original solution line except that numerical values in computations have been replaced with variable placeholders: You MUST define variables in such a way that they can be DIRECTLY SUBSTITUTED into the solution line without changing any operators or surrounding text in the line.
# *   **1.F. Final Answer:** The line that assigns the final result to the `answer` variable must be immediately preceded by a line containing only the comment `# FA`. The last line of the function must always return the `answer` variable.
#
# ## 2. "solution_line_template"
#
# *   **2.A.** The template should be EXACTLY identical to the original solution line, with the ONLY CHANGES being that every NUMERICAL value used in a computation is replaced by its corresponding `{variable_name}` placeholder. This applies to the entire content of the solution line, including the inside and outside of the calculator annotations.
# *   **2.B.** In particular, EVERY SINGLE numerical value appearing inside the calculator annotation (`<<..>>`) MUST be replaced with a `{variable_name}` placeholder.
# *   **2.C.** Note: some quantities may appear as words in the solution line (e.g. "twice as many"). Do NOT attempt to replace these with variable name placeholders.
# *   **2.D.** The Direct Substitution Rule will ensure that for correctly defined variables, it will be possible to replace the numerical values with variable name placeholders while leaving all surrounding text, symbols, and operators unchanged. Thus, in a correct "solution_line_template", the calculator annotation will not contain any numerical values, and moreover, replacing each `{variable_name}` by its value should exactly recover the original solution line, including the original calculator annotation.
#
# # Examples
#
# Given below are three examples that illustrate what a perfect formalization will look like. For each example, you are given the following:
#
# *   Input: consisting of an index, question, and solution mapping.
# *   Output: complete output, wrapped inside ```json .. ```
#
# In all examples, you will observe the following:
# *   A rigid adherence to the Direct Substitution Rule (1.E), resulting in a solution_line_template that perfectly satisfies properties 2.A - 2.D. For instance, in Example 1 below, "two dozen" is not formalized as a stand-alone variable because the computation in "L1" and "L4" treat "two" and "dozen" as separate variables.
# *   The function_code only uses solution lines with a relevant computation (rule 1.C.ii), and omits lines that are irrelevant (e.g. "L1" is ommitted in Example 3 below).
# *   Code blocks that are precisely formatted as in 1.D, consisting of line comments, then input variable declarations, then a single output variable assignment (i.e. the single computation for that solution line).
# *   A careful distinction between numerical values and word-based quantities in the solution_line_template. Per rule 2.C, only numerical values like 2 are replaced with placeholders, and word-based quantities are not, even though they are formalized as variables in the function_code (For example, in "L2" of Example 2, the word "Twice" remains in the solution_line_template).
# *   Precise categorization of input variables as described in rule 1.D.i. Note how `dozen = 12` is a WK_input (common knowledge), while `father_ate = 8` is a question_input (explicitly stated in the problem text).
# *   Strict adherence to defining only NEW variables in each step's question_inputs and WK_inputs lists. Observe that once a variable like `days_in_week` is defined in one step, it is simply re-used in later calculations without being re-defined or listed as an input again.
# *   Comments for question_inputs must cite the question text only, NEVER the solution text. For instance, in Example 3, even though "60 minutes in an hour" is stated in L1 of the solution, the variable `minutes_per_hour` is correctly labeled # WK because that fact is not present in the question text, and the number of minutes in an hour constitutes common-sense World Knowledge.
#
# ## Example 1
#
# ### Input
#
# **Index:**
# 3946
#
# **Question:**
# Mother made 2 dozen brownies and placed them on the kitchen counter to cool.  Father smelled the brownies, came into the kitchen and ate 8 of them. Then, their daughter, Mooney, wandered into the kitchen and ate 4 of the brownies. The next morning, Mother made another two dozen brownies and added them to those remaining from the day before.  After that, how many brownies were on the counter?
#
# **Solution mapping:**
# {'L1': 'Two dozen brownies is 2 * 12 = <<2*12=24>>24 brownies.', 'L2': 'After Father ate his 8, there were 24 - 8 = <<24-8=16>>16 brownies remaining on the counter.', 'L3': 'After Mooney ate her 4, there were 16 - 4 = <<16-4=12>>12 brownies remaining on the counter.', 'L4': 'Mother made a second batch of two-dozen brownies, or 2 * 12 = <<2*12=24>>24 brownies.', 'L5': 'After Mother added the second two-dozen, there were 12 + 24 = <<12+24=36>>36 brownies on the kitchen counter.'}
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 3946.\n    Returns: the number of brownies on the counter at the end.\n    \"\"\"\n    # L1\n    num_dozen_initial = 2 # 2 dozen brownies\n    dozen = 12 # WK\n    initial_brownies = num_dozen_initial * dozen\n\n    # L2\n    father_ate = 8 # ate 8 of them\n    after_father = initial_brownies - father_ate\n\n    # L3\n    mooney_ate = 4 # ate 4 of the brownies\n    after_mooney = after_father - mooney_ate\n\n    # L4\n    num_dozen_second_batch = 2 # another two dozen brownies\n    second_batch = num_dozen_second_batch * dozen\n\n    # L5\n    total_brownies = after_mooney + second_batch\n\n    # FA\n    answer = total_brownies\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["num_dozen_initial"],
#       "WK_inputs": ["dozen"],
#       "output_variable": "initial_brownies",
#       "solution_line_template": "Two dozen brownies is {num_dozen_initial} * {dozen} = <<{num_dozen_initial}*{dozen}={initial_brownies}>>{initial_brownies} brownies."
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": ["father_ate"],
#       "WK_inputs": [],
#       "output_variable": "after_father",
#       "solution_line_template": "After Father ate his {father_ate}, there were {initial_brownies} - {father_ate} = <<{initial_brownies}-{father_ate}={after_father}>>{after_father} brownies remaining on the counter."
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["mooney_ate"],
#       "WK_inputs": [],
#       "output_variable": "after_mooney",
#       "solution_line_template": "After Mooney ate her {mooney_ate}, there were {after_father} - {mooney_ate} = <<{after_father}-{mooney_ate}={after_mooney}>>{after_mooney} brownies remaining on the counter."
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": ["num_dozen_second_batch"],
#       "WK_inputs": [],
#       "output_variable": "second_batch",
#       "solution_line_template": "Mother made a second batch of two-dozen brownies, or {num_dozen_second_batch} * {dozen} = <<{num_dozen_second_batch}*{dozen}={second_batch}>>{second_batch} brownies."
#     },
#     {
#       "line_number": "L5",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "total_brownies",
#       "solution_line_template": "After Mother added the second two-dozen, there were {after_mooney} + {second_batch} = <<{after_mooney}+{second_batch}={total_brownies}>>{total_brownies} brownies on the kitchen counter."
#     }
#   ]
# }
# ```
#
# ## Example 2
#
# ### Input
#
# **Index:**
# 4258
#
# **Question:**
# Cowboy Mickey and cowgirl Minnie train horses for a living.  On average, Mickey mounts six less than twice as many horses per day as does Minnie,  while Minnie mounts three more horses per day than there are days in a week.  How many horses does Mickey Mount per week?
#
# **Solution mapping:**
# {'L1': 'If Minnie mounts three more horses per day than there are days in a week, then Minnie mounts 7+3=<<3+7=10>>10 horses per day.', 'L2': 'Twice as many horses per day as Minnie mounts is 10*2=<<10*2=20>>20 horses per day.', 'L3': 'If Mickey mounts six less than twice as many horses per day as does Minnie, then Mickey mounts 20-6=<<20-6=14>>14 horses per day.', 'L4': 'Since there are 7 days in a week, then Mickey mounts 7*14=<<7*14=98>>98 horses per week.'}
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 4258.\n    Returns: the number of horses Mickey mounts per week.\n    \"\"\"\n    # L1\n    days_in_week = 7 # WK\n    minnie_more_than_week = 3 # three more horses per day than there are days in a week\n    minnie_per_day = days_in_week + minnie_more_than_week\n\n    # L2\n    multiplier_for_twice = 2 # twice as many horses\n    twice_minnie = minnie_per_day * multiplier_for_twice\n\n    # L3\n    mickey_less_than_twice_minnie = 6 # six less than twice as many horses\n    mickey_per_day = twice_minnie - mickey_less_than_twice_minnie\n\n    # L4\n    mickey_per_week = mickey_per_day * days_in_week\n\n    # FA\n    answer = mickey_per_week\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L1",
#       "question_inputs": ["minnie_more_than_week"],
#       "WK_inputs": ["days_in_week"],
#       "output_variable": "minnie_per_day",
#       "solution_line_template": "If Minnie mounts three more horses per day than there are days in a week, then Minnie mounts {days_in_week}+{minnie_more_than_week}=<<{days_in_week}+{minnie_more_than_week}={minnie_per_day}>>{minnie_per_day} horses per day."
#     },
#     {
#       "line_number": "L2",
#       "question_inputs": ["multiplier_for_twice"],
#       "WK_inputs": [],
#       "output_variable": "twice_minnie",
#       "solution_line_template": "Twice as many horses per day as Minnie mounts is {minnie_per_day}*{multiplier_for_twice}=<<{minnie_per_day}*{multiplier_for_twice}={twice_minnie}>>{twice_minnie} horses per day."
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["mickey_less_than_twice_minnie"],
#       "WK_inputs": [],
#       "output_variable": "mickey_per_day",
#       "solution_line_template": "If Mickey mounts six less than twice as many horses per day as does Minnie, then Mickey mounts {twice_minnie}-{mickey_less_than_twice_minnie}=<<{twice_minnie}-{mickey_less_than_twice_minnie}={mickey_per_day}>>{mickey_per_day} horses per day."
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "mickey_per_week",
#       "solution_line_template": "Since there are 7 days in a week, then Mickey mounts {days_in_week}*{mickey_per_day}=<<{days_in_week}*{mickey_per_day}={mickey_per_week}>>{mickey_per_week} horses per week."
#     }
#   ]
# }
# ```
#
# ## Example 3
#
# ### Input
#
# **Index:**
# 1372
#
# **Question:**
# Micah can type 20 words per minute and Isaiah can type 40 words per minute. How many more words can Isaiah type than Micah in an hour?
#
# **Solution mapping:**
# {'L1': 'There are 60 minutes in an hour.', 'L2': 'Micah can type 20 x 60 = <<20*60=1200>>1200 words in an hour.', 'L3': 'Isaiah can type 40 x 60 = <<40*60=2400>>2400 words in an hour.', 'L4': 'Isaiah can type 2400 - 1200 = <<2400-1200=1200>>1200 words more than Micah in an hour.'}
#
# ### Output
#
# ```json
# {
#   "function_code": "def solve():\n    \"\"\"Index: 1372.\n    Returns: how many more words Isaiah can type than Micah in an hour.\n    \"\"\"\n    # L2\n    micah_wpm = 20 # 20 words per minute\n    minutes_per_hour = 60 # WK\n    micah_wph = micah_wpm * minutes_per_hour\n\n    # L3\n    isaiah_wpm = 40 # 40 words per minute\n    isaiah_wph = isaiah_wpm * minutes_per_hour\n\n    # L4\n    difference_in_words = isaiah_wph - micah_wph\n\n    # FA\n    answer = difference_in_words\n    return answer",
#   "logical_steps": [
#     {
#       "line_number": "L2",
#       "question_inputs": ["micah_wpm"],
#       "WK_inputs": ["minutes_per_hour"],
#       "output_variable": "micah_wph",
#       "solution_line_template": "Micah can type {micah_wpm} x {minutes_per_hour} = <<{micah_wpm}*{minutes_per_hour}={micah_wph}>>{micah_wph} words in an hour."
#     },
#     {
#       "line_number": "L3",
#       "question_inputs": ["isaiah_wpm"],
#       "WK_inputs": [],
#       "output_variable": "isaiah_wph",
#       "solution_line_template": "Isaiah can type {isaiah_wpm} x {minutes_per_hour} = <<{isaiah_wpm}*{minutes_per_hour}={isaiah_wph}>>{isaiah_wph} words in an hour."
#     },
#     {
#       "line_number": "L4",
#       "question_inputs": [],
#       "WK_inputs": [],
#       "output_variable": "difference_in_words",
#       "solution_line_template": "Isaiah can type {isaiah_wph} - {micah_wph} = <<{isaiah_wph}-{micah_wph}={difference_in_words}>>{difference_in_words} words more than Micah in an hour."
#     }
#   ]
# }
# ```
#
# # TASK
#
# ## Input
#
# **Index:**:
# 4
#
# **Question:**:
# James writes a 3-page letter to 2 different friends twice a week.  How many pages does he write a year?
#
# **Solution mapping:**:
# {'L1': 'He writes each friend 3*2=<<3*2=6>>6 pages a week', 'L2': 'So he writes 6*2=<<6*2=12>>12 pages every week', 'L3': 'That means he writes 12*52=<<12*52=624>>624 pages a year'}
#
# ## Output

# %% [markdown]
# ### API Clients, Concurrency Limits, Models

# %%
# Imports for API clients and related functionality
import os
import openai
import google.generativeai as genai
import anthropic
import asyncio
import nest_asyncio
from openai import AsyncOpenAI
from anthropic import AsyncClient
from dotenv import load_dotenv

# This must be done once per kernel to allow asyncio to run in a Jupyter notebook..
nest_asyncio.apply()

# Load API Keys from .env file
load_dotenv()
print("Loaded environment variables from .env file.")

# Initialize Asynchronous API Clients
try:
    openai_client_async = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    anthropic_client_async = AsyncClient(api_key=os.getenv("ANTHROPIC_API_KEY"))
    genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
    print("API clients initialized successfully.")
except TypeError:
    print("API key not found for one or more services. Please check your .env file.")
    # Assign None to prevent errors in subsequent cells
    openai_client_async = None
    anthropic_client_async = None

# Define API Concurrency Limits to prevent 429 "Too Many Requests" errors.
API_CONCURRENCY_LIMITS = {
    "google": 2,    
    "anthropic": 2, 
    "openai": 2,    
}
print(f"API concurrency limits set to: {API_CONCURRENCY_LIMITS}")

MODEL_DICT = {
  "openai": "gpt-4.1",
  "google": "gemini-2.5-flash"
}

MODELS = [f"{provider}_{model}" for provider, model in MODEL_DICT.items()]
print(f"Available models: {MODELS}")
# Out:
# Loaded environment variables from .env file.
# API clients initialized successfully.
# API concurrency limits set to: {'google': 2, 'anthropic': 2, 'openai': 2}
# Available models: ['openai_gpt-4.1', 'google_gemini-2.5-flash']

# %% [markdown]
# ### Main code for making API calls

# %%
import time
import math
import random
import datetime
from tqdm.notebook import tqdm

# --- 1. Helper Functions ---
# These two helpers are generic and can be used by any provider's function.

_anthropic_bucket = {"tokens": 50_000, "reset_at": time.monotonic() + 60}

async def _anthropic_throttle(tokens_needed: int):
    # (Code for this function is unchanged)
    global _anthropic_bucket
    while True:
        now = time.monotonic()
        if now >= _anthropic_bucket["reset_at"]:
            _anthropic_bucket = {"tokens": 50_000, "reset_at": now + 60}
        if tokens_needed <= _anthropic_bucket["tokens"]:
            _anthropic_bucket["tokens"] -= tokens_needed
            return
        else:
            to_sleep = _anthropic_bucket["reset_at"] - now
            await asyncio.sleep(max(to_sleep, 0.01))

async def with_api_retries(
        send_coroutine_factory,
        *,
        model_info: str,  # For informative logging
        max_attempts: int = 10,
        base_wait_seconds: int = 10  # Increased from 5
    ):
    """A wrapper to handle API retries with exponential backoff."""
    for attempt in range(max_attempts):
        try:
            return await send_coroutine_factory()
        except (openai.RateLimitError, anthropic.RateLimitError, Exception) as e:
            # Check for specific rate limit error types or a 429 status code in the error string
            if isinstance(e, (openai.RateLimitError, anthropic.RateLimitError)) or "429" in str(e):
                if attempt == max_attempts - 1:
                    print(f"❌ Final attempt failed for {model_info}. Giving up.")
                    raise
                
                # Exponential backoff with jitter
                wait_time = base_wait_seconds * (2 ** attempt) + random.uniform(0, 1)
                
                # More informative error message
                print(f"🕒 Rate limit on {model_info}. Retrying in {wait_time:.2f}s... (Attempt {attempt + 1}/{max_attempts})")
                await asyncio.sleep(wait_time)
            else:
                # If it's not a rate limit error, re-raise immediately
                raise
    return None

# --- 2. Provider-Specific API Calling Functions ---

async def call_openai_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int  # Pass index for logging
    ):
    """Handles an API call to OpenAI."""
    messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}]
    model_info = f"{model} (Index {index})" # Create info string for logger
    
    response = await with_api_retries(
        lambda: openai_client_async.chat.completions.create(
            model=model, 
            messages=messages, 
            temperature=0, 
            max_tokens=4000, 
            response_format={"type": "json_object"}
        ),
        model_info=model_info # Pass info to the retry wrapper
    )
    
    text_response = response.choices[0].message.content
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage:
        usage["input_tokens"] = response.usage.prompt_tokens
        usage["output_tokens"] = response.usage.completion_tokens
        if hasattr(response.usage, 'prompt_tokens_details') and response.usage.prompt_tokens_details:
             usage["cached_tokens"] = response.usage.prompt_tokens_details.get("cached_tokens", 0)
    return text_response, usage

async def call_google_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int  # Pass index for logging
    ):
    """Handles an API call to Google."""
    gemini = genai.GenerativeModel(model_name=model, system_instruction=system_prompt)
    cfg = genai.types.GenerationConfig(temperature=0, max_output_tokens=4000)
    model_info = f"{model} (Index {index})" # Create info string for logger

    response = await with_api_retries(
        lambda: gemini.generate_content_async(user_prompt, generation_config=cfg),
        model_info=model_info # Pass info to the retry wrapper
    )

    text_response = response.text
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage_metadata:
        usage["input_tokens"] = response.usage_metadata.prompt_token_count
        usage["output_tokens"] = response.usage_metadata.candidates_token_count
    return text_response, usage

async def call_anthropic_async(
        model: str,
        system_prompt: str,
        user_prompt: str,
        index: int  # Pass index for logging
    ):
    """Handles an API call to Anthropic, including prompt caching."""
    system_block = {"type": "text", "text": system_prompt, "cache_control": {"type": "ephemeral"}}
    model_info = f"{model} (Index {index})" # Create info string for logger
    
    est_tokens = math.ceil(1.2 * len(system_prompt.split()))
    await _anthropic_throttle(est_tokens)

    response = await with_api_retries(
        lambda: anthropic_client_async.messages.create(
            model=model, max_tokens=4000, temperature=0,
            system=[system_block], messages=[{"role": "user", "content": user_prompt}],
        ),
        model_info=model_info # Pass info to the retry wrapper
    )

    text_response = response.content[0].text
    usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
    if response.usage:
        usage["input_tokens"] = response.usage.input_tokens
        usage["output_tokens"] = response.usage.output_tokens
        usage["cached_tokens"] = response.usage.cache_read_input_tokens if response.usage.cache_read_input_tokens else 0
    return text_response, usage


# --- 2. Per-Problem Concurrent Runner ---
# This function runs API calls for ONE problem concurrently across all models.

async def run_one_problem_concurrently(
    index: int,
    tier: str,
    dataset: 'datasets.Dataset',
    system_prompt: str,
    model_dict: Dict[str, str],
    provider_sems: Dict[str, asyncio.Semaphore],
    output_dir: Path
) -> List[Dict]:
    """
    Generates manifests for a single problem by calling all model APIs concurrently.
    """
    user_prompt = append_sample_to_user_prompt(
        tier=tier,
        index=index,
        dataset=dataset
    )
    
    tasks = []
    # Create concurrent tasks for each model
    for provider, model in model_dict.items():
        async with provider_sems[provider]: # Acquire semaphore before creating the task
            if provider == "openai":
                coro = call_openai_async(model, system_prompt, user_prompt, index)
            elif provider == "google":
                coro = call_google_async(model, system_prompt, user_prompt, index)
            elif provider == "anthropic":
                coro = call_anthropic_async(model, system_prompt, user_prompt, index)
            else:
                async def unknown_provider(): raise ValueError(f"Unknown provider: {provider}")
                coro = unknown_provider()
        
            task = asyncio.create_task(coro)
            task.meta = {
                "provider": provider, "model": model, "index": index, "start_time": time.time()
            }
            tasks.append(task)
            
    # Wait for all models to finish for this single problem
    task_results = await asyncio.gather(*tasks, return_exceptions=True)
    
    problem_results = []
    # Process the results
    for task, result in zip(tasks, task_results):
        meta = task.meta
        elapsed = time.time() - meta["start_time"]
        status = "Failed"
        usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
        
        output_path = output_dir / str(meta['index']) / f"{meta['provider']}_{meta['model']}.txt"
        output_path.parent.mkdir(parents=True, exist_ok=True)

        if isinstance(result, Exception):
            error_message = f"--- ERROR ---\nIndex: {meta['index']}, Model: {meta['model']}\n{type(result).__name__}: {result}"
            output_path.write_text(error_message, encoding='utf-8')
            # The retry wrapper already logs, this is for the final failure
            print(f"❌ FINAL Error for Index {meta['index']}, Model {meta['model']}: {type(result).__name__}")
        else:
            text_response, usage = result
            output_path.write_text(text_response, encoding='utf-8')
            status = "Success"
            print(f"✅ Success for Index {meta['index']}, Model {meta['model']} in {elapsed:.2f}s")
        
        problem_results.append({
            "provider": meta["provider"], "model": meta["model"], "index": meta["index"],
            "status": status, "time_s": round(elapsed, 2),
            "input_tokens": usage["input_tokens"], "output_tokens": usage["output_tokens"],
            "cached_tokens": usage["cached_tokens"],
            "utc_completed": datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="seconds")
        })
    
    return problem_results


# --- 3. Main Hybrid Batch Generation Function ---
# This function processes each problem in the list SEQUENTIALLY.

async def generate_manifests_hybrid(
    indices_to_generate: List[int],
    tier: str = "tier1",
    dataset: 'datasets.Dataset' = GSM8K_TRAIN,
    model_dict: Dict[str, str] = MODEL_DICT,
    system_prompt: str = SYSTEM_PROMPT,
    output_dir: Path = TIER_OUTPUT_DIRS["tier1"],
    concurrency_limits: Dict[str, int] = API_CONCURRENCY_LIMITS
):
    """
    Runs manifest generation by processing problems sequentially, but running
    model API calls for each problem concurrently.
    """
    print("--- Starting Manifest Generation (Hybrid: Sequential Problems, Concurrent Models) ---")
    start_time = time.time()
    
    provider_semaphores = {prov: asyncio.Semaphore(limit) for prov, limit in concurrency_limits.items()}
    all_results = []
    
    # Process each problem sequentially using a simple for loop
    for index in tqdm(indices_to_generate, desc=f"Generating Manifests for {tier}"):
        problem_results = await run_one_problem_concurrently(
            index=index,
            tier=tier,
            dataset=dataset,
            system_prompt=system_prompt,
            model_dict=model_dict,
            provider_sems=provider_semaphores,
            output_dir=output_dir
        )
        all_results.extend(problem_results)

    # Create and save the performance DataFrame
    df = pd.DataFrame(all_results)
    run_ts = datetime.datetime.now(datetime.timezone.utc).strftime("%Y%m%d_%H%M%S")
    csv_path = output_dir / f"generation_performance_{run_ts}.csv"
    df.to_csv(csv_path, index=False)
    
    end_time = time.time()
    print(f"\n--- Manifest Generation Complete ---")
    print(f"Processed {len(indices_to_generate)} indices in {end_time - start_time:.2f} seconds.")
    print(f"Performance log saved to: {csv_path}")
    
    return df

# # --- 3. Per-Problem Orchestration (Dispatcher Logic) ---

# async def run_one_problem_async(
#     index: int, 
#     tier: str,
#     dataset: 'datasets.Dataset',
#     system_prompt: str,
#     model_dict: Dict[str, str],
#     provider_sems: Dict[str, asyncio.Semaphore], 
#     output_dir: Path,
#     pbar: tqdm
# ) -> List[Dict]:
#     """
#     Generates manifests for a single problem and returns a list of result dictionaries.
#     """
#     user_prompt = append_sample_to_user_prompt(
#         tier=tier,
#         index=index,
#         dataset=dataset
#     )
    
#     problem_results = []
    
#     tasks = []
#     for provider, model in model_dict.items():
#         async with provider_sems[provider]: # Acquire semaphore before creating the task
#             if provider == "openai":
#                 coro = call_openai_async(model, system_prompt, user_prompt)
#             elif provider == "google":
#                 coro = call_google_async(model, system_prompt, user_prompt)
#             elif provider == "anthropic":
#                 coro = call_anthropic_async(model, system_prompt, user_prompt)
#             else:
#                 # Create a coroutine that will immediately raise an error
#                 async def unknown_provider(): raise ValueError(f"Unknown provider: {provider}")
#                 coro = unknown_provider()
        
#             task = asyncio.create_task(coro)
#             task.meta = {
#                 "provider": provider, 
#                 "model": model, 
#                 "index": index, 
#                 "start_time": time.time()}
#             tasks.append(task)
        
#     task_results = await asyncio.gather(*tasks, return_exceptions=True)
    
#     for task, result in zip(tasks, task_results):
#         meta = task.meta
#         elapsed = time.time() - meta["start_time"]
#         status = "Failed"
#         usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
        
#         output_path = output_dir / str(meta['index']) / f"{meta['provider']}_{meta['model']}.txt"
#         output_path.parent.mkdir(parents=True, exist_ok=True)

#         if isinstance(result, Exception):
#             error_message = f"--- ERROR ---\nIndex: {meta['index']}, Model: {meta['model']}\n{type(result).__name__}: {result}"
#             output_path.write_text(error_message, encoding='utf-8')
#             print(f"❌ Error for Index {meta['index']}, Model {meta['model']}: {type(result).__name__}")
#         else:
#             text_response, usage = result
#             output_path.write_text(text_response, encoding='utf-8')
#             status = "Success"
        
#         # Append to the list of results for this problem
#         problem_results.append({
#             "provider": meta["provider"], 
#             "model": meta["model"], 
#             "index": meta["index"],
#             "status": status, 
#             "time_s": round(elapsed, 2),
#             "input_tokens": usage["input_tokens"], "output_tokens": usage["output_tokens"],
#             "cached_tokens": usage["cached_tokens"],
#             "utc_completed": datetime.datetime.now(datetime.timezone.utc).isoformat(timespec="seconds")
#         })
    
#     pbar.update(1)
#     # Return result for this problem
#     return problem_results


# # --- 4. Main Batch Generation Function ---

# async def generate_manifests_parallel(
#     indices_to_generate: List[int],
#     tier: str = "tier1",
#     dataset: 'datasets.Dataset' = GSM8K_TRAIN,
#     model_dict: Dict[str, str] = MODEL_DICT,
#     system_prompt: str = SYSTEM_PROMPT,
#     concurrency_limits: Dict[str, int] = API_CONCURRENCY_LIMITS
# ):
#     """
#     Runs the manifest generation process and returns a DataFrame with performance stats.
#     """
#     print("--- Starting Manifest Generation ---")
#     start_time = time.time()
    
#     provider_semaphores = {prov: asyncio.Semaphore(limit) for prov, limit in concurrency_limits.items()}

#     output_dir = TIER_OUTPUT_DIRS[tier]
    
#     with tqdm(total=len(indices_to_generate), desc="Generating Manifests") as pbar:
#         problem_tasks = [
#             run_one_problem_async(
#                 index=idx, 
#                 tier=tier,
#                 dataset=dataset,
#                 system_prompt=system_prompt,
#                 model_dict=model_dict,
#                 provider_sems=provider_semaphores, 
#                 output_dir=output_dir,
#                 pbar=pbar
#             )
#             for idx in indices_to_generate
#         ]
#         # This will now be a list of lists, e.g., [[results_for_p0], [results_for_p1], ...]
#         all_results = await asyncio.gather(*problem_tasks)

#     # Flatten the list of lists into a single list of result dictionaries
#     flat_results = [item for sublist in all_results for item in sublist]

#     # Create and save the performance DataFrame
#     df = pd.DataFrame(flat_results)
#     run_ts = datetime.datetime.now(datetime.timezone.utc).strftime("%Y%m%d_%H%M%S")
#     csv_path = output_dir / f"generation_performance_{run_ts}.csv"
#     df.to_csv(csv_path, index=False)
    
#     end_time = time.time()
#     print(f"\n--- Manifest Generation Complete ---")
#     print(f"Processed {len(indices_to_generate)} indices in {end_time - start_time:.2f} seconds.")
#     print(f"Performance log saved to: {csv_path}")
    
#     return df

# %%
# Choose the list of indices to generate manifests for
UPPER_LIMIT = 500
INDICES_TO_GENERATE = [idx for idx in TIER_LISTS["tier1"] if idx <= UPPER_LIMIT]

# Run the manifest generation process
perf_df = await generate_manifests_hybrid(indices_to_generate=INDICES_TO_GENERATE)
# Out:
# --- Starting Manifest Generation (Hybrid: Sequential Problems, Concurrent Models) ---
# Generating Manifests for tier1:   0%|          | 0/187 [00:00<?, ?it/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751995370.474409 11758796 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# ✅ Success for Index 4, Model gpt-4.1 in 6.53s
# ✅ Success for Index 4, Model gemini-2.5-flash in 6.53s
# ✅ Success for Index 6, Model gpt-4.1 in 6.99s
# ✅ Success for Index 6, Model gemini-2.5-flash in 6.99s
# ✅ Success for Index 7, Model gpt-4.1 in 7.91s
# ✅ Success for Index 7, Model gemini-2.5-flash in 7.91s
# ✅ Success for Index 17, Model gpt-4.1 in 14.85s
# ✅ Success for Index 17, Model gemini-2.5-flash in 14.85s
# ✅ Success for Index 18, Model gpt-4.1 in 9.52s
# ✅ Success for Index 18, Model gemini-2.5-flash in 9.52s
# ✅ Success for Index 20, Model gpt-4.1 in 7.57s
# ✅ Success for Index 20, Model gemini-2.5-flash in 7.57s
# ✅ Success for Index 21, Model gpt-4.1 in 12.90s
# ✅ Success for Index 21, Model gemini-2.5-flash in 12.90s
# ✅ Success for Index 22, Model gpt-4.1 in 7.79s
# ✅ Success for Index 22, Model gemini-2.5-flash in 7.79s
# ✅ Success for Index 24, Model gpt-4.1 in 5.12s
# ✅ Success for Index 24, Model gemini-2.5-flash in 5.12s
# ✅ Success for Index 28, Model gpt-4.1 in 5.76s
# ✅ Success for Index 28, Model gemini-2.5-flash in 5.77s
# ✅ Success for Index 31, Model gpt-4.1 in 7.56s
# ✅ Success for Index 31, Model gemini-2.5-flash in 7.56s
# ✅ Success for Index 32, Model gpt-4.1 in 8.99s
# ✅ Success for Index 32, Model gemini-2.5-flash in 9.00s
# ✅ Success for Index 34, Model gpt-4.1 in 6.08s
# ✅ Success for Index 34, Model gemini-2.5-flash in 6.08s
# ✅ Success for Index 39, Model gpt-4.1 in 8.15s
# ✅ Success for Index 39, Model gemini-2.5-flash in 8.15s
# ✅ Success for Index 41, Model gpt-4.1 in 6.56s
# ✅ Success for Index 41, Model gemini-2.5-flash in 6.57s
# ✅ Success for Index 43, Model gpt-4.1 in 9.51s
# ✅ Success for Index 43, Model gemini-2.5-flash in 9.51s
# ✅ Success for Index 45, Model gpt-4.1 in 8.80s
# ✅ Success for Index 45, Model gemini-2.5-flash in 8.80s
# ✅ Success for Index 46, Model gpt-4.1 in 8.19s
# ✅ Success for Index 46, Model gemini-2.5-flash in 8.19s
# ✅ Success for Index 51, Model gpt-4.1 in 10.72s
# ✅ Success for Index 51, Model gemini-2.5-flash in 10.72s
# ✅ Success for Index 53, Model gpt-4.1 in 9.34s
# ✅ Success for Index 53, Model gemini-2.5-flash in 9.34s
# ✅ Success for Index 56, Model gpt-4.1 in 7.71s
# ✅ Success for Index 56, Model gemini-2.5-flash in 7.71s
# ✅ Success for Index 59, Model gpt-4.1 in 6.38s
# ✅ Success for Index 59, Model gemini-2.5-flash in 6.38s
# ✅ Success for Index 60, Model gpt-4.1 in 8.43s
# ✅ Success for Index 60, Model gemini-2.5-flash in 8.43s
# ✅ Success for Index 63, Model gpt-4.1 in 6.96s
# ✅ Success for Index 63, Model gemini-2.5-flash in 6.96s
# ✅ Success for Index 65, Model gpt-4.1 in 6.14s
# ✅ Success for Index 65, Model gemini-2.5-flash in 6.14s
# ✅ Success for Index 69, Model gpt-4.1 in 6.96s
# ✅ Success for Index 69, Model gemini-2.5-flash in 6.96s
# ✅ Success for Index 71, Model gpt-4.1 in 9.01s
# ✅ Success for Index 71, Model gemini-2.5-flash in 9.01s
# ✅ Success for Index 75, Model gpt-4.1 in 12.89s
# ✅ Success for Index 75, Model gemini-2.5-flash in 12.89s
# ✅ Success for Index 76, Model gpt-4.1 in 8.12s
# ✅ Success for Index 76, Model gemini-2.5-flash in 8.13s
# ✅ Success for Index 77, Model gpt-4.1 in 9.28s
# ✅ Success for Index 77, Model gemini-2.5-flash in 9.28s
# ✅ Success for Index 78, Model gpt-4.1 in 11.58s
# ✅ Success for Index 78, Model gemini-2.5-flash in 11.59s
# ✅ Success for Index 79, Model gpt-4.1 in 8.27s
# ✅ Success for Index 79, Model gemini-2.5-flash in 8.28s
# ✅ Success for Index 82, Model gpt-4.1 in 10.64s
# ✅ Success for Index 82, Model gemini-2.5-flash in 10.65s
# ✅ Success for Index 84, Model gpt-4.1 in 9.83s
# ✅ Success for Index 84, Model gemini-2.5-flash in 9.83s
# ✅ Success for Index 85, Model gpt-4.1 in 9.42s
# ✅ Success for Index 85, Model gemini-2.5-flash in 9.42s
# ✅ Success for Index 88, Model gpt-4.1 in 10.23s
# ✅ Success for Index 88, Model gemini-2.5-flash in 10.24s
# ✅ Success for Index 93, Model gpt-4.1 in 10.95s
# ✅ Success for Index 93, Model gemini-2.5-flash in 10.95s
# ✅ Success for Index 97, Model gpt-4.1 in 10.55s
# ✅ Success for Index 97, Model gemini-2.5-flash in 10.55s
# ✅ Success for Index 98, Model gpt-4.1 in 10.25s
# ✅ Success for Index 98, Model gemini-2.5-flash in 10.25s
# ✅ Success for Index 101, Model gpt-4.1 in 23.32s
# ✅ Success for Index 101, Model gemini-2.5-flash in 23.33s
# ✅ Success for Index 102, Model gpt-4.1 in 6.48s
# ✅ Success for Index 102, Model gemini-2.5-flash in 6.48s
# ✅ Success for Index 103, Model gpt-4.1 in 15.30s
# ✅ Success for Index 103, Model gemini-2.5-flash in 15.31s
# ✅ Success for Index 104, Model gpt-4.1 in 5.23s
# ✅ Success for Index 104, Model gemini-2.5-flash in 5.24s
# ✅ Success for Index 105, Model gpt-4.1 in 6.55s
# ✅ Success for Index 105, Model gemini-2.5-flash in 6.55s
# ✅ Success for Index 110, Model gpt-4.1 in 6.96s
# ✅ Success for Index 110, Model gemini-2.5-flash in 6.96s
# ✅ Success for Index 111, Model gpt-4.1 in 7.78s
# ✅ Success for Index 111, Model gemini-2.5-flash in 7.78s
# ✅ Success for Index 114, Model gpt-4.1 in 9.83s
# ✅ Success for Index 114, Model gemini-2.5-flash in 9.83s
# ✅ Success for Index 116, Model gpt-4.1 in 16.18s
# ✅ Success for Index 116, Model gemini-2.5-flash in 16.18s
# ✅ Success for Index 118, Model gpt-4.1 in 6.54s
# ✅ Success for Index 118, Model gemini-2.5-flash in 6.55s
# ✅ Success for Index 119, Model gpt-4.1 in 7.57s
# ✅ Success for Index 119, Model gemini-2.5-flash in 7.57s
# ✅ Success for Index 120, Model gpt-4.1 in 10.06s
# ✅ Success for Index 120, Model gemini-2.5-flash in 10.06s
# ✅ Success for Index 125, Model gpt-4.1 in 9.39s
# ✅ Success for Index 125, Model gemini-2.5-flash in 9.39s
# ✅ Success for Index 126, Model gpt-4.1 in 10.03s
# ✅ Success for Index 126, Model gemini-2.5-flash in 10.04s
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[9], line 6
#       3 INDICES_TO_GENERATE = [idx for idx in TIER_LISTS["tier1"] if idx <= UPPER_LIMIT]
#       5 # Run the manifest generation process
# ----> 6 perf_df = await generate_manifests_hybrid(indices_to_generate=INDICES_TO_GENERATE)
#
# Cell In[8], line 241, in generate_manifests_hybrid(indices_to_generate, tier, dataset, model_dict, system_prompt, output_dir, concurrency_limits)
#     239 # Process each problem sequentially using a simple for loop
#     240 for index in tqdm(indices_to_generate, desc=f"Generating Manifests for {tier}"):
# --> 241     problem_results = await run_one_problem_concurrently(
#     242         index=index,
#     243         tier=tier,
#     244         dataset=dataset,
#     245         system_prompt=system_prompt,
#     246         model_dict=model_dict,
#     247         provider_sems=provider_semaphores,
#     248         output_dir=output_dir
#     249     )
#     250     all_results.extend(problem_results)
#     252 # Create and save the performance DataFrame
#
# Cell In[8], line 182, in run_one_problem_concurrently(index, tier, dataset, system_prompt, model_dict, provider_sems, output_dir)
#     179         tasks.append(task)
#     181 # Wait for all models to finish for this single problem
# --> 182 task_results = await asyncio.gather(*tasks, return_exceptions=True)
#     184 problem_results = []
#     185 # Process the results
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/asyncio/tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# Cell In[8], line 98, in call_google_async(model, system_prompt, user_prompt, index)
#      95 cfg = genai.types.GenerationConfig(temperature=0, max_output_tokens=4000)
#      96 model_info = f"{model} (Index {index})" # Create info string for logger
# ---> 98 response = await with_api_retries(
#      99     lambda: gemini.generate_content_async(user_prompt, generation_config=cfg),
#     100     model_info=model_info # Pass info to the retry wrapper
#     101 )
#     103 text_response = response.text
#     104 usage = {"input_tokens": 0, "output_tokens": 0, "cached_tokens": 0}
#
# Cell In[8], line 36, in with_api_retries(send_coroutine_factory, model_info, max_attempts, base_wait_seconds)
#      34 for attempt in range(max_attempts):
#      35     try:
# ---> 36         return await send_coroutine_factory()
#      37     except (openai.RateLimitError, anthropic.RateLimitError, Exception) as e:
#      38         # Check for specific rate limit error types or a 429 status code in the error string
#      39         if isinstance(e, (openai.RateLimitError, anthropic.RateLimitError)) or "429" in str(e):
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/google/generativeai/generative_models.py:385, in GenerativeModel.generate_content_async(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     383         return await generation_types.AsyncGenerateContentResponse.from_aiterator(iterator)
#     384     else:
# --> 385         response = await self._async_client.generate_content(
#     386             request,
#     387             **request_options,
#     388         )
#     389         return generation_types.AsyncGenerateContentResponse.from_response(response)
#     390 except google.api_core.exceptions.InvalidArgument as e:
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/async_client.py:440, in GenerativeServiceAsyncClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     437 self._client._validate_universe_domain()
#     439 # Send the request.
# --> 440 response = await rpc(
#     441     request,
#     442     retry=retry,
#     443     timeout=timeout,
#     444     metadata=metadata,
#     445 )
#     447 # Done; return the response.
#     448 return response
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/google/api_core/retry/retry_unary_async.py:231, in AsyncRetry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     227 """A wrapper that calls target function with retry."""
#     228 sleep_generator = exponential_sleep_generator(
#     229     self._initial, self._maximum, multiplier=self._multiplier
#     230 )
# --> 231 return await retry_target(
#     232     functools.partial(func, *args, **kwargs),
#     233     predicate=self._predicate,
#     234     sleep_generator=sleep_generator,
#     235     timeout=self._timeout,
#     236     on_error=on_error,
#     237 )
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/google/api_core/retry/retry_unary_async.py:158, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     156 while True:
#     157     try:
# --> 158         return await target()
#     159     # pylint: disable=broad-except
#     160     # This function explicitly must deal with broad exceptions.
#     161     except Exception as exc:
#     162         # defer to shared logic for handling errors
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/google/api_core/grpc_helpers_async.py:85, in _WrappedUnaryResponseMixin.__await__(self)
#      83 def __await__(self) -> Iterator[P]:
#      84     try:
# ---> 85         response = yield from self._call.__await__()
#      86         return response
#      87     except grpc.RpcError as rpc_error:
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/grpc/aio/_interceptor.py:472, in _InterceptedUnaryResponseMixin.__await__(self)
#     470 def __await__(self):
#     471     call = yield from self._interceptors_task.__await__()
# --> 472     response = yield from call.__await__()
#     473     return response
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/grpc/aio/_call.py:308, in _UnaryResponseMixin.__await__(self)
#     306 """Wait till the ongoing RPC request finishes."""
#     307 try:
# --> 308     response = yield from self._call_response
#     309 except asyncio.CancelledError:
#     310     # Even if we caught all other CancelledError, there is still
#     311     # this corner case. If the application cancels immediately after
#     312     # the Call object is created, we will observe this
#     313     # `CancelledError`.
#     314     if not self.cancelled():
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/asyncio/futures.py:289, in Future.__await__(self)
#     287 if not self.done():
#     288     self._asyncio_future_blocking = True
# --> 289     yield self  # This tells Task to wait for completion.
#     290 if not self.done():
#     291     raise RuntimeError("await wasn't used with future")
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/asyncio/futures.py:197, in Future.result(self)
#     190 """Return the result this future represents.
#     191
#     192 If the future has been cancelled, raises CancelledError.  If the
#     193 future's result isn't yet available, raises InvalidStateError.  If
#     194 the future is done and has an exception set, this exception is raised.
#     195 """
#     196 if self._state == _CANCELLED:
# --> 197     raise self._make_cancelled_error()
#     198 if self._state != _FINISHED:
#     199     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:

# %% [markdown]
# ### Running the manifest generation process

# %%
# # Choose the list of indices to generate manifests for
# UPPER_LIMIT = 500
# INDICES_TO_GENERATE = [idx for idx in TIER_LISTS["tier1"] if idx <= UPPER_LIMIT]

# # Run the manifest generation process
# perf_df = await generate_manifests_parallel(indices_to_generate=INDICES_TO_GENERATE)
# Out:
# --- Starting Manifest Generation ---
# Generating Manifests:   0%|          | 0/187 [00:00<?, ?it/s]
# 🕒 Rate limit error encountered. Retrying in 5.46 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.32 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.22 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.67 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.46 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.38 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.57 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.93 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.35 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.17 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.47 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.80 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.66 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.74 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.83 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.55 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.65 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.77 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.45 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.46 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.42 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.68 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.18 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.24 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.88 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.32 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.28 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.98 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.15 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.58 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.43 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.38 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.65 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.52 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.03 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.99 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.20 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.77 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.84 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.06 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.43 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.76 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.42 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.86 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.91 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.70 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.71 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.52 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.92 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.60 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.65 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.08 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.24 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.16 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.72 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.66 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.80 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.32 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.34 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.20 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.11 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.72 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.98 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.99 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.38 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.40 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.95 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.37 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.27 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.15 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.33 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.94 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.03 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.33 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.97 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.76 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.30 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.37 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.28 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.53 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.70 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.90 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.38 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.76 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.28 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.76 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.69 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.53 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.69 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.95 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.74 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.41 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.84 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.56 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.71 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.14 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.99 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.27 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.28 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.14 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.39 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.03 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.26 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.80 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.48 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.52 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.60 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.54 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.52 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.17 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.25 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.87 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.84 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.81 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.37 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.46 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.02 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.37 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.84 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.38 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.24 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.48 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.52 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.19 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.03 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.63 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.89 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.79 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.04 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.10 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.21 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.33 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.39 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.03 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 6.00 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.53 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.07 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.10 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.15 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.37 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.77 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.92 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.82 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.09 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.69 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.92 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.97 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.36 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.34 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.56 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.23 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.17 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.02 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.14 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.85 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.81 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 5.24 seconds... (Attempt 1/10)
# 🕒 Rate limit error encountered. Retrying in 10.35 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.05 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.26 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.78 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.10 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.71 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.75 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.34 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.19 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.53 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.69 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.15 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.21 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.23 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.70 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.09 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 11.00 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.77 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.43 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.89 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.49 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.94 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.83 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.61 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.23 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.67 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.35 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.38 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.93 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.76 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.79 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.10 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.45 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.01 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.68 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.83 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.51 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.15 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.97 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.07 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.53 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.88 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.49 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.42 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.17 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.64 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.48 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.50 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.27 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.65 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.86 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.94 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.63 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.26 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.88 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.41 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.30 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.53 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.07 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.03 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.80 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.13 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.23 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.59 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.77 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.88 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.43 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.27 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.66 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.35 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.80 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.49 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.74 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.53 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.10 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.71 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.28 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.27 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.67 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.49 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.88 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.49 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.15 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.20 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.99 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.46 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.28 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.58 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.39 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.75 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.34 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.55 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.50 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.71 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.66 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.12 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.43 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.44 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.00 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.82 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.63 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.25 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.76 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.65 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.59 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.06 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.10 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.25 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.37 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.17 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.12 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.22 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.46 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.66 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.89 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.32 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.48 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.41 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.48 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.58 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.36 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.68 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.40 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.11 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.11 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.39 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.91 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.33 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.31 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.30 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.72 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.04 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.41 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.96 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.90 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.95 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.22 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.13 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.15 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.15 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.86 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.41 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.76 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.64 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.16 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.79 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.22 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.71 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.78 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.50 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.60 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.96 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.54 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.66 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.73 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 10.05 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 20.34 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.68 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.49 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.56 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.21 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 10.84 seconds... (Attempt 2/10)
# 🕒 Rate limit error encountered. Retrying in 20.98 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.30 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.64 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.70 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.96 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.83 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.63 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.56 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.77 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.98 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.02 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.94 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.67 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.80 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.70 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.19 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.18 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.43 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.60 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.45 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.29 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.81 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.90 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.84 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.99 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.89 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.06 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.82 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.55 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.10 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.71 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.12 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.56 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.02 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.01 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.84 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.70 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.21 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.49 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.50 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.14 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.43 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.81 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.95 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.35 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.96 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.17 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.80 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.93 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.71 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.72 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.66 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.79 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.03 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.41 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.00 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.71 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.48 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.39 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.18 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.86 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.52 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.57 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.01 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.90 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.24 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.60 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.53 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.54 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.45 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.34 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.29 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.94 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.54 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.69 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.46 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.10 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.74 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.11 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.73 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.40 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.22 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.55 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.99 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.50 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.92 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.21 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.38 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.98 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.73 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.56 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.18 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.11 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.70 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.18 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.42 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.77 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.07 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.85 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.54 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.45 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.61 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.00 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.92 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.36 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.09 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.70 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.90 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.32 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.97 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.16 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.03 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.10 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.30 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.66 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.18 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.58 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.89 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.90 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.06 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.15 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.83 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.36 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.54 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.83 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.12 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.44 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.79 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.91 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.15 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.41 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.61 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.50 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.84 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.76 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.91 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.66 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.02 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.11 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.14 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.06 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.46 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.21 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.35 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.39 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.77 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.37 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.47 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.77 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.54 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 20.29 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 40.91 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 20.64 seconds... (Attempt 3/10)
# 🕒 Rate limit error encountered. Retrying in 40.44 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.27 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.26 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.14 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.10 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.75 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.91 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.03 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.92 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.52 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.20 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.01 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.56 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.97 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.99 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.00 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.08 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.11 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.00 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.82 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.82 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.62 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.65 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.01 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.60 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.25 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.39 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.12 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.41 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.75 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.97 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.21 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.54 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.79 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.23 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.48 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.98 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.05 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.20 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.44 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.07 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.69 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.39 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.35 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.02 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.27 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.90 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.58 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.68 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.73 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.48 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.42 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.11 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.31 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.57 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.59 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.21 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.65 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.71 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.07 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.49 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.72 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.64 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.62 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.33 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.22 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.94 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.13 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.39 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.73 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.07 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.38 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.31 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.53 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.15 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.38 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.00 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.14 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.65 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.99 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.88 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.58 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.27 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.71 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.86 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.43 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.61 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.39 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.20 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.17 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.00 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.10 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.46 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.54 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.06 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.97 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.07 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.65 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.90 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.47 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.81 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.13 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.95 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.01 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.12 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.91 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.83 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.81 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.56 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.44 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.73 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.37 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.28 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.06 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.17 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.36 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.82 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.67 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.04 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.92 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.93 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.60 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.30 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.26 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.07 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.92 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.33 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.92 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.10 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.67 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.66 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.94 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.90 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.06 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.95 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.81 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.89 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.35 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.11 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.59 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.95 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.13 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.96 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.77 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.05 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.63 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.24 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.39 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.27 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.50 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.98 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.30 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.38 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.49 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.04 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 40.12 seconds... (Attempt 4/10)
# 🕒 Rate limit error encountered. Retrying in 80.62 seconds... (Attempt 5/10)
# 🕒 Rate limit error encountered. Retrying in 80.74 seconds... (Attempt 5/10)
# 🕒 Rate limit error encountered. Retrying in 80.84 seconds... (Attempt 5/10)
# 🕒 Rate limit error encountered. Retrying in 80.34 seconds... (Attempt 5/10)
# ...
# 🕒 Rate limit error encountered. Retrying in 320.04 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.35 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.34 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.11 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.42 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.64 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.84 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.39 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.07 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.32 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.08 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.60 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.72 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.04 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.23 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.49 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.98 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.66 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.63 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.23 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.64 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.82 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.08 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.83 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.94 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.53 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.90 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.09 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.62 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.42 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.74 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.69 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.28 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.28 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.18 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.68 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.94 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.05 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.24 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.80 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.28 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.57 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.71 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.70 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.30 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.87 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.37 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.51 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.86 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.46 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.44 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.67 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.74 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.48 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.73 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.64 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.40 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.17 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.38 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.06 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.71 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.49 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.23 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.04 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.15 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.98 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.91 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.66 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.18 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.87 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.09 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.04 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.43 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.37 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.43 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.02 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.46 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.36 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.89 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.62 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.71 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.36 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.14 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.27 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.77 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.70 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.87 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.47 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.46 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 320.63 seconds... (Attempt 7/10)
# 🕒 Rate limit error encountered. Retrying in 640.17 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.18 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.96 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.35 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.05 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.21 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.76 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.91 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.58 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.18 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.17 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.47 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.70 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.68 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.05 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.45 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.03 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.33 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.07 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.07 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.07 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.96 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.54 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.23 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.15 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.28 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.39 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.99 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.14 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.39 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.06 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.14 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.12 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.02 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.42 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.93 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.50 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.34 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.18 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.95 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.09 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.31 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.17 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.57 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.97 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.13 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.62 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.41 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.49 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.36 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.39 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.80 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.72 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.92 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.02 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.04 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.78 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.94 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.83 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.95 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.72 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.25 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.67 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.03 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.77 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.87 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.75 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.33 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.60 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.41 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.49 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.95 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.65 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.91 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.23 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.95 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.18 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.52 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.84 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.07 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.09 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.93 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.87 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.03 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.86 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.94 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.22 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.06 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.28 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.58 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.51 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.03 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.45 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.06 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.82 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.14 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.02 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.46 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.48 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.32 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.11 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.09 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.75 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.06 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.93 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.87 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.39 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.25 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.91 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.50 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.40 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.61 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.81 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.25 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.97 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.94 seconds... (Attempt 8/10)
# 🕒 Rate limit error encountered. Retrying in 640.53 seconds... (Attempt 8/10)

# %% [markdown]
# ### Display the performance DataFrame

# %%
display(perf_df)
# Out:
#    provider             model  index   status  time_s  input_tokens  \
# 0    openai           gpt-4.1      4  Success   35.76          4548
# 1    google  gemini-2.5-flash      4  Success   35.76          5115
# 2    openai           gpt-4.1      6  Success    7.90          4585
# 3    google  gemini-2.5-flash      6  Success    7.90          5157
# 4    openai           gpt-4.1      7  Success    9.82          4671
# 5    google  gemini-2.5-flash      7  Success    9.82          5229
# 6    openai           gpt-4.1     17  Success   16.91          4755
# 7    google  gemini-2.5-flash     17  Success   16.91          5340
# 8    openai           gpt-4.1     18  Success   10.56          4664
# 9    google  gemini-2.5-flash     18  Success   10.56          5224
# 10   openai           gpt-4.1     20  Success    8.27          4598
# 11   google  gemini-2.5-flash     20  Success    8.27          5168
# 12   openai           gpt-4.1     21  Success   12.21          4624
# 13   google  gemini-2.5-flash     21  Success   12.21          5189
# 14   openai           gpt-4.1     22  Success   36.37          4590
# 15   google  gemini-2.5-flash     22  Success   36.37          5159
# 16   openai           gpt-4.1     24  Success    6.47          4577
# 17   google  gemini-2.5-flash     24  Success    6.47          5152
# 18   openai           gpt-4.1     28  Success    6.32          4572
# 19   google  gemini-2.5-flash     28  Success    6.32          5128
#
#     output_tokens  cached_tokens              utc_completed
# 0             453           4352  2025-07-08T16:22:55+00:00
# 1             636              0  2025-07-08T16:22:55+00:00
# 2             473           4352  2025-07-08T16:22:27+00:00
# 3             695              0  2025-07-08T16:22:27+00:00
# 4             519           4352  2025-07-08T16:22:29+00:00
# 5             697              0  2025-07-08T16:22:29+00:00
# 6             879           4352  2025-07-08T16:22:36+00:00
# 7             868              0  2025-07-08T16:22:36+00:00
# 8             748           4352  2025-07-08T16:22:30+00:00
# 9            1124              0  2025-07-08T16:22:30+00:00
# 10            486           4352  2025-07-08T16:22:28+00:00
# 11            579              0  2025-07-08T16:22:28+00:00
# 12            591              0  2025-07-08T16:22:32+00:00
# 13            615              0  2025-07-08T16:22:32+00:00
# 14            498           4352  2025-07-08T16:22:56+00:00
# 15            611              0  2025-07-08T16:22:56+00:00
# 16            316              0  2025-07-08T16:22:26+00:00
# 17            433              0  2025-07-08T16:22:26+00:00
# 18            395           4352  2025-07-08T16:22:26+00:00
# 19            483              0  2025-07-08T16:22:26+00:00

# %% [markdown]
# ### Helper function to concatenate manifests (useful for sharing in AI chat)

# %%
# def concatenate_complete_manifests(
#         indices: List[int], 
#         models: List[str], 
#         manifest_dir: Path, 
#         dataset: List[Dict[str, Any]]
#     ) -> str:
#     """
#     For each index, concatenate the wrapper output and manifest outputs for all models.
#     Returns the full text as a string.
#     """
#     def wrapper(index: int):
#         sample = dataset[index]
#         to_return = "=" * 50 + "\n\n"
#         to_return += f"**Index:** {index}\n\n"
#         to_return += "**Question:**\n"
#         to_return += f"{sample['question']}\n\n"
#         to_return += "**Solution mapping:**\n"
#         to_return += f"{build_solution_mapping(index, dataset)}\n\n"
#         return to_return

#     all_text = ""
#     for index in indices:
#         all_text += wrapper(index)
#         for model in models:
#             filepath = manifest_dir / f"{index}" / f"{model}.txt"
#             with open(filepath, 'r', encoding='utf-8') as f:
#                 content = f.read().strip()
#             all_text += f"--- {model} Output for Index {index} ---\n{content}\n\n"
#     return all_text.strip()

# # Usage and save to file
# initial_manifests_text = concatenate_complete_manifests(
#     indices=INDICES_TO_GENERATE, 
#     models=MODELS, 
#     manifest_dir=MANIFEST_OUTPUT_DIR, 
#     dataset=GSM8K_TRAIN
# )
# with open(MANIFEST_OUTPUT_DIR / "initial_manifests.txt", 'w', encoding='utf-8') as f:
#     f.write(initial_manifests_text)

# %%
import asyncio
import time
from collections import deque
import google.generativeai as genai
import threading # For thread-safe deque access in a multi-threaded context (optional, if using threads)

# Configure your API key (replace with your actual key)
# genai.configure(api_key="YOUR_API_KEY")

# --- Asynchronous Client Setup ---
# Initialize the asynchronous model
# Note: genai.GenerativeModel can be used asynchronously directly.
# The async client handles the underlying aiohttp requests.
model = genai.GenerativeModel('gemini-2.5-flash')

# --- Asynchronous Client-side RPM Tracker ---
# Use a deque for timestamps.
# In an async context, if multiple coroutines are modifying this, it's inherently single-threaded
# within the event loop, but if you were to spawn multiple processes or actual threads,
# you'd need synchronization (e.g., threading.Lock). For pure asyncio, it's fine.
request_timestamps = deque()
MAX_REQUESTS_PER_MINUTE = 60 # Example limit: adjust based on actual API limits

# An asyncio Lock to protect the deque if multiple tasks are modifying it concurrently
# (though for a single shared deque, careful design can avoid explicit locking).
# For simplicity in this pattern, we'll manage the deque in a way that minimizes race conditions.
# However, if you were dynamically creating many concurrent tasks, a lock would be safer.
deque_lock = asyncio.Lock()


async def make_api_request_with_rpm_check_async(prompt: str, task_id: int):
    """
    Makes an asynchronous API request, respecting RPM limits.
    """
    global request_timestamps

    while True:
        current_time = time.time() # Use time.time() for wall-clock time
        # Acquire lock to safely modify shared deque
        async with deque_lock:
            # Remove timestamps older than 60 seconds
            while request_timestamps and request_timestamps[0] < current_time - 60:
                request_timestamps.popleft()

            # Check if we are about to exceed the limit
            if len(request_timestamps) >= MAX_REQUESTS_PER_MINUTE:
                # Calculate how long to wait until the oldest request falls out of the window
                time_to_wait = (request_timestamps[0] + 60) - current_time
                if time_to_wait > 0:
                    print(f"Task {task_id}: RPM limit approaching. Waiting {time_to_wait:.2f} seconds...")
                    # Release lock before awaiting sleep
                    await asyncio.sleep(time_to_wait)
                    continue # Re-evaluate after waiting

            # If we reach here, we're allowed to make a request
            request_timestamps.append(current_time)
            current_estimated_rpm = len(request_timestamps)
            # Release lock before making the actual API call
            break

    try:
        # Make the actual asynchronous API call
        response = await model.generate_content_async(prompt)
        print(f"Task {task_id}: Request successful. Current Estimated RPM: {current_estimated_rpm}. Response: {response.text[:50]}...")
        return response
    except Exception as e:
        print(f"Task {task_id}: API Request Failed: {e}")
        # Implement specific error handling (e.g., retries for RESOURCE_EXHAUSTED)
        return None

async def main():
    test_prompts = [f"Tell me a short story about a cat named {i}." for i in range(1, 101)] # More prompts for concurrent testing

    # Create a list of tasks
    tasks = []
    for i, prompt in enumerate(test_prompts):
        task = asyncio.create_task(make_api_request_with_rpm_check_async(prompt, i + 1))
        tasks.append(task)

    # Await all tasks to complete
    await asyncio.gather(*tasks)

if __name__ == "__main__":
    start_time = time.time()
    asyncio.run(main())
    end_time = time.time()
    print(f"\nAll tasks completed in {end_time - start_time:.2f} seconds.")
# Out:
# Task 61: RPM limit approaching. Waiting 60.00 seconds...
# Task 51: Request successful. Current Estimated RPM: 51. Response: 51 wasn't like other cats. He appeared one Tuesday...
# Task 38: Request successful. Current Estimated RPM: 38. Response: 38 was not a name for a cat. It was a serial numbe...
# Task 48: Request successful. Current Estimated RPM: 48. Response: In the chaotic symphony of a busy animal shelter, ...
# Task 3: Request successful. Current Estimated RPM: 3. Response: Three wasn't just a number; Three was a cat. A sle...
# Task 58: Request successful. Current Estimated RPM: 58. Response: The first thing you noticed about 58 was his name....
# Task 37: Request successful. Current Estimated RPM: 37. Response: In a facility of cool, clinical whites and humming...
# Task 7: Request successful. Current Estimated RPM: 7. Response: The first light of dawn was always 7's favorite. N...
# Task 13: Request successful. Current Estimated RPM: 13. Response: The name 13 wasn't given out of malice, but out of...
# Task 56: Request successful. Current Estimated RPM: 56. Response: The cat’s name was 56. Not Fifty-Six, not Lord 56,...
# Task 17: Request successful. Current Estimated RPM: 17. Response: Seventeen was a name given to him at the shelter, ...
# Task 39: Request successful. Current Estimated RPM: 39. Response: 39 was not a name given with love. It was a tag, a...
# Task 32: Request successful. Current Estimated RPM: 32. Response: In the quiet hum of the animal shelter, Cat Unit 7...
# Task 10: Request successful. Current Estimated RPM: 10. Response: 10 was a cat who carried his name with a quiet dig...
# Task 23: Request successful. Current Estimated RPM: 23. Response: 23 wasn't a name, not really. It was a designation...
# Task 12: Request successful. Current Estimated RPM: 12. Response: The cat was named 12. Not 'Twelve,' just '12.' A t...
# Task 20: Request successful. Current Estimated RPM: 20. Response: In the echoing quiet of the city’s animal shelter,...
# Task 60: Request successful. Current Estimated RPM: 60. Response: The cat was named 60. Not because she was the 60th...
# Task 19: Request successful. Current Estimated RPM: 19. Response: 19 wasn't like other cats. For one, his name wasn'...
# Task 29: Request successful. Current Estimated RPM: 29. Response: His name was 29. Not Whiskers, or Midnight, or eve...
# Task 55: Request successful. Current Estimated RPM: 55. Response: 55 wasn't just a number. Not to Elara, who had a p...
# Task 15: Request successful. Current Estimated RPM: 15. Response: Dr. Aris Thorne, a man whose life was as meticulou...
# Task 14: Request successful. Current Estimated RPM: 14. Response: There once was a cat named 14. Not Fourteen, the m...
# Task 49: Request successful. Current Estimated RPM: 49. Response: The shelter hummed with the muted chaos of despera...
# Task 18: Request successful. Current Estimated RPM: 18. Response: 18 was not a name given lightly, nor was it a numb...
# Task 47: Request successful. Current Estimated RPM: 47. Response: 47 was not a cat named forty-seven. He was, quite ...
# Task 1: Request successful. Current Estimated RPM: 1. Response: 1 was a cat of precise habits and singular focus. ...
# Task 46: Request successful. Current Estimated RPM: 46. Response: 46 was not a name given with affection, but with p...
# Task 8: Request successful. Current Estimated RPM: 8. Response: Eight wasn't just a cat; he was a silent, sleek ob...
# Task 11: Request successful. Current Estimated RPM: 11. Response: 11 wasn't a name, not really. It was a designation...
# Task 42: Request successful. Current Estimated RPM: 42. Response: Sarah had named him 42, a nod to a book she loved,...
# Task 28: Request successful. Current Estimated RPM: 28. Response: He wasn't a "Whiskers" or a "Mittens." He was 28. ...
# Task 27: Request successful. Current Estimated RPM: 27. Response: Twenty-seven was not a name given with affection. ...
# Task 50: Request successful. Current Estimated RPM: 50. Response: Fifty was not a common name for a cat, nor was he ...
# Task 54: Request successful. Current Estimated RPM: 54. Response: In the echoing, clinical expanse of the city shelt...
# Task 2: Request successful. Current Estimated RPM: 2. Response: No one quite knew why Elara had named the sleek bl...
# Task 26: Request successful. Current Estimated RPM: 26. Response: The fluorescent hum of the shelter was a constant,...
# Task 36: Request successful. Current Estimated RPM: 36. Response: 36 wasn't a name you whispered into a fur-lined ea...
# Task 43: Request successful. Current Estimated RPM: 43. Response: In the sterile, echoing halls of the city animal s...
# Task 31: Request successful. Current Estimated RPM: 31. Response: 31 knew the world in sterile squares of white ligh...
# Task 44: Request successful. Current Estimated RPM: 44. Response: In the echoing halls of the City Animal Rehabilita...
# Task 5: Request successful. Current Estimated RPM: 5. Response: Five was a cat of quiet habits and an even quieter...
# Task 4: Request successful. Current Estimated RPM: 4. Response: The cat’s name was 4. Not ‘Four’ as in the word, b...
# Task 57: Request successful. Current Estimated RPM: 57. Response: 57 was a number, not a name. He knew this. The hum...
# Task 59: Request successful. Current Estimated RPM: 59. Response: 59 wasn't a cat. Not in the fluffy, purring, lap-w...
# Task 53: Request successful. Current Estimated RPM: 53. Response: In the sterile hum of the shelter, he was just 53....
# Task 22: Request successful. Current Estimated RPM: 22. Response: The cat named 22 wasn’t a sleek, silent shadow. Oh...
# Task 6: Request successful. Current Estimated RPM: 6. Response: The cat named Six wasn't an ordinary cat, though t...
# Task 24: Request successful. Current Estimated RPM: 24. Response: 24 wasn't a name chosen for cuteness. It was a des...
# Task 30: Request successful. Current Estimated RPM: 30. Response: 30 was a cat of quiet dignity, despite his name. H...
# Task 40: Request successful. Current Estimated RPM: 40. Response: The cat named 40 wasn't named for his age, nor for...
# Task 21: Request successful. Current Estimated RPM: 21. Response: In the sterile, echoing halls of the local animal ...
# Task 34: Request successful. Current Estimated RPM: 34. Response: The cat named 34 was not fluffy, nor Mittens, nor ...
# Task 9: Request successful. Current Estimated RPM: 9. Response: The cat named 9 was not like other cats. For one, ...
# Task 41: Request successful. Current Estimated RPM: 41. Response: The fluorescent hum of the shelter was a constant,...
# Task 52: Request successful. Current Estimated RPM: 52. Response: In a world of Fluffies, Mittens, and Patches, ther...
# Task 33: Request successful. Current Estimated RPM: 33. Response: The cat known as 33 was not sleek or fluffy, nor w...
# Task 16: Request successful. Current Estimated RPM: 16. Response: 16 wasn't a typical cat. For one, there was his na...
# Task 25: Request successful. Current Estimated RPM: 25. Response: For a long time, the scruffy tabby with the slight...
# Task 45: Request successful. Current Estimated RPM: 45. Response: The cat named 45 wasn't named for a caliber, a spe...
# Task 35: Request successful. Current Estimated RPM: 35. Response: In the humming, sterile corridors of the old Bio-T...
# Task 62: RPM limit approaching. Waiting 60.00 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 85
#      83 if __name__ == "__main__":
#      84     start_time = time.time()
# ---> 85     asyncio.run(main())
#      86     end_time = time.time()
#      87     print(f"\nAll tasks completed in {end_time - start_time:.2f} seconds.")
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /opt/miniconda3/envs/erdos-dl/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
