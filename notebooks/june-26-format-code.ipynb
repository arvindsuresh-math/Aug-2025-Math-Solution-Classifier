# %%
import ast
import sys
from pathlib import Path
import shutil

# ---------------------------------------------------------------------- #
#  Global constants & Configuration
# ---------------------------------------------------------------------- #

def find_project_root():
    """Traverse upwards to find the project root, marked by the .git folder."""
    current_path = Path.cwd()
    while current_path != current_path.parent:
        if (current_path / ".git").is_dir():
            return current_path
        current_path = current_path.parent
    raise FileNotFoundError("Could not find project root. Is this a git repository?")


PROJECT_ROOT = find_project_root()
BASE_INPUT_DIR = PROJECT_ROOT / 'data' / 'code_gen_outputs_cleaned'
BASE_OUTPUT_DIR = PROJECT_ROOT / 'data' / 'code_gen_outputs_formatted'
print(f"Project root found: {PROJECT_ROOT}")
print(f"Base input directory set to: {BASE_INPUT_DIR}")
print(f"Base output directory set to: {BASE_OUTPUT_DIR}")

MODEL_DICT = {
  "anthropic": ["claude-3-5-haiku-20241022"], 
  "openai": ["gpt-4.1-mini"],
  "google": ["gemini-2.0-flash-thinking-exp", 
             "gemini-2.5-flash-lite-preview-06-17",
             "gemini-2.5-flash"]
}

MODELS = [f"{provider}_{model}" for provider, sublist in MODEL_DICT.items() for model in sublist]
print(f"Available models: {MODELS}")

INDICES = list(range(100))
# Out:
# Project root found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math
# Base input directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned
# Base output directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted
# Available models: ['anthropic_claude-3-5-haiku-20241022', 'openai_gpt-4.1-mini', 'google_gemini-2.0-flash-thinking-exp', 'google_gemini-2.5-flash-lite-preview-06-17', 'google_gemini-2.5-flash']

# %%
import re

def get_code_lines_dict(
        problem_index: int, 
        model_name: str, 
        base_input_dir: Path = BASE_INPUT_DIR):
    """
    Returns a dict mapping line numbers (0-based) to the verbatim lines of code
    for the given problem index and model name.
    """
    import sys
    problem_dir = base_input_dir / str(problem_index)
    file_path = problem_dir / f"{model_name}.py"
    if not file_path.exists():
        print(f"[Error] File not found: {file_path}", file=sys.stderr)
        return None
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
    return {i: line.rstrip("\n") for i, line in enumerate(lines)}


def replace_final_answer_comment(code_lines_dict):
    """
    Returns a new dict where any line that begins with 'answer =' (ignoring leading whitespace)
    is preceded by a '#: FA' comment line.
    """
    new_dict = {}
    new_idx = 0
    for idx in range(len(code_lines_dict)):
        line = code_lines_dict[idx]
        if line.lstrip().startswith("answer ="):
            new_dict[new_idx] = "#: FA"
            new_dict[new_idx + 1] = line
            new_idx += 2
        else:
            new_dict[new_idx] = line
            new_idx += 1
    return new_dict

def format_comment(comment_line):
    """
    Accepts a comment string. Returns '\n' if not in the format '#: ... Ln' or '#: FA'.
    If correct, returns '#: Ln' or '#: FA' (ignoring everything between).
    """
    comment_line = comment_line.strip()
    if comment_line.startswith("#:") and comment_line.endswith("FA"):
        return "#: FA"
    m = re.match(r"^#:(.*)L(\d+)\s*$", comment_line)
    if m:
        return f"#: L{m.group(2)}"
    return "\n"

def remove_trailing_comment(code_line):
    """
    Removes trailing comment from a code line.
    If it finds the trailing comment '# FINAL ANSWER', then it returns ': FA' on one line and the code on the next. If it finds any other comment, it just removes the comment and returns the code line.
    """
    if "#" not in code_line:
        return code_line
    code, _ = code_line.split("#", 1)
    return code.rstrip()

def remove_redundant_comments(lines):
    """
    Removes any comment line that is immediately followed by another comment line.
    But keeps '#: FA' comments even if followed by 'answer =' lines.
    """
    result = []
    for i, line in enumerate(lines):
        if line.startswith("#:"):
            # If next line is also a comment, skip this one
            if i + 1 < len(lines) and lines[i + 1].startswith("#:"):
                continue
            # If next line begins with "answer" and this is NOT a FA comment, skip this one
            if (i + 1 < len(lines) and 
                lines[i + 1].lstrip().startswith("answer") and 
                line.strip() != "#: FA"):
                continue
        result.append(line)
    return result

def format_generated_code(code_lines_dict):
    """
    Cleans and formats generated code according to the specified rules.
    """

    # Format the final answer portion
    code_lines_dict = replace_final_answer_comment(code_lines_dict)

    # Split into lines for further processing
    lines = list(code_lines_dict.values())

    # Find the end of the func signature/docstring
    sig_end = 0
    for i, line in enumerate(lines):
        if line.strip().endswith('"""'):
            sig_end = i
            break
    signature = lines[:sig_end + 1]
    body = lines[sig_end + 1:]

    # Format comments and remove trailing comments
    processed = []
    for line in body:
        stripped = line.strip()
        if stripped.startswith("#"):
            processed.append(format_comment(stripped))
        elif stripped == "":
            processed.append("\n")
        else:
            processed.append(remove_trailing_comment(line))

    # Remove all line breaks, keep only comments or code
    processed = [l for l in processed if l.strip() != ""]

    # Third pass: remove redundant comments
    processed = remove_redundant_comments(processed)

    # Assemble final code: signature, then body with correct indentation and blank lines before comments
    final_lines = signature.copy()
    indent = "    "
    for line in processed:
        if line.startswith("#:"):
            final_lines.append("")  # blank line before comment
            final_lines.append(f"{indent}{line}")
        else:
            final_lines.append(f"{indent}{line.strip()}")

    # Remove any extra blank lines at the end
    while final_lines and final_lines[-1].strip() == "":
        final_lines.pop()

    return "\n".join(final_lines)

def batch_format_and_write(
    indices,
    models = MODELS,
    base_input_dir = BASE_INPUT_DIR,
    base_output_dir = BASE_OUTPUT_DIR,
    get_code_lines_dict=get_code_lines_dict,
    format_generated_code=format_generated_code
):
    """
    For each (index, model), generate formatted code and write to {base_output_dir}/{index}/{model}.py
    """
    for idx in indices:
        for model in models:
            code_lines_dict = get_code_lines_dict(idx, model, base_input_dir)
            if code_lines_dict is None:
                print(f"[Warning] No code for index={idx}, model={model}")
                continue
            formatted_code = format_generated_code(code_lines_dict)
            out_dir = base_output_dir / str(idx)
            out_dir.mkdir(parents=True, exist_ok=True)
            out_path = out_dir / f"{model}.py"
            with open(out_path, "w", encoding="utf-8") as f:
                f.write(formatted_code)
            print(f"Wrote formatted code to {out_path}")

# ---------------------------------------------------------------------- #

def format_code_wrapper(index: int):
    for model in MODELS:
        lines_dict = get_code_lines_dict(index, model)
        if lines_dict is not None:
            cleaned_code = format_generated_code(lines_dict)
            print("="*50)
            print(f"Cleaned code for {model}")
            print("-"*50)
            print(cleaned_code)
        else:
            print(f"[Error] No code found for {model} at index {index}", file=sys.stderr)

# %%
batch_format_and_write(INDICES)
# Out:
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/0/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/0/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/0/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/0/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/0/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/1/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/1/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/1/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/1/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/1/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/2/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/2/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/2/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/2/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/2/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/3/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/3/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/3/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/3/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/3/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/4/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/4/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/4/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/4/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/4/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/5/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/5/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/5/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/5/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/5/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/6/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/6/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/6/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/6/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/6/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/7/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/7/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/7/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/7/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/7/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/8/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/8/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/8/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/8/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/8/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/9/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/9/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/9/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/9/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/9/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/10/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/10/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/10/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/10/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/10/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/11/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/11/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/11/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/11/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/11/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/12/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/12/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/12/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/12/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/12/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/13/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/13/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/13/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/13/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/13/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/14/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/14/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/14/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/14/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/14/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/15/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/15/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/15/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/15/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/15/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/16/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/16/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/16/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/16/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/16/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/17/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/17/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/17/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/17/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/17/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/18/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/18/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/18/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/18/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/18/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/19/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/19/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/19/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/19/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/19/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/20/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/20/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/20/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/20/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/20/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/21/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/21/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/21/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/21/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/21/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/22/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/22/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/22/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/22/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/22/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/23/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/23/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/23/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/23/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/23/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/24/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/24/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/24/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/24/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/24/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/25/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/25/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/25/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/25/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/25/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/26/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/26/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/26/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/26/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/26/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/27/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/27/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/27/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/27/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/27/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/28/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/28/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/28/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/28/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/28/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/29/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/29/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/29/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/29/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/29/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/30/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/30/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/30/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/30/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/30/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/31/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/31/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/31/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/31/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/31/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/32/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/32/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/32/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/32/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/32/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/33/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/33/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/33/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/33/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/33/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/34/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/34/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/34/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/34/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/34/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/35/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/35/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/35/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/35/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/35/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/36/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/36/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/36/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/36/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/36/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/37/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/37/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/37/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/37/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/37/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/38/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/38/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/38/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/38/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/38/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/39/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/39/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/39/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/39/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/39/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/40/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/40/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/40/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/40/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/40/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/41/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/41/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/41/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/41/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/41/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/42/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/42/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/42/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/42/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/42/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/43/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/43/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/43/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/43/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/43/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/44/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/44/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/44/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/44/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/44/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/45/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/45/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/45/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/45/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/45/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/46/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/46/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/46/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/46/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/46/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/47/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/47/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/47/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/47/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/47/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/48/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/48/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/48/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/48/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/48/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/49/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/49/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/49/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/49/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/49/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/50/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/50/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/50/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/50/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/50/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/51/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/51/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/51/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/51/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/51/google_gemini-2.5-flash.py
# [Warning] No code for index=52, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/53/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/53/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/53/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/53/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/53/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/54/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/54/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/54/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/54/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/54/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/55/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/55/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/55/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/55/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/55/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/56/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/56/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/56/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/56/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/56/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/57/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/57/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/57/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/57/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/57/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/58/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/58/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/58/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/58/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/58/google_gemini-2.5-flash.py
# [Warning] No code for index=59, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/60/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/60/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/60/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/60/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/60/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/61/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/61/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/61/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/61/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/61/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/62/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/62/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/62/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/62/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/62/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/63/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/63/openai_gpt-4.1-mini.py
# ...
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/80/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/80/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/80/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/80/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/81/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/81/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/81/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/81/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/81/google_gemini-2.5-flash.py
# [Warning] No code for index=82, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/83/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/83/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/83/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/83/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/83/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/84/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/84/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/84/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/84/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/84/google_gemini-2.5-flash.py
# [Warning] No code for index=85, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/86/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/86/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/86/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/86/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/86/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/87/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/87/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/87/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/87/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/87/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/88/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/88/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/88/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/88/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/88/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/89/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/89/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/89/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/89/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/89/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/90/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/90/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/90/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/90/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/90/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/91/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/91/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/91/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/91/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/91/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/92/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/92/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/92/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/92/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/92/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/93/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/93/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/93/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/93/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/93/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/94/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/94/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/94/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/94/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/94/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/95/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/95/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/95/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/95/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/95/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/96/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/96/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/96/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/96/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/96/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/97/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/97/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/97/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/97/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/97/google_gemini-2.5-flash.py
# [Warning] No code for index=98, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/99/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/99/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/99/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/99/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/99/google_gemini-2.5-flash.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/52/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/59/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/71/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/76/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/82/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/85/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/98/anthropic_claude-3-5-haiku-20241022.py

# %%
def execution_trace(func):
    import inspect, ast
    src = inspect.getsource(func)
    tree = ast.parse(src)
    func_def = tree.body[0]
    env = {}
    for arg, default in zip(
        func_def.args.args[::-1], 
        func_def.args.defaults[::-1]
    ):
        env[arg.arg] = eval(compile(ast.Expression(default), '', 'eval'))
    for stmt in func_def.body:
        if isinstance(stmt, ast.Assign):
            code = compile(ast.Module([stmt], []), '', 'exec')
            exec(code, {}, env)
    # Return all variables, including arguments
    return env

def augment_code_with_trace(
    problem_index: int,
    model_name: str,
    input_dir: Path,
    output_dir: Path,
    verbose: bool = True
):
    """
    Augment a single Python file with execution trace comments using simple string replacement.
    """
    # Step 1: Get the individual lines of code
    code_lines_dict = get_code_lines_dict(problem_index, model_name, input_dir)
    if code_lines_dict is None:
        if verbose:
            print(f"Could not get code lines for problem {problem_index}, model {model_name}")
        return False
    
    try:
        # Load the module and get execution trace
        input_file = input_dir / str(problem_index) / f"{model_name}.py"
        spec = importlib.util.spec_from_file_location("module.name", input_file)
        if spec is None or spec.loader is None:
            if verbose:
                print(f"Could not load module spec for {input_file}")
            return False
                
        module = importlib.util.module_from_spec(spec)
        spec.loader.exec_module(module)
        
        # Get execution trace
        trace_dict = execution_trace(module.solve)
        
        # Step 2: Find the end of function signature (including docstring)
        lines = list(code_lines_dict.values())
        sig_end = -1
        for i, line in enumerate(lines):
            if line.strip().endswith('"""'):
                sig_end = i
                break
        
        if sig_end == -1:
            if verbose:
                print(f"Could not find end of docstring for {model_name}")
            return False
        
        # Split into signature and body
        signature_lines = lines[:sig_end + 1]
        body_lines = lines[sig_end + 1:]
        
        # Step 3-5: Process body lines
        processed_body = ""  # Start as empty string instead of list
        for line in body_lines:
            # Step 3: Add comment lines
            if line.strip().startswith('#'):
                processed_body += '\n'  # Add a blank line before comments
                processed_body += line + '\n'  # Append line with newline
                continue
            elif line.strip().startswith('answer ='):
                processed_body += line + '\n' # Do not add eval comment for answer lines
                continue
            
            # Step 4: For code lines, do search and replace
            if line.strip():  # Non-empty line
                eval_line = line
                sorted_trace_dict = sorted(trace_dict.items(), key=lambda x: len(x[0]), reverse=True)
                
                # Replace each variable with its value
                substituted = False
                for variable, value in sorted_trace_dict:
                    if variable in eval_line:
                        eval_line = eval_line.replace(variable, str(value))
                        substituted = True
                
                # Step 5: Append eval comment if any substitution happened
                if substituted:
                    # Get indentation from original line
                    new_line = line + " # eval: " + eval_line.lstrip()
                    processed_body += new_line + '\n'  # Append with newline
                else:
                    # If no substitution, just append the original line
                    processed_body += line + '\n'  # Append with newline
        
        # Step 6: Concatenate and save
        # Convert signature_lines to string and concatenate with processed_body
        signature_code = '\n'.join(signature_lines) + '\n'
        final_code = signature_code + processed_body
        
        # Write to output file
        output_file = output_dir / str(problem_index) / f"{model_name}.py"
        output_file.parent.mkdir(parents=True, exist_ok=True)
        
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(final_code)
        
        if verbose:
            print(f"Augmented {model_name} for problem {problem_index}")
        return True
        
    except Exception as e:
        if verbose:
            print(f"Error processing problem {problem_index}, model {model_name}: {e}")
        return False

def batch_augment_with_trace(
    indices: list,
    models: list = MODELS,
    input_dir: Path = PROJECT_ROOT / 'data' / 'code_gen_outputs_formatted',
    output_dir: Path = PROJECT_ROOT / 'data' / 'code_gen_outputs_traced',
    verbose: bool = True
):
    """
    Batch process multiple problems and models to augment code with execution traces.
    """
    success_count = 0
    total_count = 0
    
    for idx in indices:
        if verbose:
            print(f"Processing problem {idx}...")
        
        for model in models:
            total_count += 1
            if augment_code_with_trace(idx, model, input_dir, output_dir, verbose):
                success_count += 1
    
    if verbose:
        print(f"Completed: {success_count}/{total_count} files processed successfully")

# ---------------------------------------------------------------------- #

def augment_trace_wrapper(index: int):
    for model in MODELS:
        print(f"Execution trace for {model} with index {index}:")
        problem_dir = BASE_OUTPUT_DIR / f"{index}"
        py_file_path = problem_dir / f"{model}.py"
        try:
            spec = importlib.util.spec_from_file_location("module.name", py_file_path)
            module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(module)
        except FileNotFoundError:
            print(f"File not found: {py_file_path}, skipping.")
            continue
        except Exception as e:
            print(f"Error processing {py_file_path}: {e}, skipping.")
            continue

        trace = execution_trace(module.solve)
        display(trace)
        print("\n" + "="*50 + "\n")

# %%
batch_augment_with_trace(INDICES)
# Out:
# Processing problem 0...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 0
# Augmented openai_gpt-4.1-mini for problem 0
# Augmented google_gemini-2.0-flash-thinking-exp for problem 0
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 0
# Augmented google_gemini-2.5-flash for problem 0
# Processing problem 1...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 1
# Augmented openai_gpt-4.1-mini for problem 1
# Augmented google_gemini-2.0-flash-thinking-exp for problem 1
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 1
# Augmented google_gemini-2.5-flash for problem 1
# Processing problem 2...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 2
# Augmented openai_gpt-4.1-mini for problem 2
# Augmented google_gemini-2.0-flash-thinking-exp for problem 2
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 2
# Augmented google_gemini-2.5-flash for problem 2
# Processing problem 3...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 3
# Augmented openai_gpt-4.1-mini for problem 3
# Augmented google_gemini-2.0-flash-thinking-exp for problem 3
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 3
# Augmented google_gemini-2.5-flash for problem 3
# Processing problem 4...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 4
# Augmented openai_gpt-4.1-mini for problem 4
# Augmented google_gemini-2.0-flash-thinking-exp for problem 4
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 4
# Augmented google_gemini-2.5-flash for problem 4
# Processing problem 5...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 5
# Augmented openai_gpt-4.1-mini for problem 5
# Augmented google_gemini-2.0-flash-thinking-exp for problem 5
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 5
# Augmented google_gemini-2.5-flash for problem 5
# Processing problem 6...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 6
# Augmented openai_gpt-4.1-mini for problem 6
# Augmented google_gemini-2.0-flash-thinking-exp for problem 6
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 6
# Augmented google_gemini-2.5-flash for problem 6
# Processing problem 7...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 7
# Augmented openai_gpt-4.1-mini for problem 7
# Augmented google_gemini-2.0-flash-thinking-exp for problem 7
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 7
# Augmented google_gemini-2.5-flash for problem 7
# Processing problem 8...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 8
# Augmented openai_gpt-4.1-mini for problem 8
# Augmented google_gemini-2.0-flash-thinking-exp for problem 8
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 8
# Augmented google_gemini-2.5-flash for problem 8
# Processing problem 9...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 9
# Augmented openai_gpt-4.1-mini for problem 9
# Augmented google_gemini-2.0-flash-thinking-exp for problem 9
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 9
# Augmented google_gemini-2.5-flash for problem 9
# Processing problem 10...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 10
# Augmented openai_gpt-4.1-mini for problem 10
# Augmented google_gemini-2.0-flash-thinking-exp for problem 10
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 10
# Augmented google_gemini-2.5-flash for problem 10
# Processing problem 11...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 11
# Augmented openai_gpt-4.1-mini for problem 11
# Augmented google_gemini-2.0-flash-thinking-exp for problem 11
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 11
# Augmented google_gemini-2.5-flash for problem 11
# Processing problem 12...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 12
# Augmented openai_gpt-4.1-mini for problem 12
# Augmented google_gemini-2.0-flash-thinking-exp for problem 12
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 12
# Augmented google_gemini-2.5-flash for problem 12
# Processing problem 13...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 13
# Augmented openai_gpt-4.1-mini for problem 13
# Augmented google_gemini-2.0-flash-thinking-exp for problem 13
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 13
# Augmented google_gemini-2.5-flash for problem 13
# Processing problem 14...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 14
# Augmented openai_gpt-4.1-mini for problem 14
# Augmented google_gemini-2.0-flash-thinking-exp for problem 14
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 14
# Augmented google_gemini-2.5-flash for problem 14
# Processing problem 15...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 15
# Augmented openai_gpt-4.1-mini for problem 15
# Augmented google_gemini-2.0-flash-thinking-exp for problem 15
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 15
# Augmented google_gemini-2.5-flash for problem 15
# Processing problem 16...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 16
# Augmented openai_gpt-4.1-mini for problem 16
# Augmented google_gemini-2.0-flash-thinking-exp for problem 16
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 16
# Augmented google_gemini-2.5-flash for problem 16
# Processing problem 17...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 17
# Augmented openai_gpt-4.1-mini for problem 17
# Augmented google_gemini-2.0-flash-thinking-exp for problem 17
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 17
# Augmented google_gemini-2.5-flash for problem 17
# Processing problem 18...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 18
# Augmented openai_gpt-4.1-mini for problem 18
# Augmented google_gemini-2.0-flash-thinking-exp for problem 18
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 18
# Augmented google_gemini-2.5-flash for problem 18
# Processing problem 19...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 19
# Augmented openai_gpt-4.1-mini for problem 19
# Augmented google_gemini-2.0-flash-thinking-exp for problem 19
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 19
# Augmented google_gemini-2.5-flash for problem 19
# Processing problem 20...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 20
# Augmented openai_gpt-4.1-mini for problem 20
# Augmented google_gemini-2.0-flash-thinking-exp for problem 20
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 20
# Augmented google_gemini-2.5-flash for problem 20
# Processing problem 21...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 21
# Augmented openai_gpt-4.1-mini for problem 21
# Augmented google_gemini-2.0-flash-thinking-exp for problem 21
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 21
# Augmented google_gemini-2.5-flash for problem 21
# Processing problem 22...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 22
# Augmented openai_gpt-4.1-mini for problem 22
# Augmented google_gemini-2.0-flash-thinking-exp for problem 22
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 22
# Augmented google_gemini-2.5-flash for problem 22
# Processing problem 23...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 23
# Augmented openai_gpt-4.1-mini for problem 23
# Augmented google_gemini-2.0-flash-thinking-exp for problem 23
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 23
# Augmented google_gemini-2.5-flash for problem 23
# Processing problem 24...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 24
# Augmented openai_gpt-4.1-mini for problem 24
# Augmented google_gemini-2.0-flash-thinking-exp for problem 24
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 24
# Augmented google_gemini-2.5-flash for problem 24
# Processing problem 25...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 25
# Augmented openai_gpt-4.1-mini for problem 25
# Augmented google_gemini-2.0-flash-thinking-exp for problem 25
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 25
# Augmented google_gemini-2.5-flash for problem 25
# Processing problem 26...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 26
# Augmented openai_gpt-4.1-mini for problem 26
# Augmented google_gemini-2.0-flash-thinking-exp for problem 26
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 26
# Augmented google_gemini-2.5-flash for problem 26
# Processing problem 27...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 27
# Augmented openai_gpt-4.1-mini for problem 27
# Augmented google_gemini-2.0-flash-thinking-exp for problem 27
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 27
# Augmented google_gemini-2.5-flash for problem 27
# Processing problem 28...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 28
# Augmented openai_gpt-4.1-mini for problem 28
# Augmented google_gemini-2.0-flash-thinking-exp for problem 28
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 28
# Augmented google_gemini-2.5-flash for problem 28
# Processing problem 29...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 29
# Augmented openai_gpt-4.1-mini for problem 29
# Augmented google_gemini-2.0-flash-thinking-exp for problem 29
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 29
# Augmented google_gemini-2.5-flash for problem 29
# Processing problem 30...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 30
# Augmented openai_gpt-4.1-mini for problem 30
# Augmented google_gemini-2.0-flash-thinking-exp for problem 30
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 30
# Augmented google_gemini-2.5-flash for problem 30
# Processing problem 31...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 31
# Augmented openai_gpt-4.1-mini for problem 31
# Augmented google_gemini-2.0-flash-thinking-exp for problem 31
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 31
# Augmented google_gemini-2.5-flash for problem 31
# Processing problem 32...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 32
# Augmented openai_gpt-4.1-mini for problem 32
# Augmented google_gemini-2.0-flash-thinking-exp for problem 32
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 32
# Augmented google_gemini-2.5-flash for problem 32
# Processing problem 33...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 33
# Augmented openai_gpt-4.1-mini for problem 33
# Augmented google_gemini-2.0-flash-thinking-exp for problem 33
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 33
# Augmented google_gemini-2.5-flash for problem 33
# Processing problem 34...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 34
# Augmented openai_gpt-4.1-mini for problem 34
# Augmented google_gemini-2.0-flash-thinking-exp for problem 34
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 34
# Augmented google_gemini-2.5-flash for problem 34
# Processing problem 35...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 35
# Augmented openai_gpt-4.1-mini for problem 35
# Augmented google_gemini-2.0-flash-thinking-exp for problem 35
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 35
# Augmented google_gemini-2.5-flash for problem 35
# Processing problem 36...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 36
# Augmented openai_gpt-4.1-mini for problem 36
# Augmented google_gemini-2.0-flash-thinking-exp for problem 36
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 36
# Augmented google_gemini-2.5-flash for problem 36
# Processing problem 37...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 37
# Augmented openai_gpt-4.1-mini for problem 37
# Augmented google_gemini-2.0-flash-thinking-exp for problem 37
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 37
# Augmented google_gemini-2.5-flash for problem 37
# Processing problem 38...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 38
# Augmented openai_gpt-4.1-mini for problem 38
# Augmented google_gemini-2.0-flash-thinking-exp for problem 38
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 38
# Augmented google_gemini-2.5-flash for problem 38
# Processing problem 39...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 39
# Augmented openai_gpt-4.1-mini for problem 39
# Augmented google_gemini-2.0-flash-thinking-exp for problem 39
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 39
# Augmented google_gemini-2.5-flash for problem 39
# Processing problem 40...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 40
# Augmented openai_gpt-4.1-mini for problem 40
# Augmented google_gemini-2.0-flash-thinking-exp for problem 40
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 40
# Augmented google_gemini-2.5-flash for problem 40
# Processing problem 41...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 41
# Augmented openai_gpt-4.1-mini for problem 41
# Augmented google_gemini-2.0-flash-thinking-exp for problem 41
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 41
# Augmented google_gemini-2.5-flash for problem 41
# Processing problem 42...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 42
# Augmented openai_gpt-4.1-mini for problem 42
# Augmented google_gemini-2.0-flash-thinking-exp for problem 42
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 42
# Augmented google_gemini-2.5-flash for problem 42
# Processing problem 43...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 43
# Augmented openai_gpt-4.1-mini for problem 43
# Augmented google_gemini-2.0-flash-thinking-exp for problem 43
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 43
# Augmented google_gemini-2.5-flash for problem 43
# Processing problem 44...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 44
# Augmented openai_gpt-4.1-mini for problem 44
# Augmented google_gemini-2.0-flash-thinking-exp for problem 44
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 44
# Augmented google_gemini-2.5-flash for problem 44
# Processing problem 45...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 45
# Augmented openai_gpt-4.1-mini for problem 45
# Augmented google_gemini-2.0-flash-thinking-exp for problem 45
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 45
# Augmented google_gemini-2.5-flash for problem 45
# Processing problem 46...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 46
# Augmented openai_gpt-4.1-mini for problem 46
# Augmented google_gemini-2.0-flash-thinking-exp for problem 46
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 46
# Augmented google_gemini-2.5-flash for problem 46
# Processing problem 47...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 47
# Augmented openai_gpt-4.1-mini for problem 47
# Augmented google_gemini-2.0-flash-thinking-exp for problem 47
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 47
# Augmented google_gemini-2.5-flash for problem 47
# Processing problem 48...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 48
# Augmented openai_gpt-4.1-mini for problem 48
# Augmented google_gemini-2.0-flash-thinking-exp for problem 48
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 48
# Augmented google_gemini-2.5-flash for problem 48
# Processing problem 49...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 49
# Augmented openai_gpt-4.1-mini for problem 49
# Augmented google_gemini-2.0-flash-thinking-exp for problem 49
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 49
# Augmented google_gemini-2.5-flash for problem 49
# Processing problem 50...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 50
# Augmented openai_gpt-4.1-mini for problem 50
# Augmented google_gemini-2.0-flash-thinking-exp for problem 50
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 50
# Augmented google_gemini-2.5-flash for problem 50
# Processing problem 51...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 51
# Augmented openai_gpt-4.1-mini for problem 51
# Augmented google_gemini-2.0-flash-thinking-exp for problem 51
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 51
# Augmented google_gemini-2.5-flash for problem 51
# Processing problem 52...
# Could not get code lines for problem 52, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 52
# Augmented google_gemini-2.0-flash-thinking-exp for problem 52
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 52
# Augmented google_gemini-2.5-flash for problem 52
# Processing problem 53...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 53
# Augmented openai_gpt-4.1-mini for problem 53
# Augmented google_gemini-2.0-flash-thinking-exp for problem 53
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 53
# Augmented google_gemini-2.5-flash for problem 53
# Processing problem 54...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 54
# Augmented openai_gpt-4.1-mini for problem 54
# Augmented google_gemini-2.0-flash-thinking-exp for problem 54
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 54
# Augmented google_gemini-2.5-flash for problem 54
# Processing problem 55...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 55
# Augmented openai_gpt-4.1-mini for problem 55
# Augmented google_gemini-2.0-flash-thinking-exp for problem 55
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 55
# Augmented google_gemini-2.5-flash for problem 55
# Processing problem 56...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 56
# Augmented openai_gpt-4.1-mini for problem 56
# Augmented google_gemini-2.0-flash-thinking-exp for problem 56
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 56
# Augmented google_gemini-2.5-flash for problem 56
# Processing problem 57...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 57
# Augmented openai_gpt-4.1-mini for problem 57
# Augmented google_gemini-2.0-flash-thinking-exp for problem 57
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 57
# Augmented google_gemini-2.5-flash for problem 57
# Processing problem 58...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 58
# Augmented openai_gpt-4.1-mini for problem 58
# Augmented google_gemini-2.0-flash-thinking-exp for problem 58
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 58
# Augmented google_gemini-2.5-flash for problem 58
# Processing problem 59...
# Could not get code lines for problem 59, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 59
# Augmented google_gemini-2.0-flash-thinking-exp for problem 59
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 59
# Augmented google_gemini-2.5-flash for problem 59
# Processing problem 60...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 60
# Augmented openai_gpt-4.1-mini for problem 60
# Augmented google_gemini-2.0-flash-thinking-exp for problem 60
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 60
# Augmented google_gemini-2.5-flash for problem 60
# Processing problem 61...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 61
# Augmented openai_gpt-4.1-mini for problem 61
# Augmented google_gemini-2.0-flash-thinking-exp for problem 61
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 61
# Augmented google_gemini-2.5-flash for problem 61
# Processing problem 62...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 62
# Augmented openai_gpt-4.1-mini for problem 62
# Augmented google_gemini-2.0-flash-thinking-exp for problem 62
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 62
# Augmented google_gemini-2.5-flash for problem 62
# Processing problem 63...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 63
# Augmented openai_gpt-4.1-mini for problem 63
# Augmented google_gemini-2.0-flash-thinking-exp for problem 63
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 63
# Augmented google_gemini-2.5-flash for problem 63
# Processing problem 64...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 64
# Augmented openai_gpt-4.1-mini for problem 64
# Augmented google_gemini-2.0-flash-thinking-exp for problem 64
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 64
# Augmented google_gemini-2.5-flash for problem 64
# Processing problem 65...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 65
# Augmented openai_gpt-4.1-mini for problem 65
# Augmented google_gemini-2.0-flash-thinking-exp for problem 65
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 65
# Augmented google_gemini-2.5-flash for problem 65
# Processing problem 66...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 66
# Augmented openai_gpt-4.1-mini for problem 66
# Augmented google_gemini-2.0-flash-thinking-exp for problem 66
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 66
# Augmented google_gemini-2.5-flash for problem 66
# Processing problem 67...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 67
# Augmented openai_gpt-4.1-mini for problem 67
# Augmented google_gemini-2.0-flash-thinking-exp for problem 67
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 67
# Augmented google_gemini-2.5-flash for problem 67
# Processing problem 68...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 68
# Augmented openai_gpt-4.1-mini for problem 68
# Augmented google_gemini-2.0-flash-thinking-exp for problem 68
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 68
# Augmented google_gemini-2.5-flash for problem 68
# Processing problem 69...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 69
# Augmented openai_gpt-4.1-mini for problem 69
# Augmented google_gemini-2.0-flash-thinking-exp for problem 69
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 69
# Augmented google_gemini-2.5-flash for problem 69
# Processing problem 70...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 70
# Augmented openai_gpt-4.1-mini for problem 70
# Augmented google_gemini-2.0-flash-thinking-exp for problem 70
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 70
# Augmented google_gemini-2.5-flash for problem 70
# Processing problem 71...
# Could not get code lines for problem 71, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 71
# Augmented google_gemini-2.0-flash-thinking-exp for problem 71
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 71
# Augmented google_gemini-2.5-flash for problem 71
# Processing problem 72...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 72
# Augmented openai_gpt-4.1-mini for problem 72
# Augmented google_gemini-2.0-flash-thinking-exp for problem 72
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 72
# Augmented google_gemini-2.5-flash for problem 72
# Processing problem 73...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 73
# Error processing problem 73, model openai_gpt-4.1-mini: name 'math' is not defined
# Augmented google_gemini-2.0-flash-thinking-exp for problem 73
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 73
# Augmented google_gemini-2.5-flash for problem 73
# Processing problem 74...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 74
# Augmented openai_gpt-4.1-mini for problem 74
# Augmented google_gemini-2.0-flash-thinking-exp for problem 74
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 74
# Augmented google_gemini-2.5-flash for problem 74
# Processing problem 75...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 75
# Augmented openai_gpt-4.1-mini for problem 75
# Augmented google_gemini-2.0-flash-thinking-exp for problem 75
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 75
# Augmented google_gemini-2.5-flash for problem 75
# Processing problem 76...
# Could not get code lines for problem 76, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 76
# Augmented google_gemini-2.0-flash-thinking-exp for problem 76
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 76
# Augmented google_gemini-2.5-flash for problem 76
# Processing problem 77...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 77
# Augmented openai_gpt-4.1-mini for problem 77
# Augmented google_gemini-2.0-flash-thinking-exp for problem 77
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 77
# Augmented google_gemini-2.5-flash for problem 77
# Processing problem 78...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 78
# Augmented openai_gpt-4.1-mini for problem 78
# Augmented google_gemini-2.0-flash-thinking-exp for problem 78
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 78
# Augmented google_gemini-2.5-flash for problem 78
# Processing problem 79...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 79
# Augmented openai_gpt-4.1-mini for problem 79
# Augmented google_gemini-2.0-flash-thinking-exp for problem 79
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 79
# Augmented google_gemini-2.5-flash for problem 79
# Processing problem 80...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 80
# Augmented openai_gpt-4.1-mini for problem 80
# Augmented google_gemini-2.0-flash-thinking-exp for problem 80
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 80
# Augmented google_gemini-2.5-flash for problem 80
# Processing problem 81...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 81
# Augmented openai_gpt-4.1-mini for problem 81
# Augmented google_gemini-2.0-flash-thinking-exp for problem 81
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 81
# Augmented google_gemini-2.5-flash for problem 81
# Processing problem 82...
# Could not get code lines for problem 82, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 82
# Augmented google_gemini-2.0-flash-thinking-exp for problem 82
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 82
# Augmented google_gemini-2.5-flash for problem 82
# Processing problem 83...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 83
# Augmented openai_gpt-4.1-mini for problem 83
# Augmented google_gemini-2.0-flash-thinking-exp for problem 83
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 83
# Augmented google_gemini-2.5-flash for problem 83
# Processing problem 84...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 84
# Augmented openai_gpt-4.1-mini for problem 84
# Augmented google_gemini-2.0-flash-thinking-exp for problem 84
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 84
# Augmented google_gemini-2.5-flash for problem 84
# Processing problem 85...
# Could not get code lines for problem 85, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 85
# Augmented google_gemini-2.0-flash-thinking-exp for problem 85
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 85
# Augmented google_gemini-2.5-flash for problem 85
# Processing problem 86...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 86
# Augmented openai_gpt-4.1-mini for problem 86
# Augmented google_gemini-2.0-flash-thinking-exp for problem 86
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 86
# Augmented google_gemini-2.5-flash for problem 86
# Processing problem 87...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 87
# Augmented openai_gpt-4.1-mini for problem 87
# Augmented google_gemini-2.0-flash-thinking-exp for problem 87
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 87
# Augmented google_gemini-2.5-flash for problem 87
# Processing problem 88...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 88
# Augmented openai_gpt-4.1-mini for problem 88
# Augmented google_gemini-2.0-flash-thinking-exp for problem 88
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 88
# Augmented google_gemini-2.5-flash for problem 88
# Processing problem 89...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 89
# Augmented openai_gpt-4.1-mini for problem 89
# Augmented google_gemini-2.0-flash-thinking-exp for problem 89
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 89
# Augmented google_gemini-2.5-flash for problem 89
# Processing problem 90...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 90
# Augmented openai_gpt-4.1-mini for problem 90
# Augmented google_gemini-2.0-flash-thinking-exp for problem 90
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 90
# Augmented google_gemini-2.5-flash for problem 90
# Processing problem 91...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 91
# Augmented openai_gpt-4.1-mini for problem 91
# Augmented google_gemini-2.0-flash-thinking-exp for problem 91
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 91
# Augmented google_gemini-2.5-flash for problem 91
# Processing problem 92...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 92
# Augmented openai_gpt-4.1-mini for problem 92
# Augmented google_gemini-2.0-flash-thinking-exp for problem 92
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 92
# Augmented google_gemini-2.5-flash for problem 92
# Processing problem 93...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 93
# Augmented openai_gpt-4.1-mini for problem 93
# Augmented google_gemini-2.0-flash-thinking-exp for problem 93
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 93
# Augmented google_gemini-2.5-flash for problem 93
# Processing problem 94...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 94
# Augmented openai_gpt-4.1-mini for problem 94
# Augmented google_gemini-2.0-flash-thinking-exp for problem 94
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 94
# Augmented google_gemini-2.5-flash for problem 94
# Processing problem 95...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 95
# Augmented openai_gpt-4.1-mini for problem 95
# Augmented google_gemini-2.0-flash-thinking-exp for problem 95
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 95
# Augmented google_gemini-2.5-flash for problem 95
# Processing problem 96...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 96
# Augmented openai_gpt-4.1-mini for problem 96
# Augmented google_gemini-2.0-flash-thinking-exp for problem 96
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 96
# Augmented google_gemini-2.5-flash for problem 96
# Processing problem 97...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 97
# Augmented openai_gpt-4.1-mini for problem 97
# Augmented google_gemini-2.0-flash-thinking-exp for problem 97
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 97
# Augmented google_gemini-2.5-flash for problem 97
# Processing problem 98...
# Could not get code lines for problem 98, model anthropic_claude-3-5-haiku-20241022
# Augmented openai_gpt-4.1-mini for problem 98
# Augmented google_gemini-2.0-flash-thinking-exp for problem 98
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 98
# Augmented google_gemini-2.5-flash for problem 98
# Processing problem 99...
# Augmented anthropic_claude-3-5-haiku-20241022 for problem 99
# Augmented openai_gpt-4.1-mini for problem 99
# Augmented google_gemini-2.0-flash-thinking-exp for problem 99
# Augmented google_gemini-2.5-flash-lite-preview-06-17 for problem 99
# Augmented google_gemini-2.5-flash for problem 99
# Completed: 492/500 files processed successfully
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/71/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/76/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/anthropic_claude-3-5-haiku-20241022.py

# %%
import ast
import inspect
import importlib.util
import pandas as pd

def eval_default_expr(expr_node):
    """
    Safely evaluate a default argument AST node to obtain its value.

    Tries to use ast.literal_eval for simple literals (numbers, strings, etc.).
    Falls back to evaluating the expression using eval/compile for cases like arithmetic expressions (e.g., 1/2, 2*3).
    
    Parameters
    ----------
    expr_node : ast.AST
        The AST node representing the default value expression.

    Returns
    -------
    Any
        The evaluated value of the expression.
    """
    try:
        return ast.literal_eval(expr_node)
    except Exception:
        return eval(compile(ast.Expression(expr_node), filename="<ast>", mode="eval"))

def extract_vars_to_df(
        index: int, 
        models: list, 
        output_dir=BASE_OUTPUT_DIR,
        verbose=True,
        save=True):
    """
    Extracts argument and variable information from the 'solve' function in generated Python files for multiple models.

    For each model, loads the corresponding Python file, parses the 'solve' function, and collects:
      - All argument names, types (from type hints), and default values.
      - All intermediate and final variables (as determined by local variables in the function).
      - The role of each variable ('argument', 'intermediate', or 'final').

    Returns a pandas DataFrame with columns: index, model, variable, role, type, value.
    Optionally saves the DataFrame as a CSV file for each problem index.

    Parameters
    ----------
    index : int
        The problem index to process.
    models : list
        List of model names to process for the given index.
    output_dir : Path, optional
        The base directory containing the generated Python files (default: BASE_OUTPUT_DIR).
    verbose : bool, optional
        If True, prints progress and error messages (default: True).
    save : bool, optional
        If True, saves the resulting DataFrame as a CSV file (default: True).

    Returns
    -------
    pd.DataFrame
        DataFrame containing variable information for all models for the given index.
    """
    rows = []
    for model in models:
        problem_dir = output_dir / f"{index}"
        py_file_path = problem_dir / f"{model}.py"
        try:
            spec = importlib.util.spec_from_file_location("module.name", py_file_path)
            module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(module)
            if verbose:
                print(f"Processing ast for model {model}")
            with open(py_file_path, "r") as f:
                source = f.read()
            tree = ast.parse(source)

            result = {}

            for node in ast.walk(tree):
                if isinstance(node, ast.FunctionDef) and node.name == "solve":
                    # Arguments
                    args = node.args.args
                    defaults = node.args.defaults
                    if len(defaults) != len(args):
                        raise ValueError("All arguments must have default values.")
                    for arg, default in zip(args, defaults):
                        arg_name = arg.arg
                        # Get type from annotation
                        if arg.annotation is not None:
                            if isinstance(arg.annotation, ast.Name):
                                arg_type = arg.annotation.id
                            elif isinstance(arg.annotation, ast.Subscript):
                                arg_type = ast.unparse(arg.annotation)
                            else:
                                arg_type = str(ast.dump(arg.annotation))
                        else:
                            arg_type = "unknown"
                        value = eval_default_expr(default)
                        result[arg_name] = {
                            "role": "argument",
                            "type": arg_type,
                            "value": value
                        }
                    # Intermediate/final variables
                    solve_func = getattr(module, "solve")
                    arg_values = [result[arg.arg]["value"] for arg in args]
                    def capture_locals(*args, **kwargs):
                        frame = {}
                        def tracer(frame_obj, event, arg):
                            if event == "return":
                                frame.update(frame_obj.f_locals)
                            return tracer
                        sys.setprofile(tracer)
                        try:
                            ret = solve_func(*args, **kwargs)
                        finally:
                            sys.setprofile(None)
                        return frame, ret
                    locals_dict, _ = capture_locals(*arg_values)
                    for var, val in locals_dict.items():
                        if var not in result:
                            role = "final" if var == "answer" else "intermediate"
                            result[var] = {
                                "role": role,
                                "type": type(val).__name__,
                                "value": val
                            }
                    break
            # Add to rows
            for var, info in result.items():
                rows.append({
                    "index": index,
                    "model": model,
                    "variable": var,
                    "role": info["role"],
                    "type": info["type"],
                    "value": info["value"]
                })
        except FileNotFoundError:
            if verbose:
                print(f"File not found: {py_file_path}, skipping.")
            continue
        except Exception as e:
            if verbose:
                print(f"Error processing {py_file_path}: {e}, skipping.")
            continue
    df = pd.DataFrame(rows, columns=["index", "model", "variable", "role", "type", "value"])

    # save if required
    if save and not df.empty:
        save_path = problem_dir / f"{index}_variables.csv"
        df.to_csv(save_path, index=False)
    return df

def batch_extract_vars_to_df(
    indices: list,
    models: list = MODELS,
    output_dir=BASE_OUTPUT_DIR,
    verbose=True,
    save=True
):
    """
    Runs extract_vars_to_df for each index in indices.
    Returns a dict mapping index to the resulting DataFrame.
    """
    results = {}
    for idx in indices:
        if verbose:
            print(f"Processing index {idx}...")
        df = extract_vars_to_df(
            index=idx,
            models=models,
            output_dir=output_dir,
            verbose=verbose,
            save=save
        )
        results[idx] = df
    return results

# %%
vars_df_dict = batch_extract_vars_to_df(INDICES)
# Out:
# Processing index 0...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 1...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 2...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 3...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 4...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 5...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 6...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 7...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 8...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 9...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 10...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 11...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 12...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 13...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 14...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 15...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 16...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 17...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 18...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 19...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 20...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 21...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 22...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 23...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 24...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 25...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 26...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 27...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 28...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 29...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 30...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 31...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 32...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 33...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 34...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 35...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 36...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 37...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 38...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 39...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 40...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 41...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 42...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 43...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 44...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 45...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 46...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 47...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 48...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 49...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 50...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 51...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 52...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/52/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 53...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 54...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 55...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 56...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 57...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 58...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 59...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/59/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 60...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 61...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 62...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 63...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 64...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 65...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 66...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 67...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 68...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 69...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 70...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 71...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/71/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 72...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 73...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 74...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 75...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 76...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/76/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 77...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 78...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 79...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 80...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 81...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 82...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/82/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 83...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 84...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 85...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/85/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 86...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 87...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 88...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 89...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 90...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 91...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 92...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 93...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 94...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 95...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 96...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 97...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 98...
# File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/98/anthropic_claude-3-5-haiku-20241022.py, skipping.
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
# Processing index 99...
# Processing ast for model anthropic_claude-3-5-haiku-20241022
# Processing ast for model openai_gpt-4.1-mini
# Processing ast for model google_gemini-2.0-flash-thinking-exp
# Processing ast for model google_gemini-2.5-flash-lite-preview-06-17
# Processing ast for model google_gemini-2.5-flash
