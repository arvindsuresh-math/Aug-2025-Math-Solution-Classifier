# %%
import ast
import sys
from pathlib import Path
import shutil

# ---------------------------------------------------------------------- #
#  Global constants & Configuration
# ---------------------------------------------------------------------- #

def find_project_root():
    """Traverse upwards to find the project root, marked by the .git folder."""
    current_path = Path.cwd()
    while current_path != current_path.parent:
        if (current_path / ".git").is_dir():
            return current_path
        current_path = current_path.parent
    raise FileNotFoundError("Could not find project root. Is this a git repository?")


PROJECT_ROOT = find_project_root()
BASE_INPUT_DIR = PROJECT_ROOT / 'data' / 'code_gen_outputs_cleaned'
BASE_OUTPUT_DIR = PROJECT_ROOT / 'data' / 'code_gen_outputs_formatted' / 'formatted'
print(f"Project root found: {PROJECT_ROOT}")
print(f"Base input directory set to: {BASE_INPUT_DIR}")
print(f"Base output directory set to: {BASE_OUTPUT_DIR}")

MODEL_DICT = {
  "anthropic": ["claude-3-5-haiku-20241022"], 
  "openai": ["gpt-4.1-mini"],
  "google": ["gemini-2.0-flash-thinking-exp", 
             "gemini-2.5-flash-lite-preview-06-17",
             "gemini-2.5-flash"]
}

MODELS = [f"{provider}_{model}" for provider, sublist in MODEL_DICT.items() for model in sublist]
print(f"Available models: {MODELS}")
# Out:
# Project root found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math
# Base input directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned
# Base output directory set to: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted
# Available models: ['anthropic_claude-3-5-haiku-20241022', 'openai_gpt-4.1-mini', 'google_gemini-2.0-flash-thinking-exp', 'google_gemini-2.5-flash-lite-preview-06-17', 'google_gemini-2.5-flash']

# %%
import re

def get_code_lines_dict(
        problem_index: int, 
        model_name: str, 
        base_input_dir: Path = BASE_INPUT_DIR):
    """
    Returns a dict mapping line numbers (0-based) to the verbatim lines of code
    for the given problem index and model name.
    """
    import sys
    problem_dir = base_input_dir / str(problem_index)
    file_path = problem_dir / f"{model_name}.py"
    if not file_path.exists():
        print(f"[Error] File not found: {file_path}", file=sys.stderr)
        return None
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
    return {i: line.rstrip("\n") for i, line in enumerate(lines)}

def format_comment(comment_line):
    """
    Accepts a comment string. Returns '\n' if not in the format '#: ... Ln'.
    If correct, returns '#: Ln' (ignoring everything between).
    """
    m = re.match(r"^#:(.*)L(\d+)\s*$", comment_line.strip())
    if m:
        return f"#: L{m.group(2)}"
    return "\n"

def remove_trailing_comment(code_line):
    """
    Removes trailing comment from a code line unless it is '# FINAL ANSWER'.
    """
    if "#" not in code_line:
        return code_line
    code, comment = code_line.split("#", 1)
    if "FINAL ANSWER" in comment:
        return code_line.rstrip()
    return code.rstrip()

def remove_redundant_comments(lines):
    """
    Removes any comment line that is immediately followed by another comment line.
    """
    result = []
    for i, line in enumerate(lines):
        if line.startswith("#:"):
            # If next line is also a comment, skip this one
            if i + 1 < len(lines) and lines[i + 1].startswith("#:"):
                continue
            # If next line begins with "answer", skip this one
            if i + 1 < len(lines) and lines[i + 1].lstrip().startswith("answer"):
                continue
        result.append(line)
    return result

def format_generated_code(code_lines_dict):
    """
    Cleans and formats generated code according to the specified rules.
    """
    lines = list(code_lines_dict.values())
    # Find the end of the signature/docstring
    sig_end = 0
    for i, line in enumerate(lines):
        if line.strip().endswith('"""'):
            sig_end = i
            break
    signature = lines[:sig_end + 1]
    body = lines[sig_end + 1:]

    # First pass: format comments and remove trailing comments
    processed = []
    for line in body:
        stripped = line.strip()
        if stripped.startswith("#"):
            processed.append(format_comment(stripped))
        elif stripped == "":
            processed.append("\n")
        else:
            processed.append(remove_trailing_comment(line))

    # Second pass: remove all line breaks, keep only comments or code
    processed = [l for l in processed if l.strip() != ""]

    # Third pass: remove redundant comments
    processed = remove_redundant_comments(processed)

    # Assemble final code: signature, then body with correct indentation and blank lines before comments
    final_lines = signature.copy()
    indent = "    "
    for line in processed:
        if line.startswith("#:"):
            final_lines.append("")  # blank line before comment
            final_lines.append(f"{indent}{line}")
        elif line.lstrip().startswith("answer"):
            final_lines.append("")  # blank line before answer
            final_lines.append(f"{line}")
        else:
            final_lines.append(f"{indent}{line.strip()}")

    # Remove any extra blank lines at the end
    while final_lines and final_lines[-1].strip() == "":
        final_lines.pop()

    return "\n".join(final_lines)

import os

def batch_format_and_write(
    indices,
    models = MODELS,
    base_input_dir = BASE_INPUT_DIR,
    base_output_dir = BASE_OUTPUT_DIR,
    get_code_lines_dict=get_code_lines_dict,
    format_generated_code=format_generated_code
):
    """
    For each (index, model), generate formatted code and write to {base_output_dir}/{index}/{model}.py
    """
    for idx in indices:
        for model in models:
            code_lines_dict = get_code_lines_dict(idx, model, base_input_dir)
            if code_lines_dict is None:
                print(f"[Warning] No code for index={idx}, model={model}")
                continue
            formatted_code = format_generated_code(code_lines_dict)
            out_dir = base_output_dir / str(idx)
            out_dir.mkdir(parents=True, exist_ok=True)
            out_path = out_dir / f"{model}.py"
            with open(out_path, "w", encoding="utf-8") as f:
                f.write(formatted_code)
            print(f"Wrote formatted code to {out_path}")

# %%
INDICES = list(range(100))
batch_format_and_write(INDICES)
# Out:
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/0/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/0/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/0/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/0/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/0/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/1/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/1/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/1/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/1/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/1/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/2/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/2/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/2/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/2/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/2/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/3/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/3/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/3/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/3/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/3/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/4/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/4/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/4/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/4/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/4/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/5/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/5/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/5/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/5/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/5/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/6/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/6/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/6/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/6/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/6/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/7/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/7/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/7/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/7/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/7/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/8/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/8/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/8/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/8/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/8/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/9/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/9/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/9/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/9/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/9/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/10/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/10/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/10/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/10/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/10/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/11/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/11/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/11/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/11/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/11/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/12/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/12/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/12/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/12/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/12/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/13/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/13/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/13/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/13/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/13/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/14/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/14/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/14/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/14/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/14/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/15/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/15/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/15/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/15/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/15/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/16/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/16/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/16/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/16/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/16/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/17/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/17/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/17/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/17/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/17/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/18/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/18/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/18/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/18/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/18/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/19/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/19/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/19/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/19/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/19/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/20/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/20/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/20/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/20/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/20/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/21/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/21/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/21/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/21/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/21/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/22/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/22/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/22/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/22/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/22/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/23/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/23/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/23/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/23/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/23/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/24/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/24/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/24/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/24/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/24/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/25/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/25/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/25/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/25/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/25/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/26/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/26/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/26/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/26/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/26/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/27/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/27/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/27/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/27/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/27/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/28/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/28/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/28/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/28/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/28/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/29/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/29/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/29/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/29/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/29/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/30/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/30/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/30/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/30/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/30/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/31/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/31/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/31/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/31/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/31/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/32/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/32/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/32/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/32/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/32/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/33/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/33/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/33/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/33/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/33/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/34/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/34/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/34/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/34/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/34/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/35/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/35/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/35/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/35/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/35/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/36/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/36/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/36/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/36/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/36/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/37/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/37/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/37/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/37/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/37/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/38/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/38/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/38/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/38/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/38/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/39/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/39/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/39/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/39/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/39/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/40/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/40/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/40/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/40/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/40/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/41/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/41/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/41/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/41/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/41/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/42/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/42/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/42/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/42/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/42/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/43/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/43/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/43/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/43/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/43/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/44/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/44/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/44/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/44/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/44/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/45/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/45/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/45/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/45/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/45/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/46/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/46/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/46/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/46/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/46/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/47/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/47/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/47/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/47/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/47/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/48/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/48/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/48/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/48/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/48/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/49/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/49/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/49/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/49/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/49/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/50/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/50/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/50/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/50/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/50/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/51/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/51/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/51/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/51/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/51/google_gemini-2.5-flash.py
# [Warning] No code for index=52, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/52/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/52/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/52/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/52/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/53/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/53/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/53/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/53/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/53/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/54/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/54/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/54/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/54/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/54/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/55/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/55/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/55/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/55/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/55/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/56/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/56/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/56/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/56/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/56/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/57/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/57/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/57/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/57/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/57/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/58/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/58/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/58/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/58/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/58/google_gemini-2.5-flash.py
# [Warning] No code for index=59, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/59/openai_gpt-4.1-mini.py
# ...
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/81/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/81/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/81/google_gemini-2.5-flash.py
# [Warning] No code for index=82, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/82/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/82/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/82/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/82/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/83/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/83/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/83/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/83/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/83/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/84/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/84/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/84/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/84/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/84/google_gemini-2.5-flash.py
# [Warning] No code for index=85, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/85/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/85/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/85/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/85/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/86/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/86/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/86/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/86/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/86/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/87/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/87/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/87/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/87/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/87/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/88/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/88/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/88/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/88/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/88/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/89/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/89/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/89/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/89/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/89/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/90/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/90/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/90/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/90/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/90/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/91/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/91/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/91/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/91/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/91/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/92/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/92/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/92/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/92/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/92/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/93/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/93/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/93/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/93/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/93/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/94/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/94/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/94/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/94/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/94/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/95/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/95/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/95/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/95/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/95/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/96/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/96/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/96/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/96/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/96/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/97/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/97/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/97/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/97/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/97/google_gemini-2.5-flash.py
# [Warning] No code for index=98, model=anthropic_claude-3-5-haiku-20241022
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/98/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/98/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/98/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/98/google_gemini-2.5-flash.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/99/anthropic_claude-3-5-haiku-20241022.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/99/openai_gpt-4.1-mini.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/99/google_gemini-2.0-flash-thinking-exp.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/99/google_gemini-2.5-flash-lite-preview-06-17.py
# Wrote formatted code to /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_formatted/formatted/99/google_gemini-2.5-flash.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/52/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/59/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/71/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/76/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/82/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/85/anthropic_claude-3-5-haiku-20241022.py
# [Error] File not found: /Users/arvindsuresh/Documents/Github/Erdos-DL-June25-Math/data/code_gen_outputs_cleaned/98/anthropic_claude-3-5-haiku-20241022.py

# %%
def wrapper(index: int):
    for model in MODELS:
        lines_dict = get_code_lines_dict(index, model)
        if lines_dict is not None:
            cleaned_code = format_generated_code(lines_dict)
            print("="*50)
            print(f"Cleaned code for {model}")
            print("-"*50)
            print(cleaned_code)
        else:
            print(f"[Error] No code found for {model} at index {index}", file=sys.stderr)

# %%
wrapper(10)
# Out:
# ==================================================
# Cleaned code for anthropic_claude-3-5-haiku-20241022
# --------------------------------------------------
# def solve(
#     total_people_consumed: int = 847,  # Over three hundred years, it has consumed 847 people
#     num_periods: int = 3  # Monster rises once every hundred years over three hundred years
# ):
#     """Index: 10.
#     Returns: the number of people on the first ship the monster consumed."""
#
#     #: L4
#     total_ship_multiplier = 1 + 2 + 4
#
#     #: L5
#     people_on_first_ship = total_people_consumed / total_ship_multiplier
#
#     answer = people_on_first_ship  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for openai_gpt-4.1-mini
# --------------------------------------------------
# def solve(
#     total_people: int = 847,  # it has consumed 847 people over three hundred years
# ):
#     """Index: 10.
#     Returns: the number of people on the ship the monster ate in the first hundred years.
#     """
#
#     #: L4
#     total_ships_factor = 7
#
#     #: L5
#     first_ship_people = total_people / total_ships_factor
#
#     answer = first_ship_people  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.0-flash-thinking-exp
# --------------------------------------------------
# def solve(
#     every_hundred_years: int = 100, # rises from the waters once every hundred years
#     over_three_hundred_years: int = 300, # Over three hundred years
#     total_people_consumed: int = 847, # it has consumed 847 people
#     twice_as_many: int = 2 # each new ship has twice as many people as the last ship
# ):
#     """Index: 10.
#     Returns: the number of people on the ship the monster ate in the first hundred years.
#     """
#
#     #: L3
#     multiplier_third_ship = twice_as_many * twice_as_many
#
#     #: L4
#     total_factor = 1 + twice_as_many + multiplier_third_ship
#
#     #: L5
#     people_first_ship = total_people_consumed / total_factor
#
#     answer = people_first_ship # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash-lite-preview-06-17
# --------------------------------------------------
# def solve(
#     total_people_eaten: int = 847, # Over three hundred years, it has consumed 847 people.
#     years_between_feasts: int = 100, # once every hundred years
#     total_years: int = 300 # Over three hundred years
# ):
#     """Index: 10.
#     Returns: the number of people on the ship the monster ate in the first hundred years.
#     """
#
#     #: L4
#     total_proportions = 1 + 2 + 4
#
#     #: L5
#     people_on_first_ship = total_people_eaten / total_proportions
#
#     answer = people_on_first_ship # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash
# --------------------------------------------------
# def solve(
#         interval_years: int = 100, # once every hundred years
#         total_period_years: int = 300, # Over three hundred years
#         total_people_consumed: int = 847, # consumed 847 people
#         growth_factor: int = 2 # twice as many people as the last ship
#     ):
#     """Index: 10.
#     Returns: the number of people on the ship the monster ate in the first hundred years.
#     """
#
#     #: L3
#     coefficient_first_ship = 1
#     coefficient_second_ship = growth_factor
#     coefficient_third_ship = growth_factor * growth_factor
#
#     #: L4
#     total_coefficient_s = coefficient_first_ship + coefficient_second_ship + coefficient_third_ship
#
#     #: L5
#     people_on_first_ship = total_people_consumed / total_coefficient_s
#
#     answer = people_on_first_ship # FINAL ANSWER
#     return answer

# %%
wrapper(16)
# Out:
# ==================================================
# Cleaned code for anthropic_claude-3-5-haiku-20241022
# --------------------------------------------------
# def solve(
#     johnson_share_ratio: int = 5,  # Johnson gets 5 parts
#     mike_share_ratio: int = 2,  # Mike gets 2 parts
#     johnson_amount: int = 2500,  # Johnson got $2500
#     shirt_cost: int = 200  # shirt costs $200
# ):
#     """Index: 16.
#     Returns: the amount of money Mike has left after buying a shirt."""
#
#     #: L2
#     part_value = johnson_amount / johnson_share_ratio
#
#     #: L3
#     mike_total_share = mike_share_ratio * part_value
#
#     #: L4
#     mike_remaining_amount = mike_total_share - shirt_cost
#
#     answer = mike_remaining_amount  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for openai_gpt-4.1-mini
# --------------------------------------------------
# def solve(
#     johnson_share: int = 2500,  # Johnson got $2500
#     shirt_cost: int = 200  # shirt costs $200
# ):
#     """Index: 16.
#     Returns: the amount Mike has left after buying the shirt.
#     """
#
#     #: L2
#     value_per_part = johnson_share / 5
#
#     #: L3
#     mike_share = 2 * value_per_part
#
#     #: L4
#     mike_after_shirt = mike_share - shirt_cost
#
#     answer = mike_after_shirt  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.0-flash-thinking-exp
# --------------------------------------------------
# def solve(
#     num_partners: int = 2, # shared among 2 business partners
#     mike_ratio_part: int = 2, # in the ratio 2:5 respectively
#     johnson_ratio_part: int = 5, # in the ratio 2:5 respectively
#     johnson_share: int = 2500, # Johnson got $2500
#     shirt_cost: int = 200 # a shirt that costs $200
# ):
#     """Index: 16.
#     Returns: the amount of money Mike has left after buying the shirt.
#     """
#
#     #: L2
#     value_per_part = johnson_share / johnson_ratio_part
#
#     #: L3
#     mike_share = mike_ratio_part * value_per_part
#
#     #: L4
#     mike_remaining = mike_share - shirt_cost
#
#     answer = mike_remaining # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash-lite-preview-06-17
# --------------------------------------------------
# def solve(
#     johnson_share: int = 2500, # If Johnson got $2500
#     ratio_mike: int = 2, # Mike and Johnson in the ratio 2:5 respectively
#     ratio_johnson: int = 5, # Mike and Johnson in the ratio 2:5 respectively
#     shirt_cost: int = 200 # a shirt that costs $200
# ):
#     """Index: 16.
#     Returns: the amount of money Mike will have left after buying a shirt.
#     """
#
#     #: L2
#     value_per_part = johnson_share / ratio_johnson
#
#     #: L3
#     mike_share = ratio_mike * value_per_part
#
#     #: L4
#     mike_remaining_share = mike_share - shirt_cost
#
#     answer = mike_remaining_share # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash
# --------------------------------------------------
# def solve(
#         num_partners: int = 2, # 2 business partners
#         mike_ratio_part: int = 2, # in the ratio 2:5 respectively
#         johnson_ratio_part: int = 5, # in the ratio 2:5 respectively
#         johnson_share: int = 2500, # If Johnson got $2500
#         shirt_cost: int = 200 # on a shirt that costs $200
#     ):
#     """Index: 16.
#     Returns: Mike's remaining share after spending on a shirt.
#     """
#
#     #: L2
#     value_per_part = johnson_share / johnson_ratio_part
#
#     #: L3
#     mike_share = mike_ratio_part * value_per_part
#
#     #: L4
#     mike_remaining_share = mike_share - shirt_cost
#
#     answer = mike_remaining_share # FINAL ANSWER
#     return answer

# %%
wrapper(22)
# Out:
# ==================================================
# Cleaned code for anthropic_claude-3-5-haiku-20241022
# --------------------------------------------------
# def solve(
#     jamie_last_name: str = "Grey", # Jamie's full name is Jamie Grey
#     letters_difference: int = 3 # Samantha's last name has three fewer letters than Bobbie's
# ):
#     """Index: 22.
#     Returns: the number of letters in Samantha's last name."""
#
#     #: L1
#     jamie_last_name_length = len(jamie_last_name)
#     bobbie_last_name_length = jamie_last_name_length * 2 + 2
#
#     #: L2
#     samantha_last_name_length = bobbie_last_name_length - letters_difference
#
#     answer = samantha_last_name_length  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for openai_gpt-4.1-mini
# --------------------------------------------------
# def solve(
#     jamies_last_name_length: int = 4,  # Jamie’s last name is Grey, which has 4 letters
#     letters_removed_from_bobbie: int = 2,  # Bobbie took two letters off her last name
#     difference_samantha_bobbie: int = 3  # Samantha’s last name has three fewer letters than Bobbie’s
# ):
#     """Index: 22.
#     Returns: the number of letters in Samantha’s last name.
#     """
#
#     #: L1
#     bobbies_last_name_length = jamies_last_name_length * 2 + letters_removed_from_bobbie
#
#     #: L2
#     samanthas_last_name_length = bobbies_last_name_length - difference_samantha_bobbie
#
#     answer = samanthas_last_name_length  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.0-flash-thinking-exp
# --------------------------------------------------
# def solve(
#     samantha_fewer_than_bobbie: int = 3, # three fewer letters than Bobbie’s last name
#     bobbie_letters_removed: int = 2, # Bobbie took two letters off her last name
#     bobbie_multiplier_of_jamie: int = 2, # she would have a last name twice the length of Jamie’s
#     jamie_last_name_length: int = 4 # Jamie’s full name is Jamie Grey (Grey has 4 letters)
# ):
#     """Index: 22.
#     Returns: the number of letters in Samantha's last name.
#     """
#
#     #: L1
#     bobbie_last_name_length = jamie_last_name_length * bobbie_multiplier_of_jamie + bobbie_letters_removed
#
#     #: L2
#     samantha_last_name_length = bobbie_last_name_length - samantha_fewer_than_bobbie
#
#     answer = samantha_last_name_length # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash-lite-preview-06-17
# --------------------------------------------------
# def solve(
#     jamie_last_name_len: int = 4, # Jamie Grey.
#     bobbie_letters_removed: int = 2, # Bobbie took two letters off her last name
#     bobbie_name_multiplier: int = 2, # she would have a last name twice the length of Jamie’s
#     samantha_letters_fewer: int = 3 # Samantha’s last name has three fewer letters than Bobbie’s last name.
# ):
#     """Index: 22.
#     Returns: the number of letters in Samantha's last name.
#     """
#
#     #: L1
#     bobbie_last_name_len = (jamie_last_name_len * bobbie_name_multiplier) + bobbie_letters_removed
#
#     #: L2
#     samantha_last_name_len = bobbie_last_name_len - samantha_letters_fewer
#
#     answer = samantha_last_name_len # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash
# --------------------------------------------------
# def solve(
#         samantha_fewer_letters: int = 3, # three fewer letters
#         bobbie_letters_off: int = 2, # two letters off her last name
#         bobbie_length_multiplier: int = 2, # twice the length
#         jamie_last_name_length: int = 4 # Jamie’s full name is Jamie Grey (Grey has 4 letters)
#     ):
#     """Index: 22.
#     Returns: the number of letters in Samantha's last name.
#     """
#
#     #: L1
#     bobbie_last_name_length = jamie_last_name_length * bobbie_length_multiplier + bobbie_letters_off
#
#     #: L2
#     samantha_last_name_length = bobbie_last_name_length - samantha_fewer_letters
#
#     answer = samantha_last_name_length # FINAL ANSWER
#     return answer

# %%
wrapper(29)
# Out:
# ==================================================
# Cleaned code for anthropic_claude-3-5-haiku-20241022
# --------------------------------------------------
# def solve(
#     previous_rent_percentage: float = 0.4,  # Mrs. Snyder used to spend 40% of her monthly income on rent and utilities
#     new_rent_percentage: float = 0.25,  # now her rent and utilities only amount to 25% of her monthly income
#     income_increase: int = 600  # Her salary was recently increased by $600
# ):
#     """Index: 29.
#     Returns: Mrs. Snyder's previous monthly income."""
#
#     answer = 1000  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for openai_gpt-4.1-mini
# --------------------------------------------------
# def solve(
#     increase_amount: int = 600,  # salary was recently increased by $600
#     old_rent_fraction: float = 0.40,  # used to spend 40% of income on rent and utilities
#     new_rent_fraction: float = 0.25  # now rent and utilities amount to 25% of income
# ):
#     """Index: 29.
#     Returns: the previous monthly income before the salary increase.
#     """
#
#     #: L2
#     old_rent_cost_expr = (2/5)
#
#     #: L4
#     new_rent_cost_expr = (1/4)
#
#     #: L8
#     previous_income = 3000 / 3
#
#     answer = previous_income  # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.0-flash-thinking-exp
# --------------------------------------------------
# def solve(
#     rent_utilities_percent_before: float = 0.40, # spend 40% of her monthly income on rent and utilities
#     salary_increase: int = 600, # Her salary was recently increased by $600
#     rent_utilities_percent_after: float = 0.25 # now her rent and utilities only amount to 25% of her monthly income
# ):
#     """Index: 29.
#     Returns: the previous monthly income.
#     """
#
#     #: L6
#     lhs_step_6 = 20 * rent_utilities_percent_before
#     rhs_multiplier_step_6 = 20 * rent_utilities_percent_after
#     rhs_constant_step_6 = rhs_multiplier_step_6 * salary_increase
#
#     #: L7
#     lhs_step_7 = lhs_step_6 - rhs_multiplier_step_6
#
#     #: L8
#     previous_income = rhs_constant_step_6 / lhs_step_7
#
#     answer = previous_income # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash-lite-preview-06-17
# --------------------------------------------------
# def solve(
#     previous_rent_utility_percentage: float = 0.40, # Mrs. Snyder used to spend 40% of her monthly income on rent and utilities.
#     income_increase: int = 600, # Her salary was recently increased by $600
#     new_rent_utility_percentage: float = 0.25 # now her rent and utilities only amount to 25% of her monthly income.
# ):
#     """Index: 29.
#     Returns: Mrs. Snyder's previous monthly income.
#     """
#
#     #: L8
#     previous_monthly_income = (new_rent_utility_percentage * income_increase) / (previous_rent_utility_percentage - new_rent_utility_percentage)
#
#     answer = previous_monthly_income # FINAL ANSWER
#     return answer
# ==================================================
# Cleaned code for google_gemini-2.5-flash
# --------------------------------------------------
# def solve(
#         initial_rent_utilities_percentage: float = 0.40, # 40% of her monthly income on rent and utilities
#         salary_increase: int = 600, # Her salary was recently increased by $600
#         new_rent_utilities_percentage: float = 0.25 # now her rent and utilities only amount to 25% of her monthly income
#     ):
#     """Index: 29.
#     Returns: her previous monthly income.
#     """
#
#     #: L6
#     right_side_constant_term = 5 * salary_increase
#
#     #: L7
#     coefficient_of_p = 3
#
#     #: L8
#     previous_monthly_income = right_side_constant_term / coefficient_of_p
#
#     answer = previous_monthly_income # FINAL ANSWER
#     return answer
